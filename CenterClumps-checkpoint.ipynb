# %%
from astropy.table import Table
from astropy.table import vstack
import numpy as np
import pylab as plt
import photutils as phot

# %%
def FitsRead(time):
    # Read the fits file for that time and return table of stars
    if time < 10:
        time = '0{0}'.format(time)
    try:
        fileName = 'coords.starsandgas.chemrun733DiffFB10T1.0.00{0}0.fits'.format(time)
        read = Table.read(fileName,1)
        stars = (read['P']=='s')
        cat = read[stars]
    except:
        try:
            fileName = 'coords.chem733DiffFB10T1.0.00{0}0.fits'.format(time)
            cat = Table.read(fileName,1)
        except:
            raise ValueError('No file')
    return cat

# %%
txy = Table.read('clumps4.fits',1)
stars = Table.read('clumps4.fits',2)
merges = Table.read('clumps4.fits',3)
txyz = Table.read('txyzform.fits',1)

# %% [markdown]
# <h4>X-Y location plot and [O/Fe] vs [Fe/H] plot at 4 billion years for stars that formed within a distance of 0.5 from the center</h4>

# %%
snapshot = FitsRead(40)
txyzcut = txyz[0:len(snapshot)]
center = ((txyzcut['XFORM']**2+txyzcut['YFORM']**2+txyzcut['ZFORM']**2)**(1/2)<0.5)
centerform = snapshot[center]
age = 4-txyzcut['TFORM'][center]
plt.figure(figsize=(10,10))
x = centerform['X']
y = centerform['Y']
plt.scatter(x,y,c=age,s=1)
plt.xlabel('x')
plt.ylabel('y')
plt.title('x and y locations for stars formed in the center (color is age)')
plt.xlim((-25,25))
plt.ylim((-25,25))
plt.colorbar()
plt.figure(figsize=(10,10))
im, xedges, yedges  = np.histogram2d (-y,x,(100,100),range=[[-25,25],[-25,25]])
extent = [yedges[0], yedges[-1], -xedges[-1], -xedges[0]]
plt.imshow(np.log(im),cmap='Greys_r',extent=extent)
plt.xlabel('x')
plt.ylabel('y')
plt.title('x and y locations for stars formed in the center')
plt.xlim((-25,25))
plt.ylim((-25,25))
plt.figure(figsize=(10,10))
feh = centerform['FEH']
ofe = centerform['OFE']
plt.scatter(feh,ofe,c=age,s=1)
plt.xlabel('[Fe/H]')
plt.ylabel('[O/Fe]')
plt.title('[O/Fe] vs [Fe/H] for stars formed in the center (color is age)')
plt.xlim((-1.7,0.6))
plt.ylim((-0.8,0.6))
plt.colorbar()
# Out:
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: RuntimeWarning: divide by zero encountered in log

# %% [markdown]
# <h4>IDs of clumps that spent any time in the center and IDs of clumps that spent more than 50 timesteps in the center</h4>

# %%
inCenter = (txy['X']**2+txy['Y']**2<0.09)
center = txy[inCenter]

centerclumpslist = []
for i in center['CLUMPID']:
    if i not in centerclumpslist:
        centerclumpslist.append(i)
print(centerclumpslist)
print()

centerclumpslist2 = []
for i in centerclumpslist:
    inclumpi = (center['CLUMPID']==i)
    clumpi = center[inclumpi]
    if len(clumpi)>50:
        centerclumpslist2.append(i)
print(centerclumpslist2)
# Out:
# [1, 3, 9, 64, 66, 70, 78, 86, 95, 111, 112, 118, 119, 218, 230, 231, 236, 242, 246, 247, 252, 293, 296, 297, 304, 307, 310, 311, 317, 324, 325, 327, 329, 330, 331, 354, 366, 373, 378, 383, 415, 418, 423, 432, 435, 445, 447, 452, 455, 465, 471, 477, 482, 492, 509, 514, 519, 537, 542, 544, 546, 565, 576, 584, 591, 594, 600, 607, 608, 615, 618, 620, 623, 628, 633, 650, 651, 671, 721, 724, 725, 732, 734, 740, 741, 745]
#
# [1, 3, 86, 415, 628]

# %% [markdown]
# <h4>Tables showing times clumps in the center were tracked and their x and y positions.</h4>

# %%
tableslist = []
for i in centerclumpslist2:
    txyincenter = (txy['CLUMPID'] == i)
    center = txy[txyincenter]
    tableslist.append(center)
center = vstack(tableslist)
print(center)
# Out:
# CLUMPID  TIME       X             Y
# ------- ----- ------------- -------------
#       1   1.5     0.7346486      5.065455
#       1 1.501     0.5303958      5.111601
#       1 1.502    0.33361426     5.1580067
#       1 1.503    0.17744948     5.1704655
#       1 1.504   -0.01212932     5.1822066
#       1 1.505   -0.22100961      5.186489
#       1 1.506    -0.3806468      5.183966
#       1 1.507   -0.59482694      5.175237
#       1 1.508    -0.7448187      5.147476
#       1 1.509    -0.9578854       5.11038
#     ...   ...           ...           ...
#     628 3.794  -0.012497859  -0.022490969
#     628 3.795  0.0032371287  -0.014621845
#     628 3.796  -0.007044287  -0.008882827
#     628 3.797 -0.0054906337   -0.00996849
#     628 3.798    0.43168616   -0.24313399
#     628 3.799     0.4473843   0.035478268
#     628   3.8    0.44126514     0.0662997
#     628 3.801 0.00024803326 -0.0071340986
#     628 3.802  0.0017658926  -0.024360327
#     628 3.803    0.47175586    0.14948627
#     628 3.805    0.38310376     0.3719899
# Length = 4649 rows

# %% [markdown]
# <h4>Table showing indices (in the txyzform and snapshot files) for all the stars in center clumps.</h4>

# %%
tableslist = []
for i in centerclumpslist2:
    starsincenter = (stars['CLUMPID'] == i)
    center = stars[starsincenter]
    tableslist.append(center)
centerstars = vstack(tableslist)
print(centerstars)
# Out:
# CLUMPID  INDEX
# ------- -------
#       1  700310
#       1  700311
#       1  700312
#       1  700324
#       1  700325
#       1  700401
#       1  700402
#       1  700403
#       1  700404
#       1  700405
#     ...     ...
#     628 1262870
#     628 1262952
#     628 1262988
#     628 1263001
#     628 1263109
#     628 1263110
#     628 1263146
#     628 1263148
#     628 1263147
#     628 1263365
#     628 1263598
# Length = 155263 rows

# %% [markdown]
# <h4>Plots of the x and y locations of the stars in center clumps. The color of the dots corresponds to their age at the time of the snapshot.</h4>

# %%
times = []
masses = []
for time in range(4,9):
    plt.figure(figsize=(10,10))
    snapshot = FitsRead(time*5)
    cut = (centerstars['INDEX']<len(snapshot))
    cutstars = centerstars[cut]
    clumpstars = snapshot[cutstars['INDEX']]
    x = clumpstars['X']
    y = clumpstars['Y']
    age = time/2-txyz['TFORM'][cutstars['INDEX']]
    plt.scatter(x,y,c=age,s=1)
    plt.colorbar()
    plt.xlabel('x')
    plt.ylabel('y')
    plt.xlim((-10,10))
    plt.ylim((-10,10))
    plt.title('Center clump stars at {0} billion years (color is age).'.format(time/2))
