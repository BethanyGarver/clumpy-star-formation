# %%
import photutils as phot
from astropy.stats import sigma_clipped_stats
from astropy.table import Table
import numpy as np
import scipy.stats as stats
from scipy.interpolate import UnivariateSpline
import pylab as plt
from astropy.visualization import simple_norm

# %%
def FitsRead(time):
    # Read the fits file for that time and return table of stars
    if time < 10:
        time = '0{0}'.format(time)
    try:
        fileName = 'coords.starsandgas.chemrun733DiffFB10T1.0.00{0}0.fits'.format(time)
        read = Table.read(fileName,1)
        stars = (read['P']=='s')
        cat = read[stars]
    except:
        try:
            fileName = 'coords.chem733DiffFB10T1.0.00{0}0.fits'.format(time)
            cat = Table.read(fileName,1)
        except:
            raise ValueError('No file')
    return cat

# %%
def RotateBack(x,y,dtime,vcirc):
    # Rotate stars back in time
    lindist = vcirc*dtime #linear distance traveled in time interval
    rho = (x**2+y**2)**(1/2) #distance from z axis
    nrot = lindist/(2*np.pi*rho) #number of rotations
    nrotints = []
    for i in nrot:
        nrotints.append(int(i))
    nrotints = np.array(nrotints) #integer number of rotations
    rotangle = nrot-nrotints #partial rotation
    rotanglerad = 2*np.pi*rotangle #convert to radians
    xrot = x*np.cos(-rotanglerad)-y*np.sin(-rotanglerad) #x position at beginning of interval
    yrot = x*np.sin(-rotanglerad)+y*np.cos(-rotanglerad) #y position at beginning of interval
    return xrot,yrot

# %%
def make_unique(original_list):
    # Takes a list and returns it without duplicate entries
    unique_list = []
    [unique_list.append(obj) for obj in original_list if obj not in unique_list]
    return unique_list

# %%
def StarsInInterval(starlist,start,end):
    # Returns table of stars that formed within time interval
    tRange = (starlist['TFORM']>start,starlist['TFORM']<end)
    inRange = np.array(np.zeros(len(tRange[0])),dtype=bool) 
    for i in range(0,len(inRange)):
        if tRange[0][i] and tRange[1][i]:
            inRange[i] = True            #true for stars that formed in time interval
    newStars = starlist[inRange]
    return newStars

# %%
def FindPeaks(data,z):
    # Find peaks in 2D array of data
    statsdata = [] #only includes data points with density greater than 1 to calculate threshold
    for i in data:
        for j in i:
            if j>1:
                statsdata.append(j)
    mean, median, std = sigma_clipped_stats(statsdata, sigma=3.0)
    threshold = median + (z * std) #minimum density for a peak
    tbl = phot.find_peaks(data, threshold, box_size=11) #table of x index, y index, and density for peaks
    tbl['peak_value'].info.format = '%.8g'
    return tbl

# %%
def CombineClose(positions):
    # Combine multiple peaks in the same star cluster
    peaks = []
    closelist = []
    for i in range(0,len(positions[0])):
        jlist = [i] #a list containing that peak and other peaks near it
        for j in range(i+1,len(positions[0])):
            xi = positions[0][i]
            yi = positions[1][i]
            xj = positions[0][j]
            yj = positions[1][j]
            dist2 = (xi-xj)**2+(yi-yj)**2
            if dist2<0.1:
                jlist.append(j)
        closelist.append(jlist) #a list where each element is a list of nearby peaks
    for i in range(0,len(closelist)):
        if len(closelist[i])>1:
            for j in closelist[i]:
                if i==j:
                    continue
                closelist[j] = closelist[0]
    closelist = make_unique(closelist) #remove elements of closelist that contain the same peaks
    for i in closelist:
        sumx = 0
        sumy = 0
        for j in i:
            sumx = sumx+positions[0][j]
            sumy = sumy+positions[1][j]
        meanx = sumx/len(i) #mean x position of a close group of peaks
        meany = sumy/len(i) #mean y position of a close group of peaks
        peaks.append([meanx,meany])
    xcoords = []
    ycoords = []
    for peak in peaks:
        xcoords.append(peak[0])
        ycoords.append(peak[1])
    xcoords = np.array(xcoords) #array of peak x coordinates
    ycoords = np.array(ycoords) #array of peak y coordinates
    peaks1 = (xcoords,ycoords)
    return peaks1

# %%
def MeanPeaks(starlist,positions):
    # Make the x and y positions of the clumps equal to the mean x and y positions of the stars, rather than peak location
    x = []
    y = []
    for i in range(0,len(positions[0])):
        inclump = ((starlist['XROT']-positions[0][i])**2+(starlist['YROT']-positions[1][i])**2<0.09) #true for stars within
                                                                                                     #aperture
        clump = starlist[inclump] #only includes stars in clump
        x.append(np.mean(clump['XROT']))
        y.append(np.mean(clump['YROT']))
    x = np.array(x) #array of mean x coordinates of clump
    y = np.array(y) #array of mean y coordinates of clump
    meanPositions = (x,y)
    return x,y,meanPositions

# %%
def TrackClumps(oldClumps,xcoords,ycoords,stars):
    # Match clumps in current timestep to clumps in previous timesteps
    leftx = xcoords
    lefty = ycoords
    lefti = []
    clumps = oldClumps
    for i in range(0,len(leftx)):
        lefti.append(i)
    if len(clumps)>0:
        for skip in range(1,6): #run through the previous 5 timesteps
            clumpsrho = (leftx**2+lefty**2)**(1/2)
            clumpsvcirc = vDisk(clumpsrho)
            cxrot,cyrot = RotateBack(leftx,lefty,skip*dt,clumpsvcirc) #move clumps back in time
            xleft = []
            yleft = []
            ileft = []
            for i in range(0,len(cxrot)): #run through clumps in current timestep
                for clump in clumps: #run through clumps from previous timesteps
                    newest = clump[len(clump)-1] #[time,x,y] of the most recent location of the clump
                    if newest[0]==round(start-skip*dt,3): #only look at clumps that were found recently
                        xi = cxrot[i]
                        yi = cyrot[i]
                        xj = newest[1]
                        yj = newest[2]
                        if (xi-xj)**2+(yi-yj)**2<0.25 and clumpsrho[i]>0.5:
                            inclump = ((stars['XROT']-leftx[i])**2+(stars['YROT']-lefty[i])**2<0.09)
                            clumpStars = stars[inclump] #only includes stars in clump
                            clump.append([start,xcoords[lefti[i]],ycoords[lefti[i]]])
                            clump[0] = clump[0]+list(clumpStars['INDEX'])
                            clump[0] = make_unique(clump[0])
                            break
                    if clump==clumps[len(clumps)-1]: #make a list of clumps that do not match clumps seen earlier
                        xleft.append(leftx[i])
                        yleft.append(lefty[i])
                        ileft.append(lefti[i])
            leftx = np.array(xleft)
            lefty = np.array(yleft)
            lefti = ileft
    for i in range(0,len(lefti)): #add clumps that don't match older ones to the end of the list
        if leftx[i]**2+lefty[i]**2>0.25:
            inclump = ((stars['XROT']-leftx[i])**2+(stars['YROT']-lefty[i])**2<0.09)
            clumpStars = stars[inclump] #only includes stars in clump        
            clumps.append([list(clumpStars['INDEX']),[start,xcoords[lefti[i]],ycoords[lefti[i]]]])
    return clumps

# %%
# Read txyz file
txyz = Table.read('txyzform.fits',1)
index = np.linspace(0,len(txyz)-1,len(txyz))
txyz.add_column(Table.Column(index),name='INDEX')
rho = np.sqrt(txyz['XFORM']**2+txyz['YFORM']**2)
txyz.add_column(rho,name='RHO')
start = 1.5
dt = 0.001
clumps = []
oldClumps = []

for refTime in range(15,19):
    print('refTime = {}'.format(refTime))
    # Read snapshot file
    snapshot = FitsRead(refTime)
    r = np.sqrt(snapshot['X']**2+snapshot['Y']**2)
    theta = np.arctan2(snapshot['Y'],snapshot['X'])
    vth = -snapshot['VX']*np.sin(theta)+snapshot['VY']*np.cos(theta)
    snapshot.add_column(r,name='R')
    snapshot.add_column(vth,name='VTH')

    # Interpolate vDisk as a function of rho
    bins = int(np.max(r)/2.5)
    medians,binEdges,binNumber = stats.binned_statistic(r,vth,'median',bins)
    edges = []
    for i in range(0,len(binEdges)-1):
        edges.append((binEdges[i]+binEdges[i+1])/2)
    w = np.isnan(medians)
    medians[w] = 0
    vDisk = UnivariateSpline(edges,medians,~w)

    while round(start*10)==refTime and start<1.795:
        #Find stars that formed in time interval
        end = start+5*dt
        newStars = StarsInInterval(txyz,start,end)

        # Move stars back in time to beginning of interval
        vcirc = vDisk(newStars['RHO'])
        dtime = newStars['TFORM']-start
        xrot,yrot = RotateBack(newStars['XFORM'],newStars['YFORM'],dtime,vcirc)
        newStars.add_column(xrot,name='XROT')
        newStars.add_column(yrot,name='YROT')
        im, xedges, yedges  = np.histogram2d (-yrot,xrot,(100,100))
        dx = xedges[1]-xedges[0]
        dy = yedges[1]-yedges[0]
        extent = [yedges[0], yedges[-1], -xedges[-1], -xedges[0]]

        # Find peaks in density
        tbl = FindPeaks(im,2)

        # Combine clumps in the same place
        peakPositions = (yedges[tbl['x_peak']]+dy/2, -xedges[tbl['y_peak']]-dx/2)
        peaks = CombineClose(peakPositions)

        # Make clump positions the mean x and y of stars in the clump
        xcoords,ycoords,positions = MeanPeaks(newStars,peaks)

        # Track clumps through time
        clumps = TrackClumps(clumps,xcoords,ycoords,newStars)

        #Plot density plots with clumps
        #apertures = phot.CircularAperture(peaks, r=0.3)
        #norm = simple_norm(im, 'sqrt', percent=99.9)
        #plt.figure(figsize=(10,10))
        #plt.imshow(im, cmap='Greys_r', norm=norm, extent=extent)
        #apertures.plot(color='#0547f9', lw=1.5)
        #plt.title("{0} million years".format(int(start*1000)))

        start = round(start+dt,3)
    newClumps = []
    for clump in clumps:
        if clump[len(clump)-1][0]>start-5*dt:
            newClumps.append(clump)
        else:
            oldClumps.append(clump)
    clumps = newClumps
clumps = oldClumps+newClumps
print('{0} clumps total'.format(len(clumps)))
# Out:
# refTime = 15
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 16
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 17
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 18
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# 104 clumps total

# %%
#Plot locations of clumps through time
plt.figure(figsize=(10,10))
for i in clumps:
    x = []
    y = []
    for j in i:
        if len(j)==3:
            x.append(j[1])
            y.append(j[2])
    plt.plot(x,y)
plt.imshow(im, cmap='Greys_r', extent=extent)

# %%
# Print x and y locations of clumps
for i in clumps:
    t = Table(names=('TIME','X','Y'))
    for j in i:
        if len(j)==3:
            t.add_row((j[0],j[1],j[2]))
    print(t)
# Out:
#  TIME         X                   Y
# ----- ------------------ -------------------
#   1.5  4.884163187760024 -1.3393711604691092
# 1.501 4.9219028013607025 -1.1600113019655247
# 1.502  4.945343786353543 -1.0379250337894446
# 1.504  5.056402208167534 -0.6337596507016271
# 1.505  5.095244049104792 -0.4493198311864123
# 1.509  5.128224696891044 0.25696730686717206
#  1.51 5.1478036497823645 0.43432902646434174
# 1.511  5.126956717669865   0.587335104738798
# 1.512  5.122318664227216  0.7486740984147527
#  TIME          X                  Y
# ----- ------------------- ------------------
# 1.501 -3.1986745708763693  4.002963729953815
# 1.502 -3.2816341166611043  3.907128928064019
# 1.505  -3.652064763426272 3.5913535360489712
# 1.508  -4.020885402906126 3.2213209626479227
# 1.512 -4.4435205051561395  2.444233010020995
# 1.514   -4.48661249181008 1.9416636885308678
# 1.515   -4.50545195403269 1.7704526048964238
# 1.516  -4.608650974007918 1.6530057739670938
# 1.517  -4.912374609490131 1.6064346875127333
#  TIME          X                  Y
# ----- ------------------- ------------------
# 1.501 -2.5028157868249985 3.2776976307968986
# 1.502   -2.63443911805367 3.1686979557656607
#  TIME         X                  Y
# ----- ----------------- -------------------
# 1.501 4.374769438287054  -2.062107964988746
# 1.502 4.531443914299266 -1.8437150439108583
# 1.503 4.556070574902956  -1.737366552036287
#  TIME          X                  Y
# ----- ------------------- ------------------
# 1.501 -2.1924363497810266 -4.467725795872232
#  TIME         X                 Y
# ----- ----------------- ------------------
# 1.504 3.796715916815645 4.5483373982659545
# 1.505 3.706247078449874  4.629592727933152
#  TIME         X                   Y
# ----- ------------------ -------------------
# 1.511 3.4914878232449684 -2.0445799301062952
# 1.512 3.5620693729611808 -1.9066429122744466
# 1.513 3.6268275590937766 -1.7405089121525024
#  TIME         X                  Y
# ----- ------------------ -----------------
# 1.512 0.9520374214544582 -4.12158747028478
#  TIME         X                  Y
# ----- ------------------ -----------------
# 1.514 1.6782776823860228 5.291876423208002
# 1.515 1.5473195440596512 5.393615048236087
# 1.516 1.4278950295069839 5.454586006540847
# 1.517 1.3061222732192386 5.476130898099523
#  TIME         X                  Y
# ----- ------------------ ------------------
# 1.516 0.7183316445122884 -4.995838309416796
#  TIME         X                  Y
# ----- ------------------ -----------------
# 1.517 -4.640665150047003 1.513704092453535
#  TIME         X                    Y
# ----- ------------------ ---------------------
# 1.519 3.9668777570631706 -0.027308772204421256
# 1.522 3.9421553768677056     0.424084328280067
#  TIME          X                   Y
# ----- ------------------- --------------------
# 1.523  -5.166834849798842   0.5232435715803383
# 1.524  -5.139447723392449  0.38026170803839265
# 1.525 -5.1937991099956164  0.21604918981608615
# 1.526  -5.140453584419615 -0.13780098274501856
# 1.527  -5.134248293268764 -0.30099046545338903
# 1.529  -5.156256646638063  -0.7064946005403941
#  1.53  -5.128478961525843  -0.8748757500764001
# 1.531  -5.105479920487358  -1.0026984473983922
#  TIME         X                  Y
# ----- ------------------ ------------------
# 1.523  1.778305288224233 -5.081830959097787
# 1.526 2.2184930606973468 -4.906552821208631
#  TIME         X                 Y
# ----- ----------------- ------------------
# 1.524 2.296848613875108 2.9939104558124248
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.524 -0.5465395415165489 -1.6420020522569663
#  TIME          X                   Y
# ----- ------------------- --------------------
# 1.525 -5.1770243774124305 0.012587105161206152
#  TIME          X                   Y
# ----- -------------------- ------------------
# 1.526 -0.20682023431698682   5.80456721791104
# 1.527  -0.3513622530026211  5.798032725816001
# 1.528 -0.48951582273179184 5.7866176137065475
# 1.529  -0.7148922031696419  5.722353388242309
#  1.53  -0.8769170723162516  5.708742131866469
# 1.531  -1.0106652564449978  5.681268110281791
# 1.532  -1.1626588330526233   5.65227980451086
# 1.533  -1.2918657339913273  5.619188428475143
# 1.535   -1.726714946865037  5.475001071045099
#  TIME         X                  Y
# ----- ------------------ ------------------
# 1.526  4.010494337015936  3.233020676673629
# 1.527 3.8770825438851255 3.3880947881232784
# 1.529 3.6921190519557023 3.6010552564490608
# 1.531 3.6633831173231504 3.4186521770248213
#  TIME         X                   Y
# ----- ------------------ --------------------
# 1.526  2.992561238623826  -1.6613839075575587
#  1.53 3.2139196891327746  -1.0177801468388679
# 1.533   3.25606350370255  -0.4713123082215741
# 1.534   3.25968622695003  -0.3225585227329526
# 1.535 3.2984114002605316 -0.15365837537746596
#  TIME         X                 Y
# ----- ----------------- ------------------
# 1.527 4.094194656927952 3.3934166517760724
#  TIME         X                  Y
# ----- ------------------ -----------------
# 1.535  2.211232818318092 4.284931163373754
# 1.536 2.0757977068490128 4.337665100215286
#  TIME         X                  Y
# ----- ------------------ ------------------
# 1.535 -4.103550412178139 1.0819107803040449
#  TIME         X                   Y
# ----- ------------------ --------------------
# 1.535 -3.356197432318428 -0.29435070977453526
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.535 -4.4380528817207985  -1.608447548552204
# 1.537   -4.70374783074311 -2.1562489461106287
# 1.538 -4.6621498770589715 -2.2688104322301204
# 1.539  -4.582360366020784 -2.4123430772776606
#  1.54  -4.499063300919681  -2.551899197101076
# 1.543  -4.214153924914207 -2.9475773887587056
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.535  -3.619567213796847 -1.5233842485299955
# 1.537 -3.4783019521629774 -1.8823458249785663
# 1.538  -3.407588613385479 -2.0075728126274597
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.535 -1.9185519232811317 -1.5964345906944222
#  TIME         X                  Y
# ----- ------------------ ------------------
# 1.535 0.3456440526567386 -2.495354146885833
#  TIME          X                  Y
# ----- ------------------- ------------------
# 1.539 -0.3361581961346069 1.9655713049940857
#  TIME          X                  Y
# ----- ------------------- -----------------
# 1.542 -3.2324795828031596 3.735367544073083
#  TIME         X                  Y
# ----- ------------------ -----------------
# 1.542 2.8112772783604876 1.146196046812844
#  TIME         X                  Y
# ----- ------------------ ------------------
# 1.533 3.0374619645096175  4.051790037768469
# 1.535 2.9622999630368088  4.234091262387363
# 1.537 2.7580738080792675  4.383717571855383
# 1.539 2.3960077896813723  4.566870398030879
#  1.54 2.2083370703928753  4.674518576954845
# 1.541 2.0739459190658582  4.740768146861659
# 1.542  1.890576040557584  4.802810689884221
# 1.543 1.7391538408301919  4.855447820219359
# 1.544 1.5258936032497525  4.912892503234043
# 1.545  1.293503476634941  4.966519803768792
# 1.546 1.1581891894943863 5.0035713126275665
# 1.547 0.9940854790748209  5.045686093767172
# 1.548  0.840799567195222  5.076082941730889
# 1.549 0.6932258237718304   5.10861766280636
#  TIME        X                 Y
# ----- ---------------- -----------------
# 1.549 2.24835791617755 2.214721587159889
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.549 -2.5777547654102086 -3.5733293037350364
# TIME         X                  Y
# ---- ----------------- -------------------
# 1.55 4.458627113936022 -0.7983186333921972
#  TIME         X                  Y
# ----- ------------------ ------------------
# 1.551 3.8540710027556537 2.5323052334829965
#  TIME         X                 Y
# ----- ------------------ ----------------
# 1.554 -4.239183437449136 2.26486218361713
#  TIME         X                 Y
# ----- ----------------- -----------------
# 1.555 4.425823643275528 1.682467509819747
#  TIME          X                    Y
# ----- -------------------- -------------------
# 1.564  -1.9972554914298295   4.438909725616308
# 1.566  -2.3004877152952554    4.27578883596292
# 1.567  -2.5285631757101896   4.145887756027864
# 1.568  -2.7768817582995764   3.930030766512968
# 1.569   -2.864139461476552   3.877955869843982
#  1.57  -2.9949727631390317  3.7923695530085384
# 1.571  -3.0984604278350276  3.7250401642377384
# 1.572   -3.206619208275474  3.6169649803980395
# 1.573  -3.3585057067343578  3.4580424594229675
# 1.574  -3.4598053955568058   3.310702465772446
#   ...                  ...                 ...
# 1.627   -1.007687677705679  -4.376495043686414
# 1.628  -0.8611739269560099 -4.3874844062929395
# 1.629    -0.67702295582807  -4.406830818358677
#  1.63  -0.4710530747450715  -4.451186419605686
# 1.631 -0.31423028804957476  -4.474347736718941
# 1.633  0.04544169520437084  -4.456162935473472
# 1.634   0.2317394314022412  -4.465257876260105
# 1.635   0.4343121275255379  -4.429666102020109
# 1.636   0.5836974969300096  -4.392397376860608
# 1.637   0.8728933214430464  -4.289421343907598
# 1.638   0.9829198760099265   -4.28140616251391
# Length = 73 rows
#  TIME         X                  Y
# ----- ------------------ -----------------
# 1.567 -2.672087661566233 4.016219466689562
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.571  -4.629358016881465  0.4377598975363731
# 1.572  -4.602376916352226 0.25193499164880556
# 1.573 -4.6072761691847495 0.10070569691362624
# 1.575  -4.435417739757247  -0.325874127790086
#  TIME          X                  Y
# ----- ------------------- -----------------
# 1.575 -3.5459590671353753 3.037573778629097
#  TIME         X                  Y
# ----- ------------------ -----------------
# 1.579 2.1867896908530637 -3.42917440157235
#  TIME         X                  Y
# ----- ------------------ ------------------
# 1.584 3.3320039439743656 1.1885046664360208
#  TIME         X                  Y
# ----- ------------------ ------------------
# 1.585 3.0817916445123115 -2.197567568211511
#  TIME         X                  Y
# ----- ----------------- -------------------
# 1.585 2.974244520603306 -2.7005465209784587
#  TIME          X                  Y
# ----- ------------------- -----------------
# 1.586 -1.0736910762774836 4.761425238502399
#  TIME          X                  Y
# ----- ------------------- ------------------
# 1.588 -0.8436301982230492  4.720694393483631
# 1.589  -1.014629708827295  4.698174967096719
#  1.59 -1.1508740752253852  4.646077386815037
# 1.591  -1.337566631537253 4.6357929035577765
#  TIME          X                  Y
# ----- ------------------- ------------------
# 1.588 -3.1121040611621087 -2.514230645693947
#  TIME         X                  Y
# ----- ------------------ ------------------
# 1.591 1.5069771240643026 2.9804970951078555
# 1.592 1.4091005779732053  3.042823747076951
#  TIME          X                   Y
# ----- ------------------- --------------------
# 1.594  -2.360197968519929    4.188091269657576
# 1.596  -2.621726214293591    4.022764075103886
# 1.597 -2.7942527039695864   3.8833719304886576
# 1.601 -3.3191910405605394   3.4456999451880885
# 1.602 -3.4109043245582265   3.2980598729039796
# 1.603  -3.512920461295573    3.163473699016156
# 1.604 -3.6054264327236183   3.0424403241741946
# 1.605  -3.687156465422791   2.8911108431634345
# 1.606 -3.7841502479067466   2.7924981483549636
# 1.607 -3.9071285446935335   2.6258748167962054
# 1.611  -4.172197370567359   1.9777716097144813
# 1.612  -4.255145559440318   2.0533421933678477
# 1.614  -4.311969463947531   1.4142330890294303
# 1.615  -4.354096882069225   1.2891349078192011
# 1.616  -4.387823735240826   1.1001400085288526
# 1.617 -4.4910387642797165   1.0237055350133069
# 1.618  -4.417577695923833     0.72428836585894
# 1.621  -4.350218299970616  0.11314651155257494
# 1.622 -4.3311469260144815 -0.09112217128361576
# 1.623  -4.315551095673196  -0.2560781916483706
# 1.624    -4.2569011288058 -0.40923079639093213
# 1.626  -4.164019521429136  -0.7383725584250956
#  TIME          X                   Y
# ----- ------------------- --------------------
# 1.595  -5.199308954063036 -0.08654192978661124
# 1.596  -5.218090305201907 -0.24558823401094546
# 1.597  -5.224721778297493  -0.4862269703239884
# 1.598  -5.212864138512307  -0.6928342997983848
# 1.599  -5.194321526983015  -0.8984311713948794
#   1.6  -5.165177211768256  -1.0895322078517402
# 1.601  -5.133837301973122  -1.3017556857619226
# 1.602 -5.0748800021604525   -1.515396899051398
# 1.603  -5.030361318598333  -1.6846165749004258
# 1.604  -4.961784651026171  -1.9021143174096877
# 1.605  -4.883212639047521  -2.1124949759236027
# 1.606  -4.807914585671066  -2.3421797099071666
# 1.607  -4.737390272911825   -2.517680113957778
# 1.608 -4.6803265325723755  -2.6517554444295834
# 1.609  -4.594852529196282  -2.8419095681784787
#  1.61  -4.500984204486625  -3.0132330618749235
# 1.612 -4.2074815056770385   -3.467420987461225
# 1.614  -3.971826230144638  -3.8022566028771654
# 1.615    -3.8674013811772  -3.9156262816013703
# 1.616  -3.733539841324447   -4.065129848553128
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.596 -2.1138379402288185 -3.2493253295009157
#  TIME         X                  Y
# ----- ------------------ -----------------
# 1.612 -4.190553494199953 1.693516469352794
#  TIME          X                   Y
# ----- -------------------- ------------------
# 1.623   -2.507488600424426 -4.870856917121849
# 1.624  -2.3116358027424426 -4.954849770758312
# 1.627  -1.8562188671068534 -5.223623581393065
# 1.628  -1.6484150031860487 -5.325286411110833
# 1.629  -1.4306955026419688 -5.414481210519339
#  1.63   -1.230518866497391  -5.45665676841873
# 1.631  -1.0680165279937905 -5.482365978525114
# 1.633  -0.6832900088924955 -5.526357997489032
# 1.634 -0.48002255656303283 -5.565156977227584
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.633 -3.5383286850788425 -1.9385359286410873
# 1.634  -3.335965312881222  -2.059600108577171
# 1.635  -3.210955514516911 -2.2318090343633994
# 1.636 -3.1358308495206533 -2.3378941365872365
# 1.637  -2.978207403706695 -2.4384436400291225
# 1.638 -2.7600011063541934  -2.577476306078685
# 1.639 -2.6091007310646868 -2.6983775423809346
#  1.64 -2.5482191585401304  -2.793777240291957
#  TIME         X                  Y
# ----- ------------------ ------------------
# 1.645 3.0297584300341978 -1.856240895746562
#  TIME          X                  Y
# ----- ------------------- ------------------
# 1.645 -3.3976341920383777 -2.703958533844246
#  TIME        X                Y
# ----- --------------- ------------------
# 1.646 2.3410009516208 -3.599034649901239
#  TIME          X                   Y
# ----- ------------------- --------------------
#   1.5 -3.8325034663434114   -2.261198737982124
# 1.501 -3.7509953976553603  -2.4010690202439644
# 1.502  -3.650569834405383     -2.5587114923308
# 1.503 -3.5537974509073256   -2.694399455833148
# 1.504  -3.446904134226015   -2.852370447381483
# 1.505 -3.3179431242846795   -3.019750942740805
# 1.506 -3.2065872172304988  -3.1378315319457593
# 1.507 -3.0654219552130764  -3.2844439372404475
# 1.508  -2.929381173624958   -3.411993605361357
# 1.509  -2.788791952623082    -3.53706381330977
#   ...                 ...                  ...
# 1.707   4.807597469172848  -1.0404582144155008
# 1.708   4.817907533668325  -0.8706579065274884
# 1.709   4.802887012188741  -0.6809810400944524
#  1.71   4.811010423415612  -0.5223783014677423
# 1.711   4.781765952963827 -0.32890035364339937
# 1.712   4.733850616682954 -0.13887607885294803
# 1.713   4.691981780451666 0.019910186904817332
# 1.714   4.614041550382786   0.2088068715813711
# 1.715   4.561989163704857  0.37906672148112996
# 1.716   4.493375344991192    0.532048447329531
# 1.717   4.395946930089252   0.7176621483313698
# Length = 218 rows
#  TIME          X                   Y
# ----- ------------------- -------------------
#  1.55 -3.0268150751329372 -3.7047901886081456
# 1.551 -2.8891450424802074   -3.77805870032929
# 1.553 -2.6520505100504597  -4.075862123864154
# 1.554   -2.51307189095431  -4.174466013634897
# 1.555  -2.286757164030266  -4.217913012626699
# 1.556 -2.1292426846597285  -4.288230410247306
# 1.557  -1.981721979424873  -4.382384859891683
# 1.558 -1.8109339850981634  -4.445053091655611
# 1.562 -1.1431621242515118  -4.708461157145836
# 1.563 -0.9258264419804049  -4.779425435727445
#   ...                 ...                 ...
# 1.659 -1.4184045231554894  4.2950082833594045
#  1.66  -1.592173168192507   4.166241882480133
# 1.661 -1.7431003581388598  4.0864691555726145
# 1.662 -1.8959680651353092  3.9667721792856048
# 1.663 -2.0381150296785107   3.850587649973782
# 1.664 -2.1876247555808703   3.705804064000815
# 1.665  -2.326495174238651  3.5537677608645897
# 1.666 -2.4541309531445057  3.4363735916447977
# 1.667 -2.5776529156371852  3.2994795392724092
# 1.668  -2.699681188158897  3.1580113365004108
#  1.67  -2.899003193594918  2.7686455642897996
# Length = 116 rows
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.583  -3.892935302319033 -1.6765638998583745
# 1.584  -3.801805994005509 -1.8057831450333082
# 1.585  -3.691425673409746 -1.9216181101122096
# 1.586 -3.5761522100298966  -2.103945219189503
# 1.587 -3.4830560129159247 -2.2421684649286755
# 1.588  -3.391949113238258  -2.357670223360173
# 1.589 -3.1943594983146553 -2.5458355302731843
#  1.59  -3.041548502281639 -2.6929513442869375
# 1.591 -2.9376331345840097  -2.790243825604415
# 1.592  -2.888567283876775  -2.885049831354559
#   ...                 ...                 ...
# 1.643  2.9091216550469783   1.206297353795117
# 1.644  2.8063872568590993  1.4079409780373395
# 1.645   2.699573026601643  1.5811248536912383
# 1.646   2.597827193878652  1.7311844043161313
# 1.647  2.4770293496270055  1.9087859362140902
# 1.648   2.357316433969199  2.0547327558776938
# 1.649  2.2236952231732467   2.232448542123591
#  1.65   2.087273099427139   2.371497110963783
# 1.651  1.9643131316003055  2.4833500933720285
# 1.652  1.7965953017536738   2.628833108315513
# 1.653  1.6326902507771728  2.7458217181524525
# Length = 70 rows
#  TIME          X                  Y
# ----- ------------------- ------------------
# 1.648 -1.0132539361250357 -3.463801506407228
#  TIME         X                  Y
# ----- ----------------- -------------------
# 1.654 3.308852465065052 -2.4031344491541264
#  TIME         X                  Y
# ----- ----------------- -------------------
# 1.674 3.025091377975335 -1.8350935292938781
#  TIME         X                   Y
# ----- ------------------ -------------------
# 1.698 3.7847017413218684 -2.4957010846247716
#  TIME         X                  Y
# ----- ------------------ ------------------
# 1.708  1.650221022906526 0.7259426455550321
# 1.709 1.5592186613727939 0.8685574370094654
#  TIME         X                   Y
# ----- ------------------ -------------------
# 1.709 -2.378442052684938 0.20664196189266504
#  TIME         X                  Y
# ----- ------------------ ------------------
#  1.72  1.528731018918802 1.0716830103206219
# 1.721 1.4144672262760363 1.1888920259314806
#  TIME          X                   Y
# ----- -------------------- ------------------
# 1.731 -0.33271471388276247   1.28624943966539
# 1.732  -0.5106392085104265  1.172589550145523
# 1.733  -0.6583907796332319 1.0819663957621057
# 1.734   -0.814889532461529 0.9642309845583908
# 1.735  -0.9452339001848423 0.8568547840759351
# 1.736  -1.0489804713242514 0.7382446683619299
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.734 -1.0506954482107929 -2.4253564720369587
#  TIME         X                  Y
# ----- ----------------- -------------------
# 1.737 4.329678396312489 -2.0866064078110558
#  TIME         X                  Y
# ----- ----------------- -------------------
# 1.739 1.129498964427767 -1.1109329057137798
#  TIME         X                 Y
# ----- ----------------- ------------------
# 1.741 1.402938948932021 -4.301733324642853
#  TIME         X                  Y
# ----- ------------------ -----------------
# 1.743 0.7238892066128177 0.897185635841999
#  TIME         X                   Y
# ----- ------------------ --------------------
# 1.744 4.1672539754872515 -0.16939543789134157
#  TIME          X                    Y
# ----- -------------------- --------------------
#   1.5   0.7499688904340079   5.0829066193454295
# 1.501   0.5067010709321027    5.103552297083217
# 1.502  0.29935598704746086    5.152861023823722
# 1.503  0.15074089907192947    5.150677005419995
# 1.504 -0.02635404790436728    5.181999253040211
# 1.505  -0.2260562248234079    5.184210866079932
# 1.506   -0.375171800406551    5.181976218722902
# 1.507  -0.5925126674333906    5.172670526215814
# 1.508  -0.7489814134367596    5.147645907241599
# 1.509  -0.9578853813016895    5.110379979391937
#   ...                  ...                  ...
# 1.771  -1.5147998741944078    1.601608222783473
# 1.772  -1.6403993998583706   1.4620351549870465
# 1.773  -1.7517944228440459   1.3272887158043751
# 1.774  -1.8660274890886699   1.1802457865385052
# 1.775  -1.9861363856023353   1.0126490816785099
# 1.776  -2.0709657960175343   0.8587291762203761
# 1.777   -2.155827238752353   0.6865118916519264
# 1.778  -2.2210306880215893   0.5229623362561207
# 1.779  -2.3007813566290007   0.3340215644910727
#  1.78  -2.3711064851483408  0.14364698158512199
# 1.781  -2.4024794137843255 -0.02868081667080743
# Length = 282 rows
#  TIME         X                  Y
# ----- ----------------- -------------------
# 1.737 4.490296801332713  -2.646185071912426
# 1.738 4.588893282147214 -2.4768269969049364
# 1.743 4.950193853865515 -1.4985366933094555
# 1.744 4.942930859805358 -1.2192984956383714
# 1.746 5.017989273927044 -0.8861562786031281
# 1.747 5.061991018669112 -0.6998084935437919
# 1.748 5.265653631108792 -1.0000384470062484
#  TIME         X                  Y
# ----- ----------------- -------------------
# 1.737 4.564693730357727 -3.1608312129847507
# 1.739 4.681633713754644  -2.893444689761852
#  1.74 4.780568398985365 -2.7417049740911983
# 1.743 5.023590552979667 -2.1844403388802727
# 1.747 5.192980479888925 -1.1376423747210644
#  TIME         X                   Y
# ----- ------------------ --------------------
# 1.749 5.0632224870922355   -0.236918562168891
#  1.75  5.060510053986763 -0.09394609392609204
# 1.751  5.026248428356456  0.10154134009526342
# 1.752   5.07757052502971   0.2152635985802956
# 1.753  5.050206174984918    0.372932718851897
# 1.755  4.842909705190299   0.9322785790207093
# 1.757  4.748408275290548   1.3273797804505563
# 1.758  4.719782213207748   1.4907545844986938
# 1.759  4.611203493754663   1.6698754084680782
#  1.76  4.546592442290704    1.834911546123796
# 1.765 3.9942232325476494   2.6954776446773834
# 1.766  3.846439388409953    2.865554408598949
#  TIME         X                   Y
# ----- ------------------ -------------------
# 1.752 0.9426115827336349 -1.8421993235865888
#  TIME         X                   Y
# ----- ------------------ -------------------
# 1.753 0.4280336989617672  -2.255536373972878
# 1.755 0.7177940266908187  -2.167321561134159
# 1.756 0.8465996537458684 -2.1265895373708075
#  TIME         X                 Y
# ----- ----------------- ------------------
# 1.755 4.149790765935527 1.4013050547060493
# 1.756 4.091249275811605 1.5470448744213077
#  TIME         X                   Y
# ----- ------------------ -------------------
# 1.758 1.7396180370429515  -1.130482944928002
# 1.759 1.8270717552277072 -1.0025519310925957
#  TIME         X                  Y
# ----- ----------------- -------------------
# 1.764  2.04826154793498 -0.9523523094937795
# 1.765 2.114835456884596 -0.8010649825438484
#  TIME         X                  Y
# ----- ------------------ -----------------
# 1.765 1.8152020835431522 0.326295490230958
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.768 -0.5747650620122868 -0.1879617889194158
#  TIME         X                   Y
# ----- ------------------ --------------------
#  1.77 1.8176714423147755  -1.5386087935610977
# 1.772 1.9925844663132963  -1.2468946618376382
# 1.773 2.0746784333760795  -1.0593629996466871
# 1.774  2.144865522072101  -0.8595429721189317
# 1.776 2.2306174280193556 -0.45599222257215055
# 1.777 2.2344280060919957 -0.24422415872926173
#  TIME         X                   Y
# ----- ------------------ -------------------
# 1.774 1.4298410502627745 -2.4473017436031204
#  TIME         X                   Y
# ----- ------------------ -------------------
# 1.777 1.9273920688289994 0.36107419776147626
# 1.778 1.8849059616622545  0.5045534309147941
# 1.779 1.8506346492082781  0.6510160397770792
#  1.78 1.7697284727482023  0.8514128620352697
#  TIME         X                 Y
# ----- ------------------ ---------------
# 1.779 1.6758614041918667 4.4128585392718
#  TIME         X                   Y
# ----- ------------------ --------------------
# 1.779  4.741458845877934 0.046954441233924164
#  1.78   4.74369278631027  0.22879721992489152
# 1.781 4.7343025582279035   0.3757690396422822
# 1.782  4.714108440736724   0.5387288266770572
# TIME         X                  Y
# ---- ------------------ ------------------
# 1.78 2.2732444714152535 2.8715418556502623
#  TIME          X                  Y
# ----- ------------------- ------------------
# 1.785 -0.1021820238999785 3.5556174786053987
# 1.786 -0.2621707073792043 3.5205632309338615
# 1.787 -0.4335489587186725  3.488573359485331
#  TIME         X                  Y
# ----- ------------------ -----------------
# 1.787 -1.164839199067885 0.979316830078895
# TIME          X                   Y
# ---- ------------------- -------------------
# 1.79 -1.7139478496134752 -0.6408667410400832
#  TIME          X                   Y
# ----- ------------------- --------------------
#   1.5    -3.9095114316768   1.0366654327688711
# 1.501 -3.9705120947028703   0.8424085155262071
# 1.502  -4.019697360925169   0.6492957549545502
# 1.503  -4.045268649783327  0.48387585604985106
# 1.504  -4.081956527477604   0.2739437242036737
# 1.505  -4.094382222968071  0.06902452280218127
# 1.506   -4.09937324308466  -0.1219195290308174
# 1.507   -4.09524677338604  -0.3076978533047302
# 1.508  -4.088229347375009 -0.48107667307735913
# 1.509   -4.07301992497247  -0.6714284578278171
#   ...                 ...                  ...
# 1.784  -2.866884447325051  -0.9373483642710462
# 1.785 -2.7389104189237163  -1.0365162655683657
# 1.786 -2.6638770181891243   -1.169780134729789
# 1.787 -2.5600512968994846   -1.264021639311726
# 1.788 -2.4877471319074616   -1.415438404736913
# 1.789 -2.4040757535113655  -1.5497547309448942
#  1.79 -2.2961514149541875  -1.6842424428558382
# 1.791  -2.200903066395532  -1.8145513950250316
# 1.792 -2.0837804406407727  -1.9479075933375616
# 1.793 -1.9659363358555682  -2.0619115410964386
# 1.794 -1.8378456092192277   -2.167814081327537
# Length = 295 rows
#  TIME         X                   Y
# ----- ------------------ -------------------
#   1.5  4.415857403136349  1.1472416660058204
# 1.501  4.382836698909639   1.297122578208175
# 1.502 4.3161433797325595  1.4321114078343564
# 1.503 4.2400534760738156  1.5754698786625874
# 1.508  3.759765358527097  2.5405922757856167
# 1.509 3.6791144504655606   2.674367528165531
#  1.51  3.494171922858655  2.8547286804125505
# 1.511 3.4188248506606294   2.977614803633815
# 1.512 3.2782079563987008   3.131510066904045
# 1.513 3.1821547246978006  3.2611592905066065
#   ...                ...                 ...
# 1.784 2.2455172572389914 -3.8089821236412846
# 1.785 2.4075341160377355 -3.7115997590648955
# 1.786  2.531252206161673  -3.617541049838917
# 1.787  2.678015755629395 -3.5077599530887604
# 1.788  2.810333885270828 -3.3939351385832937
# 1.789 2.9456030858442865 -3.2654420964156445
#  1.79 3.0730851841138462 -3.1323872063256712
# 1.791  3.187027566652872 -3.0058328700409547
# 1.792  3.309803451931418 -2.8530647758084666
# 1.793 3.4090141542607615  -2.729512707042804
# 1.794 3.5125884438682435  -2.579918384130706
# Length = 291 rows
#  TIME          X                   Y
# ----- ------------------- -------------------
#   1.5  0.9775767588303711  -4.358749781344653
# 1.501  1.1543174697676366  -4.301655240046182
# 1.502  1.3513969557375862  -4.247646827587965
# 1.504  1.6745952249290197  -4.157006081571989
# 1.505  1.8456201871999813  -4.102512759471974
# 1.507  2.1275717686499545 -3.9298441127749815
# 1.508  2.2694714795515574 -3.8367962183624797
# 1.509  2.4253386251586795 -3.7346320715947883
#  1.51  2.5532465963849504 -3.6277091593935893
# 1.511   2.673165794324059 -3.5380577262433577
#   ...                 ...                 ...
# 1.784 -2.2707609998384224 -2.9553823674156305
# 1.785 -2.1141923575687525 -3.0563761737761763
# 1.786 -1.9842451936428724  -3.135576634092481
# 1.787  -1.829421628520977  -3.205805927202557
# 1.788 -1.6763898945425335 -3.2700080042726127
# 1.789  -1.506350527566095 -3.3005421944359683
#  1.79 -1.3501381666733243 -3.3320338151705324
# 1.791 -1.1942769031660234 -3.3747757950395845
# 1.792 -1.0236471049467055  -3.379660544970028
# 1.793 -0.8680233667721132   -3.39630293972444
# 1.794 -0.7079505281336725  -3.389395057476445
# Length = 293 rows
#  TIME          X                    Y
# ----- -------------------- -------------------
# 1.733   0.9091913303870961 -3.9098166676135957
# 1.734   1.0844878388451684  -3.834841050724551
# 1.735   1.2281505131123056  -3.748482023216024
# 1.736   1.4005847465513417 -3.6805225040193257
# 1.737   1.5700494738615105 -3.5796828212483653
# 1.738    1.710324910883968  -3.503356051896346
# 1.739   1.8211988628807987 -3.3452743856758995
#  1.74   1.9457750230433253 -3.2217897387189742
# 1.741    2.083697003172585  -3.109275894399093
# 1.742   2.2145622633390993  -2.953591726719218
#   ...                  ...                 ...
#  1.78   -0.306656004414715   2.413606296361964
# 1.781 -0.48940404514838043  2.3492297259917065
# 1.782  -0.6847358963179384  2.2791473187195854
# 1.783  -0.8560654316512071   2.211992061775596
# 1.784  -1.0135503973236535  2.1197669282286693
# 1.785  -1.1823504791384676  2.0243621417342066
# 1.786  -1.3291108547786508  1.9032819279894801
# 1.789  -1.7918181425031872  1.4606987207678885
# 1.791  -1.9966192893974266  1.1469697082369184
# 1.793  -2.0783109572530387  0.7662386449665883
# 1.794  -2.0507298672270573  0.5678739021562974
# Length = 58 rows
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.784   0.439811208301732 0.24398305070809662
# 1.785 0.48837026456314836 0.15104379257084452
# 1.786 0.49067676869556176 0.11170030952079928
# 1.787 0.44403197727991317 0.28649293163938394
# 1.789  0.4135661773496927  0.3138512788113932
#  1.79 0.40861241260653747   0.347600098703167
# 1.791 0.34133856919011507  0.3868097312696907
# 1.792  0.3649531650463052  0.3943720298826746
# 1.793  0.4562953445900628  0.2960972125463031
# 1.794 0.29018730760675215  0.4694869752816262
#  TIME          X                    Y
# ----- -------------------- -------------------
# 1.791 -0.19593363634977276 -0.8435268968529935
# 1.792  0.03289103677100469  -0.823989159299886
# 1.793   0.1636925472419469 -0.8169552999754799
#  TIME          X                  Y
# ----- ------------------- -----------------
# 1.792 -4.0116094038069505 2.428574912302726
#  TIME          X                  Y
# ----- ------------------- ------------------
# 1.793 -1.0934702220167318 1.9751678634403216

# %%
plt.figure(figsize=(10,10))
snapshot = FitsRead(18)
colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(newClumps))]
for clump,c in zip(newClumps,colors):
    x = []
    y = []
    for index in clump[0]:
        ind = int(index)
        x.append(snapshot['X'][ind])
        y.append(snapshot['Y'][ind])
    plt.scatter(x,y,color=c)
im, xedges, yedges  = np.histogram2d (-snapshot['Y'],snapshot['X'],(100,100),range=[[-5,5],[-5,6]])
extent = [yedges[0], yedges[-1], -xedges[-1], -xedges[0]]
plt.imshow(np.log(im), cmap='Greys_r', extent=extent)
# Out:
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in log

# %%
positions = (tbl['x_peak'], tbl['y_peak'])
apertures = phot.CircularAperture(positions, r=3)
norm = simple_norm(data, 'sqrt', percent=99.9)
plt.figure(figsize=(10,10))
plt.imshow(data, cmap='Greys_r', origin='lower', norm=norm)
apertures.plot(color='#0547f9', lw=1.5)
plt.xlim(0, data.shape[1]-1)
plt.ylim(0, data.shape[0]-1)
# Out:
# (0, 99)

# %%
# Read snapshot file
snapshot = FitsRead(16)
r = np.sqrt(snapshot['X']**2+snapshot['Y']**2)
theta = np.arctan2(snapshot['Y'],snapshot['X'])
vth = -snapshot['VX']*np.sin(theta)+snapshot['VY']*np.cos(theta)
snapshot.add_column(r,name='R')
snapshot.add_column(vth,name='VTH')

# Interpolate vDisk as a function of rho
bins = int(np.max(r)/2.5)
medians,binEdges,binNumber = stats.binned_statistic(r,vth,'median',bins)
edges = []
for i in range(0,len(binEdges)-1):
    edges.append((binEdges[i]+binEdges[i+1])/2)
w = np.isnan(medians)
medians[w] = 0
vDisk1 = UnivariateSpline(edges,medians,~w)

#Snapshot density plot
plt.figure(figsize=(10,10))
imS, xedgesS, yedgesS  = np.histogram2d (-snapshot['Y'],snapshot['X'],(100,100),range=[[-7,7],[-7,7]])
extentS = [yedgesS[0], yedgesS[-1], -xedgesS[-1], -xedgesS[0]]
plt.imshow(np.log(imS),extent=extentS)

#Clump 1 (2.77,3.5)
inclump1 = ((snapshot['X']-2.77)**2+(snapshot['Y']-3.5)**2<0.01)
clump1 = snapshot[inclump1]
#plt.figure(figsize=(10,10))
#imC1, xedgesC1, yedgesC1  = np.histogram2d (-clump1['Y'],clump1['X'],(100,100))
#extentC1 = [yedgesC1[0], yedgesC1[-1], -xedgesC1[-1], -xedgesC1[0]]
#plt.imshow(np.log(imC1),extent=extentC1)

#Clump 2 (0.9,4.23)
inclump2 = ((snapshot['X']-0.9)**2+(snapshot['Y']-4.23)**2<0.01)
clump2 = snapshot[inclump2]

#Clump 3 (-3.97,0.42)
inclump3 = ((snapshot['X']+3.97)**2+(snapshot['Y']-0.42)**2<0.01)
clump3 = snapshot[inclump3]

#Clump 4 (-2.96,4.3)
inclump4 = ((snapshot['X']+2.96)**2+(snapshot['Y']+4.3)**2<0.01)
clump4 = snapshot[inclump4]

#Plot vDisk and density plot
plt.figure(figsize=(10,10))
imVth, xedgesVth, yedgesVth  = np.histogram2d (-vth,r,(100,100),range=[[-400,50],[0,20]])
extentVth = [yedgesVth[0], yedgesVth[-1], -xedgesVth[-1], -xedgesVth[0]]
plt.imshow(np.log(imVth),extent=extentVth)
x = np.arange(0,20)
plt.plot(x,vDisk(x),color='r')
#plt.scatter(clump1['R'],clump1['VTH'])
plt.axes().set_aspect(20/450, 'datalim')

#Plot Vth vs r density plot for clumps
plt.figure(figsize=(10,10))
imV1, xedgesV1, yedgesV1  = np.histogram2d (-clump1['VTH'],clump1['R'],(100,20))
extentV1 = [yedgesV1[0], yedgesV1[-1], -xedgesV1[-1], -xedgesV1[0]]
plt.imshow(np.log(imV1),extent=extentV1)
imV2, xedgesV2, yedgesV2  = np.histogram2d (-clump2['VTH'],clump2['R'],(100,20))
extentV2 = [yedgesV2[0], yedgesV2[-1], -xedgesV2[-1], -xedgesV2[0]]
plt.imshow(np.log(imV2),extent=extentV2)
imV3, xedgesV3, yedgesV3  = np.histogram2d (-clump3['VTH'],clump3['R'],(100,20))
extentV3 = [yedgesV3[0], yedgesV3[-1], -xedgesV3[-1], -xedgesV3[0]]
plt.imshow(np.log(imV3),extent=extentV3)
imV4, xedgesV4, yedgesV4  = np.histogram2d (-clump4['VTH'],clump4['R'],(100,20))
extentV4 = [yedgesV4[0], yedgesV4[-1], -xedgesV4[-1], -xedgesV4[0]]
plt.imshow(np.log(imV4),extent=extentV4)
plt.plot(x,vDisk(x),color='r')
plt.xlim(3.5,5.5)
plt.axes().set_aspect(2/450, 'datalim')
# Out:
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: RuntimeWarning: divide by zero encountered in log
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:49: RuntimeWarning: divide by zero encountered in log
# C:\Users\betha\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: divide by zero encountered in log
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:62: RuntimeWarning: divide by zero encountered in log
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:65: RuntimeWarning: divide by zero encountered in log
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:68: RuntimeWarning: divide by zero encountered in log

# %%
clumps[0][0]
# Out:
# [725799.0,
#  725800.0,
#  725801.0,
#  725802.0,
#  725803.0,
#  725804.0,
#  725805.0,
#  725806.0,
#  725807.0,
#  725984.0,
#  725985.0,
#  725986.0,
#  725987.0,
#  725988.0,
#  725989.0,
#  725990.0,
#  725991.0,
#  726158.0,
#  726159.0,
#  726160.0,
#  726161.0,
#  726162.0,
#  726163.0,
#  726164.0,
#  726165.0,
#  726166.0,
#  726167.0,
#  726168.0,
#  726169.0,
#  726170.0,
#  726171.0,
#  726172.0,
#  726173.0,
#  726174.0,
#  726175.0,
#  726358.0,
#  726359.0,
#  726360.0,
#  726361.0,
#  726362.0,
#  726363.0,
#  726364.0,
#  726365.0,
#  726366.0,
#  726367.0,
#  726368.0,
#  726556.0,
#  726557.0,
#  726558.0,
#  726559.0,
#  726560.0,
#  726561.0,
#  726562.0,
#  726563.0,
#  726564.0,
#  726565.0,
#  726566.0,
#  726567.0,
#  726747.0,
#  726748.0,
#  726749.0,
#  726750.0,
#  726751.0,
#  726752.0,
#  726753.0,
#  726754.0,
#  726909.0,
#  726918.0,
#  726919.0,
#  726920.0,
#  726921.0,
#  726922.0,
#  726923.0,
#  726924.0,
#  726925.0,
#  726926.0,
#  726927.0,
#  726928.0,
#  726929.0,
#  726930.0,
#  726931.0,
#  726932.0,
#  726933.0,
#  726934.0,
#  726935.0,
#  727099.0,
#  727100.0,
#  727101.0,
#  727102.0,
#  727103.0,
#  727104.0,
#  727105.0,
#  727106.0,
#  727107.0,
#  727108.0,
#  727109.0,
#  727137.0,
#  727154.0,
#  727276.0,
#  727277.0,
#  727338.0,
#  727339.0,
#  727340.0,
#  727341.0,
#  727342.0,
#  727343.0,
#  727344.0,
#  727345.0,
#  727346.0,
#  727347.0,
#  727348.0,
#  727349.0,
#  727350.0,
#  727470.0,
#  727530.0,
#  727531.0,
#  727532.0,
#  727534.0,
#  727535.0,
#  727536.0,
#  727537.0,
#  727538.0,
#  727539.0,
#  727540.0,
#  727541.0,
#  727469.0,
#  727657.0,
#  727658.0,
#  727659.0,
#  727660.0,
#  727719.0,
#  727720.0,
#  727721.0,
#  727722.0,
#  727723.0,
#  727724.0,
#  727725.0,
#  727727.0,
#  727728.0,
#  727729.0,
#  727857.0,
#  727858.0,
#  727920.0,
#  727921.0,
#  727922.0,
#  727923.0,
#  727924.0,
#  727927.0,
#  728031.0,
#  728091.0,
#  728092.0,
#  728094.0,
#  728095.0,
#  728096.0,
#  728097.0,
#  728099.0,
#  728100.0,
#  728101.0,
#  728102.0,
#  728103.0,
#  728104.0,
#  728106.0,
#  728107.0,
#  728225.0,
#  728226.0,
#  728281.0,
#  728282.0,
#  728283.0,
#  728284.0,
#  728285.0,
#  728286.0,
#  728287.0,
#  728288.0,
#  728289.0,
#  728290.0,
#  728291.0,
#  728292.0,
#  728467.0,
#  728468.0,
#  728469.0,
#  728470.0,
#  728471.0,
#  728472.0,
#  728473.0,
#  728475.0,
#  728476.0,
#  728477.0,
#  728478.0,
#  728639.0,
#  728640.0,
#  728641.0,
#  728642.0,
#  728643.0,
#  728644.0,
#  728645.0,
#  728646.0,
#  728647.0,
#  728648.0,
#  728649.0,
#  728650.0,
#  728841.0,
#  728842.0,
#  728843.0,
#  728844.0,
#  728845.0,
#  728847.0,
#  728848.0,
#  728849.0,
#  728851.0,
#  728852.0,
#  728853.0,
#  729022.0,
#  729023.0,
#  729024.0,
#  729025.0,
#  729026.0,
#  729027.0,
#  729028.0,
#  729029.0,
#  729030.0,
#  729031.0,
#  729032.0,
#  729138.0,
#  729220.0,
#  729221.0,
#  729222.0,
#  729223.0,
#  729224.0,
#  729225.0,
#  729226.0,
#  729352.0,
#  729353.0,
#  729411.0,
#  729412.0,
#  729413.0,
#  729415.0,
#  729416.0,
#  729417.0,
#  729418.0,
#  729539.0,
#  729540.0,
#  729623.0,
#  729625.0,
#  729626.0,
#  729627.0,
#  729628.0,
#  729629.0,
#  729630.0,
#  729631.0,
#  729632.0,
#  729633.0,
#  729634.0,
#  729635.0,
#  729636.0,
#  729637.0,
#  729793.0,
#  729794.0,
#  729795.0,
#  729796.0,
#  729797.0,
#  729798.0,
#  729799.0,
#  729800.0,
#  729801.0,
#  729802.0,
#  729803.0,
#  729804.0,
#  729805.0,
#  729902.0,
#  729904.0,
#  729905.0,
#  729906.0,
#  729972.0,
#  729973.0,
#  729974.0,
#  729975.0,
#  729976.0,
#  729977.0,
#  729978.0,
#  729979.0,
#  729980.0,
#  729981.0,
#  729982.0,
#  730064.0,
#  730065.0,
#  730137.0,
#  730138.0,
#  730139.0,
#  730140.0,
#  730141.0,
#  730142.0,
#  730143.0,
#  730144.0,
#  730145.0,
#  730146.0,
#  730147.0,
#  729732.0,
#  730230.0,
#  730315.0,
#  730316.0,
#  730317.0,
#  730318.0,
#  730319.0,
#  730320.0,
#  730321.0,
#  730322.0,
#  730323.0,
#  730324.0,
#  730325.0,
#  730326.0,
#  730327.0,
#  730328.0,
#  730329.0,
#  730496.0,
#  730497.0,
#  730498.0,
#  730499.0,
#  730500.0,
#  730501.0,
#  730502.0,
#  730503.0,
#  730504.0,
#  730505.0,
#  730620.0,
#  730681.0,
#  730682.0,
#  730683.0,
#  730684.0,
#  730685.0,
#  730686.0,
#  730687.0,
#  730688.0,
#  730689.0,
#  730690.0,
#  730691.0,
#  730692.0,
#  730693.0,
#  730694.0,
#  730858.0,
#  730859.0,
#  730860.0,
#  730861.0,
#  730862.0,
#  730863.0,
#  730864.0,
#  730865.0,
#  730866.0,
#  730867.0,
#  730990.0,
#  731066.0,
#  731067.0,
#  731068.0,
#  731069.0,
#  731070.0,
#  731071.0,
#  731072.0,
#  731073.0,
#  731075.0,
#  731076.0,
#  731077.0,
#  731078.0,
#  731079.0,
#  731112.0,
#  731271.0,
#  731272.0,
#  731273.0,
#  731274.0,
#  731275.0,
#  731276.0,
#  731277.0,
#  731278.0,
#  731279.0,
#  731280.0,
#  731282.0,
#  731283.0,
#  731284.0,
#  731285.0,
#  731286.0,
#  731364.0,
#  731365.0,
#  731440.0,
#  731441.0,
#  731442.0,
#  731443.0,
#  731444.0,
#  731445.0,
#  731446.0,
#  731447.0,
#  731448.0,
#  731449.0,
#  731450.0,
#  731451.0,
#  731540.0,
#  731608.0,
#  731609.0,
#  731610.0,
#  731611.0,
#  731612.0,
#  731614.0,
#  731615.0,
#  731616.0,
#  731617.0,
#  731670.0,
#  731799.0,
#  731800.0,
#  731801.0,
#  731802.0,
#  731804.0,
#  731805.0,
#  731806.0,
#  731807.0,
#  731809.0,
#  731810.0,
#  731926.0,
#  732021.0,
#  732022.0,
#  732023.0,
#  732025.0,
#  732026.0,
#  732027.0,
#  732028.0,
#  732029.0,
#  732030.0,
#  732031.0,
#  732032.0,
#  732033.0,
#  732034.0,
#  732020.0,
#  732076.0,
#  732147.0,
#  732223.0,
#  732225.0,
#  732226.0,
#  732227.0,
#  732229.0,
#  732231.0,
#  732232.0,
#  732233.0,
#  732235.0,
#  732347.0,
#  732348.0,
#  732423.0,
#  732424.0,
#  732426.0,
#  732427.0,
#  732428.0,
#  732429.0,
#  732544.0,
#  732615.0,
#  732616.0,
#  732617.0,
#  732618.0,
#  732619.0,
#  732620.0,
#  732621.0,
#  732623.0,
#  732624.0,
#  732625.0,
#  732612.0,
#  732728.0,
#  732729.0,
#  732730.0,
#  732731.0,
#  732732.0,
#  732735.0,
#  732802.0,
#  732805.0,
#  732808.0,
#  732901.0,
#  732903.0,
#  732974.0,
#  732975.0,
#  732976.0,
#  732977.0,
#  732978.0,
#  732979.0,
#  732980.0,
#  732981.0,
#  732982.0]

# %%
len(clumps)
# Out:
# 69
