# %%
import photutils as phot
from astropy.stats import sigma_clipped_stats
from astropy.table import Table
import numpy as np
import scipy.stats as stats
from scipy.interpolate import UnivariateSpline
import pylab as plt
from astropy.visualization import simple_norm
from astropy.io import fits

# %%
def FitsRead(time):
    # Read the fits file for that time and return table of stars
    if time < 10:
        time = '0{0}'.format(time)
    try:
        fileName = 'coords.starsandgas.chemrun733DiffFB10T1.0.00{0}0.fits'.format(time)
        read = Table.read(fileName,1)
        stars = (read['P']=='s')
        cat = read[stars]
    except:
        try:
            fileName = 'coords.chem733DiffFB10T1.0.00{0}0.fits'.format(time)
            cat = Table.read(fileName,1)
        except:
            raise ValueError('No file')
    return cat

# %%
def RotateBack(x,y,dtime,vcirc):
    # Rotate stars back in time
    lindist = vcirc*dtime #linear distance traveled in time interval
    rho = (x**2+y**2)**(1/2) #distance from z axis
    nrot = lindist/(2*np.pi*rho) #number of rotations
    nrotints = []
    for i in nrot:
        nrotints.append(int(i))
    nrotints = np.array(nrotints) #integer number of rotations
    rotangle = nrot-nrotints #partial rotation
    rotanglerad = 2*np.pi*rotangle #convert to radians
    xrot = x*np.cos(-rotanglerad)-y*np.sin(-rotanglerad) #x position at beginning of interval
    yrot = x*np.sin(-rotanglerad)+y*np.cos(-rotanglerad) #y position at beginning of interval
    return xrot,yrot

# %%
def make_unique(original_list):
    # Takes a list and returns it without duplicate entries
    unique_list = []
    [unique_list.append(obj) for obj in original_list if obj not in unique_list]
    return unique_list

# %%
def StarsInInterval(starlist,start,end):
    # Returns table of stars that formed within time interval
    tRange = (starlist['TFORM']>start,starlist['TFORM']<end)
    inRange = np.array(np.zeros(len(tRange[0])),dtype=bool) 
    for i in range(0,len(inRange)):
        if tRange[0][i] and tRange[1][i]:
            inRange[i] = True            #true for stars that formed in time interval
    newStars = starlist[inRange]
    return newStars

# %%
def FindPeaks(data,z):
    # Find peaks in 2D array of data
    statsdata = [] #only includes data points with density greater than 1 to calculate threshold
    for i in data:
        for j in i:
            if j>2:
                statsdata.append(j)
    mean, median, std = sigma_clipped_stats(statsdata, sigma=3.0)
    threshold = median + (z * std) #minimum density for a peak
    tbl = phot.find_peaks(data, threshold, box_size=11) #table of x index, y index, and density for peaks
    tbl['peak_value'].info.format = '%.8g'
    return tbl

# %%
def CombineClose(positions):
    # Combine multiple peaks in the same star cluster
    peaks = []
    closelist = []
    for i in range(0,len(positions[0])):
        jlist = [i] #a list containing that peak and other peaks near it
        for j in range(i+1,len(positions[0])):
            xi = positions[0][i]
            yi = positions[1][i]
            xj = positions[0][j]
            yj = positions[1][j]
            dist2 = (xi-xj)**2+(yi-yj)**2
            if dist2<0.1:
                jlist.append(j)
        closelist.append(jlist) #a list where each element is a list of nearby peaks
    for i in range(0,len(closelist)):
        if len(closelist[i])>1:
            for j in closelist[i]:
                if i==j:
                    continue
                closelist[j] = closelist[0]
    closelist = make_unique(closelist) #remove elements of closelist that contain the same peaks
    for i in closelist:
        sumx = 0
        sumy = 0
        for j in i:
            sumx = sumx+positions[0][j]
            sumy = sumy+positions[1][j]
        meanx = sumx/len(i) #mean x position of a close group of peaks
        meany = sumy/len(i) #mean y position of a close group of peaks
        peaks.append([meanx,meany])
    xcoords = []
    ycoords = []
    for peak in peaks:
        xcoords.append(peak[0])
        ycoords.append(peak[1])
    xcoords = np.array(xcoords) #array of peak x coordinates
    ycoords = np.array(ycoords) #array of peak y coordinates
    peaks1 = (xcoords,ycoords)
    return peaks1

# %%
def MeanPeaks(starlist,positions):
    # Make the x and y positions of the clumps equal to the mean x and y positions of the stars, rather than peak location
    x = []
    y = []
    for i in range(0,len(positions[0])):
        inclump = ((starlist['XROT']-positions[0][i])**2+(starlist['YROT']-positions[1][i])**2<0.09) #true for stars within
                                                                                                     #aperture
        clump = starlist[inclump] #only includes stars in clump
        x.append(np.mean(clump['XROT']))
        y.append(np.mean(clump['YROT']))
    x = np.array(x) #array of mean x coordinates of clump
    y = np.array(y) #array of mean y coordinates of clump
    meanPositions = (x,y)
    return x,y,meanPositions

# %%
def TrackClumps(oldClumps,xcoords,ycoords,stars):
    # Match clumps in current timestep to clumps in previous timesteps
    leftx = xcoords
    lefty = ycoords
    lefti = []
    clumps = oldClumps
    for i in range(0,len(leftx)):
        lefti.append(i)
    if len(clumps)>0:
        for skip in range(1,6): #run through the previous 5 timesteps
            clumpsrho = (leftx**2+lefty**2)**(1/2)
            clumpsvcirc = vDisk(clumpsrho)
            cxrot,cyrot = RotateBack(leftx,lefty,skip*dt,clumpsvcirc) #move clumps back in time
            xleft = []
            yleft = []
            ileft = []
            for i in range(0,len(cxrot)): #run through clumps in current timestep
                for clump in clumps: #run through clumps from previous timesteps
                    newest = clump[len(clump)-1] #[time,x,y] of the most recent location of the clump
                    if newest[0]==round(start-skip*dt,3): #only look at clumps that were found recently
                        xi = cxrot[i]
                        yi = cyrot[i]
                        xj = newest[1]
                        yj = newest[2]
                        if (xi-xj)**2+(yi-yj)**2<0.36 and clumpsrho[i]>0.3:
                            inclump = ((stars['XROT']-leftx[i])**2+(stars['YROT']-lefty[i])**2<0.09)
                            clumpStars = stars[inclump] #only includes stars in clump
                            clump.append([start,xcoords[lefti[i]],ycoords[lefti[i]]])
                            clump[0] = clump[0]+list(clumpStars['INDEX'])
                            clump[0] = make_unique(clump[1])
                            break
                    if clump==clumps[len(clumps)-1]: #make a list of clumps that do not match clumps seen earlier
                        xleft.append(leftx[i])
                        yleft.append(lefty[i])
                        ileft.append(lefti[i])
            leftx = np.array(xleft)
            lefty = np.array(yleft)
            lefti = ileft
    for i in range(0,len(lefti)): #add clumps that don't match older ones to the end of the list
        if leftx[i]**2+lefty[i]**2>0.09:
            inclump = ((stars['XROT']-leftx[i])**2+(stars['YROT']-lefty[i])**2<0.09)
            clumpStars = stars[inclump] #only includes stars in clump        
            clumps.append([list(clumpStars['INDEX']),[start,xcoords[lefti[i]],ycoords[lefti[i]]]])
    return clumps

# %%
# Read txyz file
txyz = Table.read('txyzform.fits',1)
index = np.linspace(0,len(txyz)-1,len(txyz))
txyz.add_column(Table.Column(index),name='INDEX')
rho = np.sqrt(txyz['XFORM']**2+txyz['YFORM']**2)
txyz.add_column(rho,name='RHO')
start = 1.5
dt = 0.001
clumps = []
oldClumps = []

for refTime in range(15,41):
    print('refTime = {}'.format(refTime))
    # Read snapshot file
    snapshot = FitsRead(refTime)
    r = np.sqrt(snapshot['X']**2+snapshot['Y']**2)
    theta = np.arctan2(snapshot['Y'],snapshot['X'])
    vth = -snapshot['VX']*np.sin(theta)+snapshot['VY']*np.cos(theta)
    snapshot.add_column(r,name='R')
    snapshot.add_column(vth,name='VTH')

    # Interpolate vDisk as a function of rho
    bins = int(np.max(r)/2.5)
    medians,binEdges,binNumber = stats.binned_statistic(r,vth,'median',bins)
    edges = []
    for i in range(0,len(binEdges)-1):
        edges.append((binEdges[i]+binEdges[i+1])/2)
    w = np.isnan(medians)
    medians[w] = 0
    vDisk = UnivariateSpline(edges,medians,~w)

    while round(start*10)==refTime and start<4:
        #Find stars that formed in time interval
        end = start+5*dt
        newStars = StarsInInterval(txyz,start,end)
        outOfCenter = (newStars['RHO'] > 0.15)
        newStars = newStars[outOfCenter]

        # Move stars back in time to beginning of interval
        vcirc = vDisk(newStars['RHO'])
        dtime = newStars['TFORM']-start
        xrot,yrot = RotateBack(newStars['XFORM'],newStars['YFORM'],dtime,vcirc)
        newStars.add_column(xrot,name='XROT')
        newStars.add_column(yrot,name='YROT')
        im, xedges, yedges  = np.histogram2d (-yrot,xrot,(40,40))
        dx = xedges[1]-xedges[0]
        dy = yedges[1]-yedges[0]
        extent = [yedges[0], yedges[-1], -xedges[-1], -xedges[0]]

        # Find peaks in density
        tbl = FindPeaks(im,2)
        
        if len(tbl)>0:
            # Combine clumps in the same place
            peakPositions = (yedges[tbl['x_peak']]+dy/2, -xedges[tbl['y_peak']]-dx/2)
            peaks = CombineClose(peakPositions)

            # Make clump positions the mean x and y of stars in the clump
            xcoords,ycoords,positions = MeanPeaks(newStars,peaks)
            xcoords,ycoords,positions = MeanPeaks(newStars,positions)

            # Track clumps through time
            clumps = TrackClumps(clumps,xcoords,ycoords,newStars)

            # Plot density plots with clumps
            #apertures = phot.CircularAperture(peaks, r=0.3)
            #norm = simple_norm(im, 'sqrt', percent=99.9)
            #plt.figure(figsize=(10,10))
            #plt.imshow(im, cmap='Greys_r', norm=norm, extent=extent)
            #apertures.plot(color='#0547f9', lw=1.5)
            #plt.title("{0} million years".format(int(start*1000)))

        start = round(start+dt,3)
    newClumps = []
    for clump in clumps:
        if clump[len(clump)-1][0]>start-5*dt:
            newClumps.append(clump)
        else:
            oldClumps.append(clump)
    clumps = newClumps
clumps = oldClumps+newClumps
for id in range(0,len(clumps)):
    clumps[id] = [id+1]+clumps[id]
print('{0} clumps total'.format(len(clumps)))
# Out:
# refTime = 15
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 16
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 17
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 18
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 19
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 20
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 21
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 22
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 23
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 24
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 25
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 26
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 27
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 28
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 29
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 30
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 31
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 32
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 33
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 34
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 35
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 36
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 37
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 38
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 39
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# WARNING: No local peaks were found. [photutils.detection.core]
# refTime = 40
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# 2618 clumps total

# %%
#Plot locations of clumps through time
plt.figure(figsize=(10,10))
for clump in clumps:
    x = []
    y = []
    for j in range(2,len(clump)):
        x.append(clump[j][1])
        y.append(clump[j][2])
    plt.plot(x,y)
    #plt.scatter(x,y)
plt.imshow(im, cmap='Greys_r', extent=extent)

# %%
tList = []
xList = []
yList = []
idList1 = []
iList = []
idList2 = []
for clump in clumps:
    for j in range(2,len(clump)):
        txy = clump[j]
        tList.append(txy[0])
        xList.append(txy[1])
        yList.append(txy[2])
        idList1.append(clump[0])
    for star in clump[1]:
        iList.append(star)
        idList2.append(clump[0])

hdu1 = fits.PrimaryHDU()
        
idcol1 = fits.Column(name="CLUMPID", format='J', array=idList1)
tcol = fits.Column(name="TIME", format='E', array=tList)
xcol = fits.Column(name="X", format='E', array=xList)
ycol = fits.Column(name="Y", format='E', array=yList)
hdu2 = fits.BinTableHDU.from_columns([idcol1,tcol,xcol,ycol])

idcol2 = fits.Column(name="CLUMPID", format='J', array=idList2)
icol = fits.Column(name="INDEX", format='J', array=iList)
hdu3 = fits.BinTableHDU.from_columns([idcol2,icol])

hdul = fits.HDUList([hdu1,hdu2,hdu3])
hdul.writeto('clumps3.fits')

# %%
fits.info('clumps3.fits')
# Out:
# Filename: clumps3.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1                1 BinTableHDU     16   15470R x 4C   [J, E, E, E]
#   2                1 BinTableHDU     12   17442R x 2C   [J, J]

# %%
# Print x and y locations of clumps (only the ones that are tracked for at least 10 steps)
for clump in clumps:
    if len(clump) > 11:
        t = Table(names=('TIME','X','Y'))
        for j in range(2,len(clump)):
            t.add_row((clump[j][0],clump[j][1],clump[j][2]))
        print('Clump {0}'.format(clump[0]))
        print(t)
        print()
# Out:
# Clump 1
#  TIME          X                   Y
# ----- ------------------- --------------------
# 1.501 -3.1865265961226794    3.991874438161208
# 1.502 -3.2816341166611043    3.907128928064019
# 1.504 -3.5535038818434828    3.638099876361473
# 1.505  -3.621849931352921    3.586494675902591
# 1.506 -3.8050485437280175   3.3850267576725757
# 1.507 -3.9733031068508797    3.263849861716759
# 1.508  -4.003804445977954   3.2429024671167506
# 1.509  -4.166317416160814   2.7462334607945866
#  1.51  -4.359975338450126    2.766391513013312
# 1.511  -4.249359364812089   2.4936857531993355
#   ...                 ...                  ...
# 1.524  -5.193821496828493   0.3070306159797112
# 1.525 -5.2020776949522824  0.13055038422981838
# 1.526  -5.148516409788119 -0.16054863943577888
# 1.527  -5.134248293268764 -0.30099046545338903
# 1.528  -5.131697670978414 -0.44498496476087374
# 1.529  -4.735379316163743 -0.46260087392116106
# 1.532  -5.003242842665992  -1.2782763276867835
# 1.533 -4.9697028241270065  -1.4029419179362763
# 1.534 -4.4390585845353145  -1.2644094208713246
# 1.535 -4.3638582312200285  -1.5288867902884393
# 1.536  -4.308462352181598  -1.5967264357509525
# Length = 30 rows
#
# Clump 21
#  TIME          X                   Y
# ----- ------------------- --------------------
#   1.5   4.888029805357634  -1.3012384136028534
# 1.501  4.9298466790194135  -1.1358579951831498
# 1.502   4.967175427693803  -0.9955645273305751
# 1.504    5.05131698362776    -0.68580212064854
# 1.505   5.090938717652863  -0.4184796193099679
# 1.506   5.110682773452638 -0.33489280694066853
# 1.507   5.123987938326801 -0.12469766316609313
# 1.508   5.125771073075967  0.02173435975092593
# 1.509   5.128224696891044  0.25696730686717206
#  1.51   5.136606905480524  0.43609179156196415
#   ...                 ...                  ...
# 1.585  -4.420867795060049   1.4457316990179134
# 1.586 -4.4894100597467395   1.2629998042777395
# 1.587 -4.5457256939133615   1.0931373458082825
# 1.589  -4.632347490928667   0.7449597913160796
#  1.59 -4.6519199674186265   0.5514384101389481
# 1.591  -4.672967486739498   0.3780130869025664
# 1.592  -4.683181513472218  0.19616408438998567
# 1.593  -5.160221792188409  0.38708362482303255
# 1.596  -5.211882561303068  -0.2729429379654874
# 1.599  -5.184593261816862  -0.9191020044043051
#   1.6  -5.164390808100178   -1.084599341126663
# Length = 82 rows
#
# Clump 26
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.594  -4.672234918915207 -0.1687998926630971
# 1.595  -4.648374269336904 -0.3676935165445868
# 1.597  -4.576625807420155 -0.7280886840576061
# 1.598 -4.5403077887316385 -0.8931551090511868
# 1.601  -4.385285728615444  -1.415394499191849
# 1.602  -4.307387007240846 -1.5946148700997267
# 1.603 -4.2474624241857075 -1.7440095097795518
# 1.604  -4.169900179610609  -1.892086176955717
# 1.605 -4.0976050546462295  -2.055724057359432
# 1.607 -3.9175719237622024 -2.3801469684964234
# 1.608 -3.8161502022854634   -2.53265116945705
#  1.61  -3.583106500216246   -2.83011601812221
# 1.612 -3.3400483574177673 -3.1366005625084528
# 1.614  -3.058848240215995  -3.384827904918345
# 1.616   -2.76238228379006 -3.6166059383825986
# 1.618 -2.4772043624266398 -3.8123881271237847
# 1.619 -2.2851761151598184 -3.9167979707132794
# 1.621 -1.9873773264754926 -4.0823111346022944
# 1.623  -1.667966976165594   -4.20892480158044
# 1.624  -1.491267848969163  -4.262586524642939
# 1.625 -1.3311558749503887 -4.3177707622563615
# 1.626 -1.1635558739320417 -4.3490497421224745
# 1.629 -0.6219568103016478 -4.4315937127324405
#
# Clump 28
#  TIME         X                   Y
# ----- ------------------ --------------------
#  1.61 0.2315604044917059  -3.6612687921539595
# 1.611 0.4141620093275597   -3.622030088554954
# 1.612 0.6052026418497511  -3.5637023161838117
# 1.613 0.7732372476005491  -3.5259555897672628
# 1.614 0.9550861729687967   -3.459490427048842
# 1.615 1.1223934474372055  -3.3923514900508898
# 1.616 1.3002812370062815   -3.301650798289137
# 1.617  1.476140055671495   -3.183787659247172
# 1.618 1.6207505499470887  -3.0974996205946317
# 1.619 1.7722221680950543  -2.9978654789949335
#   ...                ...                  ...
# 1.632 3.0730085348141154  -0.9028527481353706
# 1.633 3.1169905422093693  -0.7119793524545144
# 1.634 3.1431280573846982  -0.5074455884784385
# 1.635  3.165704563384371  -0.2911735610766669
# 1.636 3.1730819106284347 -0.12829899639146955
# 1.637 3.1712800943558426  0.06018328157771867
# 1.638 3.1519036061767816  0.24943355558775138
# 1.639 3.1220001830215143   0.4648290326010829
#  1.64  3.076680911218286   0.6804131191537165
# 1.641  3.033798731192343   0.8656948736388627
# 1.643 2.9091216550469783    1.206297353795117
# Length = 33 rows
#
# Clump 33
#  TIME          X                   Y
# ----- ------------------- -------------------
#   1.5 -3.8325034663434114  -2.261198737982124
# 1.501 -3.7509953976553603 -2.4010690202439644
# 1.502  -3.650569834405383    -2.5587114923308
# 1.503 -3.5537974509073256  -2.694399455833148
# 1.504  -3.446904134226015  -2.852370447381483
# 1.505 -3.3193389556188384  -3.014067639225646
# 1.506 -3.2065872172304988 -3.1378315319457593
# 1.507  -3.059509881600355 -3.2844293341655995
# 1.508  -2.929381173624958  -3.411993605361357
# 1.509  -2.788791952623082   -3.53706381330977
#   ...                 ...                 ...
# 1.695   4.096837639060034   -3.10521568791797
# 1.696  4.2186832510655465  -2.941970071728191
# 1.697   4.313244233196048 -2.7708231017336757
# 1.698   4.400208640535947 -2.6309492257585916
# 1.699   4.486171924235998 -2.4532763656871475
#   1.7   4.559937958166731 -2.2934724393867723
# 1.701  4.6212980197108084 -2.1227278718967417
# 1.702   4.675734054155474 -1.9337522863319425
# 1.703  4.7220453075868685 -1.7752945395055444
# 1.704   4.753810333808576 -1.5899344798463133
# 1.705   4.790936978284019  -1.426190314232467
# Length = 206 rows
#
# Clump 34
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.537  -4.677760057903213 -2.1602413981470723
# 1.538 -4.6621498770589715 -2.2688104322301204
# 1.539  -4.549246351964853  -2.410946549183966
#  1.54  -4.449752135509956  -2.527269353465955
# 1.541   -4.40386432472262 -2.6239998560918694
# 1.542  -4.188160475832832  -2.842578602578428
# 1.543   -4.00620001233538 -2.9358384311747168
# 1.545  -3.466619540976526  -3.182592031530844
# 1.546  -3.648145823922261  -3.369938553290679
# 1.547 -3.4634395444240504 -3.4376853528588924
#   ...                 ...                 ...
#  1.64  1.9139741186672634   4.591312524965153
# 1.641   1.759201543066913   4.628775737601634
# 1.642  1.5755996124061915   4.680997133996438
# 1.643  1.4206548564021142   4.722298211586532
# 1.644   1.222581890754774   4.750946563038571
# 1.645  1.0364553936625336   4.775338999867851
# 1.646  0.8796347545636166   4.792920069111033
# 1.647  0.6808069231967252   4.787071450687719
# 1.648  0.5116451560904055   4.795312868570067
# 1.649  0.3219307798531561   4.783096868975544
#  1.65 0.13339332754770955   4.763333738690679
# Length = 112 rows
#
# Clump 35
#  TIME          X                    Y
# ----- -------------------- -------------------
# 1.579  0.17637990123134809   4.822299699684255
# 1.581   0.4438167548082753   4.633917381888614
# 1.582  0.24573369827297656   4.646800489445727
# 1.585 -0.28110692392798176   4.673744522558413
# 1.586  -0.5195819851277029    4.73607089110812
# 1.587  -0.6777390717602211   4.713099632620902
# 1.588  -0.8368532827431976   4.711403347476975
# 1.589   -1.005122587554393   4.686836614904791
#  1.59  -1.1508740752253852   4.646077386815037
# 1.591  -1.3677333931803868   4.643927392238497
#   ...                  ...                 ...
# 1.635   -3.180395249322615  -2.201280855747688
# 1.636   -3.105387247930926 -2.3316395894881694
# 1.637  -2.8770654106427456  -2.421122184551224
# 1.638    -2.75421118765797 -2.5679629082153905
# 1.639  -2.5852903619666034  -2.690343895144321
#  1.64   -2.522152990242524  -2.780764068143828
# 1.641  -2.6861157208827247 -2.9326541174767002
# 1.642  -2.2057902154241753 -3.0527311859201114
# 1.646  -1.4685135068866721  -3.348445420973456
# 1.647  -1.2682092791390034 -3.4149995096361003
# 1.648  -1.0132539361250357  -3.463801506407228
# Length = 56 rows
#
# Clump 37
#  TIME         X                   Y
# ----- ------------------ -------------------
# 1.654 0.2472689735974599 -3.5334036203203976
# 1.655 0.2108359946994661 -3.5628856535430846
# 1.658 0.7176166261492029  -3.443617683762162
# 1.662 1.4174715009686747  -3.214684329001223
# 1.663  1.604295177544211 -3.1553547506378385
# 1.664 1.7666082956268974 -3.0765687476452483
# 1.665 1.9545120349830944 -2.9898048974910405
# 1.666 2.0659670505716377 -2.8762886996626067
# 1.667 2.1888790725512473 -2.7865669333931993
#  1.67  2.615543864886511 -2.4214357831819915
# 1.672 2.8322804491002977 -2.2067564556212766
# 1.674 3.0511650413982467 -1.9048457670692776
# Clump 58
#  TIME           X                    Y
# ----- --------------------- --------------------
#   1.5    0.7050107756157383    5.070047278307145
# 1.501    0.5067010709321027    5.103552297083217
# 1.502    0.3336142640494322    5.158006718813074
# 1.503   0.17112065758286926    5.165138240538078
# 1.504 -0.033522624072171395    5.174377248688249
# 1.505  -0.21860373154288235   5.1844931902032165
# 1.506  -0.39377943417332256    5.179988220342584
# 1.507    -0.594826918839607    5.175237146634788
# 1.508   -0.7448186805617277    5.147476387198657
# 1.509   -0.9719052089853151     5.10027457779647
#   ...                   ...                  ...
# 1.764  -0.37333095713685077    2.245377142032409
# 1.765   -0.5607424469531664    2.186111830998307
# 1.766   -0.7174855100773982    2.126899655058537
# 1.767   -0.8940174402633759    2.048043496371099
# 1.768   -1.0488104483018814   1.9672847925114243
# 1.769   -1.2207645271708358   1.8594800441060741
#  1.77   -1.3821002449069781    1.724524284278062
# 1.772   -1.6441214449400794   1.4625363641115499
# 1.773   -1.7517944228440459   1.3272887158043751
# 1.776   -2.0729437189272946   0.8554915164403284
# 1.781   -2.4024794137843255 -0.02868081667080743
# Length = 269 rows
#
# Clump 59
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.501   1.154013213845153  -4.318862074310282
# 1.502  1.3513969557375862  -4.247646827587965
# 1.503   1.512114173661068 -4.2008547781999255
# 1.504  1.6745952249290197  -4.157006081571989
# 1.505    1.85903283909932  -4.110499631060274
# 1.506  1.9785605452059727  -4.046092560295122
# 1.507   2.137145249375543 -3.9388687182098154
# 1.508   2.278271912410976 -3.8474460682869887
# 1.509   2.432639472320041 -3.7202809498074942
#  1.51  2.5532465963849504 -3.6277091593935893
#   ...                 ...                 ...
# 1.778  -3.060100779292556 -2.2989014148291003
# 1.779  -2.944076331386716 -2.4170682981091525
#  1.78  -2.814054262768957  -2.534430393014353
# 1.781  -2.690976592559565 -2.6419150237302897
# 1.782 -2.5590907451394145 -2.7529799650988673
# 1.783  -2.427546957506602  -2.856059115674722
# 1.784 -2.2693945712767154   -2.96625397753154
# 1.785  -2.121305276460982  -3.059676550470539
# 1.786 -1.9901361124975254 -3.1301733991886507
# 1.787 -1.8352956132322977  -3.202562324887184
# 1.788 -1.6774718460249696 -3.2743784405241882
# Length = 270 rows
#
# Clump 60
#  TIME          X                    Y
# ----- -------------------- -------------------
# 1.728 0.014353942764954164  -4.255305351356327
# 1.732   0.7439300081219677  -3.921454885147975
# 1.733   0.8987659888471469 -3.8906044895710905
# 1.735   1.2281505131123056  -3.748482023216024
# 1.736   1.4043203700530427 -3.6960444039492018
# 1.737    1.561099892991708 -3.5667196743319485
# 1.738   1.6864383651480153 -3.4727858029940695
# 1.739     1.81070156654766  -3.343689052906289
# 1.741    2.073174537078715  -3.111179668688227
# 1.742    2.217250753784247 -2.9738296905393335
#   ...                  ...                 ...
# 1.768    2.086181261976065  1.7883534203273714
# 1.769    1.923478568542337  1.9079636806689417
#  1.77   1.7302013178763551    2.03393120798099
# 1.771   1.5678147912590867  2.1297541393555233
# 1.772   1.3328737745078834    2.21851804769483
# 1.773   1.1720581481505945   2.299460255402117
# 1.774   0.9546499582693272  2.3592837628708296
# 1.775   0.7253303142695202  2.4326825472682323
# 1.776   0.5542037689427574  2.4539902475998288
# 1.777   0.3289075979623242  2.5161989308133763
# 1.778  0.13994099478287098   2.522022701388964
# Length = 44 rows
#
# Clump 61
#  TIME         X                   Y
# ----- ------------------ --------------------
# 1.735  4.420966019525627   -3.129351636087556
# 1.736   4.47280667969876  -2.8752843145233826
# 1.737  4.585319282118768  -2.8684856577643503
# 1.738  4.630202498091027   -2.521519353545132
# 1.739 4.6760105865391335  -2.8333855497929665
#  1.74  4.775323061281835  -2.2803163247256846
# 1.741  4.869956563108803   -1.983755484904568
# 1.742  4.880476352299411  -1.6086551820179322
# 1.743 4.9585562899615026   -1.613095619815638
# 1.744  4.930966163108815   -1.204496118737923
#   ...                ...                  ...
# 1.748  5.030807991667112  -0.4567979505486873
# 1.749 5.0632224870922355   -0.236918562168891
#  1.75  5.060510053986763 -0.09394609392609204
# 1.751  5.032218137638031  0.09334639849758565
# 1.752 5.0309091860493975  0.26812430262815634
# 1.753  4.987418214395007  0.46473856930254387
# 1.754  4.941848644263911   0.6818304763650749
# 1.755  4.865838473665512   0.9180575477763034
#  1.76  4.546592442290704    1.834911546123796
# 1.761  4.455191360215305   2.0135644928368404
# 1.764  4.120702812668265   2.5393635796612988
# Length = 24 rows
#
# Clump 65
#  TIME           X                    Y
# ----- --------------------- --------------------
# 1.752   0.04097644011158457  -0.2975851295664083
# 1.754    0.0650643787944731  -0.3020541560532953
# 1.755    0.0810796131227246  -0.3068404125517391
# 1.756   0.11026636845824965 -0.29410451455023806
# 1.757   0.11183996678521313 -0.30334022882008355
# 1.758    0.2696397493888819  -0.2305926016926649
# 1.759   0.14166461790371918  -0.3253092872974622
#  1.76    0.1609032167692223  -0.3281497788394884
# 1.761   0.21420227481185722 -0.29964817413356937
# 1.762   0.21850547362683886  -0.3074560032345307
#   ...                   ...                  ...
# 1.809   0.09255056005216276   0.5200738676341382
#  1.81 -0.004704578253518372   0.5270945708642469
# 1.811  -0.11663189971441894   0.5332652774721588
# 1.812  -0.08054710836882178    0.542813221260809
# 1.813  -0.13196285693452292   0.5401288850485403
# 1.814  -0.21332327799354217   0.5228115094243112
# 1.815   -0.2539769405879289   0.4817412329777687
# 1.816  -0.23436726890074694  0.47762113577800913
# 1.817   -0.2299349774412596   0.4811019300543744
# 1.818   -0.2523109884570673  0.47040253292160467
# 1.819  -0.23213646066045604   0.4710674789158183
# Length = 67 rows
#
# Clump 77
#  TIME          X                   Y
# ----- ------------------- --------------------
# 1.784 -1.0135503973236535   2.1197669282286693
# 1.787 -1.4989349653326438   1.7502064203130805
# 1.788 -1.6232046353746643   1.6370256482607572
# 1.789 -1.7918181425031872   1.4606987207678885
#  1.79 -1.8845898192447101   1.3028468512361993
# 1.791 -1.9770037147782142   1.1454452599888676
# 1.793 -2.0783109572530387   0.7662386449665883
# 1.794 -2.1217805568489974   0.5751871822307553
# 1.795 -2.0779115466245996   0.3939677968169936
# 1.796 -2.1354807500165323   0.1779596873786159
# 1.798  -2.087321542807681 -0.13763525541416857
# 1.801 -1.9612305891108575   -0.700032546796605
# 1.802 -1.9146646376086869  -0.8574910149058028
#
# Clump 78
#  TIME         X                   Y
# ----- ------------------ --------------------
# 1.785 5.3723325079821596  -2.1347453009157227
# 1.786  5.421266931598356  -1.9921058810101968
# 1.789 5.5706047980035915   -1.072901916686743
#  1.79   5.58355508189551  -0.9968793262549982
# 1.791  5.462740371697929  -1.0132180622571545
# 1.793  5.644961435676243  -0.3538728300250932
# 1.794 5.6722263636884165  -0.1640508795137915
# 1.796 5.4979500107578385 -0.12752797825854342
# 1.797  5.492923109356698  0.08301316072113578
# 1.798  5.484873367572287  0.19553102376708947
#   ...                ...                  ...
# 1.812  4.434353970669492    2.832882964027632
# 1.814  4.197289655476906   3.1053333148429876
# 1.815    4.1056291904586   3.2275255358214294
# 1.816  3.901981974643542   3.3604383349560867
# 1.817 3.8120092180432272    3.459338120263662
# 1.819  3.357772293623843   3.6554451464509157
#  1.82 3.1016436331583717    3.691489743078512
# 1.821  2.937229730867017   3.8274114531015058
# 1.822 2.7276254112614304   3.8835286454443345
# 1.823 2.6504976854620073   3.9808265819240765
# 1.824 2.4666226490838286    4.021954702929808
# Length = 31 rows
#
# Clump 89
#  TIME          X                    Y
# ----- ------------------- ---------------------
# 1.799  -4.534180718525894    1.7287867222086428
#   1.8  -4.625446267322791    1.4870823244786555
# 1.802   -4.74379090099306    1.1219137517906623
# 1.803    -4.7755775891211    0.9444688184979853
# 1.805  -4.807406922554005    0.5635794443186932
# 1.806  -4.534856290599549 -0.022760388753838772
# 1.807  -4.788657459423119   0.17384774499001918
# 1.808  -4.762848217550294  -0.05890545860054475
# 1.809   -4.77606320923869  -0.22603528211683493
#  1.81  -4.764277062226645   -0.4155394486139097
#   ...                 ...                   ...
# 1.826 -3.3584405651634417   -3.0510896202416333
# 1.827 -3.2030384724940446    -3.186763303619955
# 1.828 -3.0662053973126175   -3.2932097238906253
# 1.829  -2.918513825550963   -3.3938854179478626
#  1.83 -2.7960522337225577    -3.495996827126228
# 1.831  -2.575078030014148    -3.558543133436371
# 1.833 -2.2166017652248287    -3.687842689040008
# 1.834 -2.0069611676277437   -3.7363244601385968
# 1.835 -1.8524229407718136   -3.7724434204979578
# 1.837   -1.49285928596052   -3.9021819886561087
# 1.839 -1.1941956871332284   -3.9175358821558057
# Length = 36 rows
#
# Clump 91
#  TIME          X                  Y
# ----- ------------------- ------------------
# 1.802  -1.203338735597121   5.44204233007738
# 1.803 -1.3226694845274598  5.414877755239823
# 1.807 -2.2777869380802866  5.087820139458726
# 1.808 -2.4137829071919783  5.027486765596596
# 1.809  -2.575254637963885  4.929550943766201
#  1.81 -2.7367463686525886  4.842179001454784
# 1.811  -2.928439461509768 4.7335594143562245
# 1.812 -3.1069816952188374  4.629065532292824
# 1.813 -3.2547565219966117  4.591467654601853
# 1.814 -3.4113238330107887  4.470812938097385
# 1.815  -3.551039884261807  4.420766501088703
# 1.817 -3.9385751665849518  3.944875552586441
#  1.82   -4.22306893772354 3.5724097199005675
# Clump 100
#  TIME          X                  Y
# ----- ------------------- ------------------
#   1.5   4.383638163491104  1.134803998897035
# 1.501   4.388281024699662  1.272067760528128
# 1.502   4.319849132432957 1.3757252624147516
# 1.503   4.225878483774556 1.5778087341431526
# 1.507   3.839286922202509 2.3643732253346332
# 1.508  3.7676059711484213   2.51982925311566
# 1.509  3.6791144504655606  2.674367528165531
#  1.51  3.5568029473183436  2.828426281426045
# 1.511   3.455256793763879  2.961327491215102
# 1.512  3.2782079563987008  3.131510066904045
#   ...                 ...                ...
# 1.854 -1.4270962611979154  3.547049834372723
# 1.855  -1.588937805427183  3.467474375944721
# 1.856 -1.7428818898953202 3.3704460882037424
# 1.857 -1.9038155094927638 3.2608003301099853
# 1.858  -2.050781798953246 3.1547782062582432
# 1.859  -2.190913451413104 3.0199293914545815
#  1.86  -2.326957648941103   2.90985248195012
# 1.861  -2.442969165232571 2.7703770142036794
# 1.862  -2.571186114783352 2.6194377117085716
# 1.863 -2.6878169974204704  2.479411909967023
# 1.864  -2.793597224059472  2.317522296035602
# Length = 362 rows
#
# Clump 101
#  TIME          X                    Y
# ----- -------------------- --------------------
# 1.831  -0.7222091606929348   0.7215789049609099
# 1.832  -0.7755853946885236   0.6230814847235953
# 1.833   -1.189459809027673  0.39493957103779354
# 1.834   -1.420799460923506  0.12954989906837805
# 1.835  -1.4855498716453301  -0.0770260481388883
# 1.836  -1.4453807566323102 -0.20419590519616262
# 1.837  -1.5297395817245942  -0.5040812324051559
# 1.838   -1.523637659796639  -0.7395712668490553
# 1.839   -1.493664241286802  -0.9927381134003841
#  1.84  -1.4158151567366262   -1.167245797870914
#   ...                  ...                  ...
# 1.844  -0.9032805184468828  -1.7449696009843354
# 1.845   -0.751889385996097  -1.8121323904751419
# 1.846   -0.581005239761238  -1.8566199341706633
# 1.847  -0.4075223616104945   -1.857022243540739
# 1.848  -0.2477047109238758  -1.8566745019472053
# 1.849 -0.08293547455408042    -1.80170669337986
#  1.85  0.07169294649118738  -1.7436957523072087
# 1.851  0.22173876154664274  -1.6541452597239752
# 1.852  0.35794264196227155  -1.5495668547049448
# 1.853   0.4840174689248318  -1.4541020201054113
# 1.855   0.4717543889921874  -0.9158025046268405
# Length = 24 rows
#
# Clump 102
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.838  -2.667571570911972  -4.482309086584636
#  1.84  -2.387029581443748  -4.648587512323768
# 1.843  -1.706342871295179  -4.838918857292973
# 1.844  -1.453496898899889  -4.806784512485079
# 1.845 -1.3357188173410839  -4.893055807652285
# 1.847 -0.9965205320767452  -4.892326006560879
# 1.851 -0.2101475962522444  -4.918441370416672
# 1.853 0.11249543806782124  -4.921021814597862
# 1.854  0.3844961502308015  -5.138970465908961
# 1.855 0.49362075739582434 -4.8289356163573585
#   ...                 ...                 ...
# 1.904  3.9943879831006797   2.502636442603449
# 1.905   3.898181360169994  2.6545073786047717
# 1.906    3.80430765109882   2.788278401867605
# 1.907  3.7005234253243438   2.938543645082039
# 1.908  3.5869651897214005  3.0809554141474917
#  1.91  3.3193041544175585  3.4168498402404666
# 1.913  2.8491861974165884   3.782907312400664
# 1.914  2.7473700173170097  3.9075381437736203
# 1.916   2.493915273044224  4.1170667155373915
# 1.917   2.383129142497084  4.2294202809627715
# 1.919   2.138587854227465   4.407895871556905
# Length = 66 rows
#
# Clump 112
#  TIME          X                    Y
# ----- -------------------- -------------------
# 1.863  -0.8443428557136223 -0.4274434932479832
# 1.864  -0.8121124085792119 -0.6363074911952188
# 1.865  -0.7320173919238099 -0.8071195785660573
# 1.866  -0.6134068639609267 -0.9957525385493358
# 1.867  -0.4319438679417908  -1.167397856372973
# 1.868   -0.245347142377759  -1.237200576192992
# 1.869 0.004455682832246588 -1.2578522022704297
#  1.87  0.21806651238295938 -1.2153569968993096
# 1.871  0.39837616957427807 -1.1002996684426247
# 1.872   0.5495516849092764 -0.9637378890653021
# 1.873   0.6882768264564432 -0.8827144517106301
# 1.874   0.7648276390955085 -0.6395534471965179
#
# Clump 116
#  TIME           X                   Y
# ----- --------------------- ------------------
# 1.874    2.0617470677188168  4.739920662667598
# 1.875    1.8273162141415993  4.806845804329954
#  1.88    0.8224254355368159  5.081992293057837
# 1.881    0.6697604765278549  5.104737813886144
# 1.882    0.5145532245989113  5.149670535473504
# 1.883    0.3547655798361042  5.160523469782549
# 1.884   0.17798404638682067  5.167547306652939
# 1.885 -0.047712122947115916 5.1591943407114975
# 1.888   -0.6746782956742968  5.108820238264544
# 1.889   -0.8609348599196123  5.093990737728608
#  1.89   -1.0712561674607186  5.051822333678323
# 1.893    -1.682887836273266  4.943212948503384
# 1.894   -1.8273482880859957  4.897244693813055
# 1.896   -2.1547837675023875 4.8028133044289305
# 1.898    -2.462057462097973  4.627925777988401
# 1.899   -2.6011536369821147  4.572860736702904
#
# Clump 118
#  TIME          X                    Y
# ----- -------------------- --------------------
# 1.875   0.2286061894274025  -0.3668609116447774
# 1.876  0.07244258286596789  -0.5079077070982501
# 1.877   0.0623994104961621 -0.48254613503104876
# 1.878 -0.35236447476078336 -0.32135484991655533
# 1.879 -0.13759496623870188   -0.572606784222513
#  1.88 -0.09700161760864262  -0.4739373550886142
# 1.881  0.22386272346941755  -0.5293813058450814
# 1.882   0.2917342385285397  -0.5144609489725945
# 1.883 0.023504682184411138  -0.3362662866918702
# 1.884 -0.03307838545119441 -0.31762743270381505
#
# Clump 121
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.882  -2.615484289119968   4.857151694339812
# 1.883  -2.791874262033452  4.7997850621651175
# 1.884  -2.892643109615083   4.744305658064271
# 1.886 -3.2055240504024307   4.562361689971779
# 1.887 -3.4777018503798867  4.4611155064226145
# 1.888  -3.666688514833634   4.336785780953998
# 1.889  -3.836381003165337  4.2410589044384155
#  1.89  -3.987839129966863  4.1223390342390624
# 1.891  -4.097902513394915   4.029157175435634
# 1.892  -4.265717316060811   3.912322247215094
#   ...                 ...                 ...
#  1.92  -5.938221328831914 -0.3539042842597676
# 1.921  -5.922365859031915 -0.5077019721290404
# 1.922   -5.89980681499503 -0.6847344200967984
# 1.923  -5.876782836265388 -0.8401213952042149
# 1.924 -5.8255122410393865 -0.9881933910566251
# 1.925  -5.765086047467128 -1.1621409640081395
# 1.926  -5.711349678616113 -1.3187457291487195
# 1.927  -5.635041483176964  -1.492444640681991
# 1.928   -5.58709239893616 -1.6422879869978904
# 1.929  -5.516218786516418 -1.8030805038071915
#  1.93   -5.41684343058776 -1.9514626835820919
# Length = 48 rows
#
# Clump 125
#  TIME          X                    Y
# ----- -------------------- -------------------
# 1.899  -0.9429841888219153   -1.50232709396172
#   1.9  -0.7816226349718967 -1.5023121950711276
# 1.901  -0.6346032628475139 -1.5387190220754428
# 1.902  -0.4504576324053977 -1.4916019794829731
# 1.904 -0.10944614003106705 -1.3955435285370872
# 1.905 0.058326076954044626 -1.3063445155811275
# 1.906  0.20960456588794985 -1.2546981589329844
# 1.907  0.35881252939493885 -1.1220379037385038
# 1.908   0.4928545566350349 -1.0280119728436243
# 1.909   0.6121475053065677 -0.8371744859197884
#   ...                  ...                 ...
# 1.934   -1.246060257943926 -0.9826103338383929
# 1.935  -1.0914362498724364 -1.1143483084317194
# 1.936   -0.918803129181898 -1.2128774578652977
# 1.937  -0.6934627606079454 -1.2618719327361165
# 1.938  -0.5243014831575618 -1.3041272884254895
# 1.939  -0.3101248063464461 -1.2804314626921682
#  1.94 -0.10279134411108874  -1.197103057559999
# 1.941  0.05637934527435184 -1.1444529080786485
# 1.942  0.22380219970633985 -1.0128169468424686
# 1.943  0.36102703137972564 -0.9307053481187959
# 1.945   0.3824491946395026 -0.4500546219126504
# Length = 42 rows
#
# Clump 126
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.909 0.09258925658317496  -5.500699084192178
#  1.91 0.31184927999167183  -5.469277656432993
# 1.911  0.4735432991735615  -5.455870152609887
# 1.912  0.6588163374965175  -5.421466183634955
# 1.913  0.8076141926299616  -5.401277337811731
# 1.914   0.976170889322146   -5.36126972420759
# 1.916   1.150150051595472  -5.750610174934151
# 1.917  1.3304255856988128  -5.686873721169464
# 1.918   1.583396118783081   -5.61387546021073
#  1.92  2.1104567056491916  -5.366044672061757
#   ...                 ...                 ...
# 1.928  3.2871110282315974  -4.714371260447794
# 1.929  3.4913022253827704  -4.555404110804213
#  1.93   3.663814660671668  -4.423763269450917
# 1.932    3.93983200503033   -4.06043781295469
# 1.934   4.241643818035179  -3.830203665241742
# 1.936   4.507046922174406 -3.5673200642204677
# 1.937   4.620597427547815 -3.4286798151398763
# 1.938   4.725406644626053  -3.236665163637947
# 1.942   5.251443106226469 -2.4038685657217975
# 1.943   5.305042080278206 -2.2598116583099555
# 1.944  5.3729141196690975  -2.075746738247547
# Length = 28 rows
#
# Clump 137
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.938  -4.424476296309943  1.2491814999266841
# 1.941  -4.907926709019842  0.7588807415517456
# 1.942  -5.112005442182376   1.114800478589704
# 1.944   -5.19636880965001   0.635062139138499
# 1.945  -5.189968109249952  0.4971484493545883
# 1.947   -5.26243645624531 0.10866985495036209
# 1.948  -5.279977078357596 -0.1528108984412272
# 1.949 -5.2884788132520635 -0.3618095582166446
#  1.95  -5.277450666607632 -0.5408282387644701
# 1.951  -5.263351685287466 -0.8877323933471518
#   ...                 ...                 ...
# 1.995  0.9197728949902597  -6.226588520181223
# 1.996  1.0958659934710095  -6.204091770602424
# 1.997   1.350677582146475  -6.117113873702411
# 1.998  1.4963343475949973  -6.121586109769929
# 1.999  1.7008386615310112  -6.061636936799318
#   2.0  1.8845907464098066  -6.035909611712338
# 2.001  2.0482448387262866  -5.987143557459672
# 2.004  2.5572201025433237 -5.7726746231421044
# 2.006  2.8693096755137057  -5.617781787639688
# 2.007  3.0130157368416595  -5.485843640655894
# 2.009   3.242289958142274  -5.475943594619221
# Length = 63 rows
#
# Clump 138
#  TIME         X                   Y
# ----- ------------------ --------------------
#  1.94  4.659015234566796  -0.7969744341482027
# 1.941 4.6918635204822845  -0.5719261365221251
# 1.942  4.707199217152054 -0.35704619962630835
# 1.943 4.7138645185246535  -0.1535775310233261
# 1.944 4.7223123702055005 0.015845880444898607
# 1.945  4.720755021136149  0.22850038571603548
# 1.946  4.698245499168891  0.41238943259538396
# 1.947  4.650066154714319    0.742615383995886
# 1.948  4.614005275745066   1.0184178107854553
# 1.949  4.582669609018261      1.2452424747408
# 1.951  4.460905434514503    1.573745456658687
# 1.952  4.397789621695433   1.7762315006282707
# 1.953  4.331183659320727    1.935212243975202
# 1.958   3.85436962576928    3.005219661727556
#  1.96 3.6449430643038356   3.3394810656759537
#
# Clump 140
#  TIME          X                    Y
# ----- -------------------- --------------------
# 1.951  -0.7707168015740907 -0.18230158139624172
# 1.952  -0.7832507610482256  -0.4516117072722142
# 1.953  -0.6968043162396055  -0.5313743988616187
# 1.954   -0.584782222507817  -0.7891403992290119
# 1.955  -0.4639569699166776  -0.8869257462638307
# 1.956 -0.20127071077077585  -1.0337130181436467
# 1.957  0.09721234338911595  -1.0496562100884412
# 1.958  0.30095385070577785  -0.9947103845482664
# 1.959   0.2373756357886874  -0.4983958004258043
#  1.96 0.010666282776895117  -0.5230309599856517
#   ...                  ...                  ...
# 1.971   0.3469831072147891  -0.3373282062229652
# 1.972  0.27652004950736847  -0.3937550989351892
# 1.973    0.336557617044628 -0.33649066872755146
# 1.974  0.33510312982134516  -0.3219395381529811
# 1.975   0.3650619708826763 -0.26513064170151684
# 1.976  0.35684153853722367  -0.2723815493637501
# 1.977  0.33780284297414576  -0.2706178856689603
# 1.978  0.37479325745314745 -0.20653275736860396
# 1.979  0.33932517742517043 -0.22022585854492716
# 1.981  0.32340070190674314 -0.17967248550171838
# 1.983   0.3368028740055758 -0.09599741256826705
# Length = 31 rows
# Clump 144
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.968 -1.5012845625911444   3.971132452553285
# 1.969  -1.833623807617383  3.9511166605159307
#  1.97 -1.9936650751684855  3.9130337154822024
# 1.971 -2.2017656740908382   3.820956088475422
# 1.972   -2.40983652390804  3.7454472382486323
# 1.973 -2.5222215084285984  3.6191506490549252
# 1.974 -2.7497590808861565  3.5276283489305835
# 1.975  -2.857518112096949   3.425903896554486
# 1.976  -3.210073628698889   3.276420309489318
# 1.978 -3.5482400040634987  2.9694879322191743
#   ...                 ...                 ...
# 1.982  -4.240312327789488  2.5098586336697015
# 1.983  -4.338437058304525  2.3814956021014293
# 1.984  -4.461675030109431  2.2015874931963726
# 1.985 -4.5463158838655096   2.049032525924378
# 1.987  -4.800527029699414  1.6691358842924884
# 1.989 -5.0556898309783795  1.2714947751302859
# 1.991  -5.212837818773289  0.8863403523544352
# 1.992  -5.272367231410973  0.6922433917853797
# 1.993  -5.343690210011132  0.5271480330808557
# 1.994  -5.407536613138227 0.31275785437259934
# 1.995  -5.439909756750616 0.13687000044941544
# Length = 24 rows
#
# Clump 167
#  TIME          X                    Y
# ----- -------------------- --------------------
#   1.5     -3.9095114316768   1.0366654327688711
# 1.501  -3.9705120947028703   0.8424085155262071
# 1.502   -4.018848090238364   0.6517690939982869
# 1.503   -4.050740589570385   0.4842600541038774
# 1.504   -4.081956527477604   0.2739437242036737
# 1.505    -4.09748754002424  0.06113842505851281
# 1.506   -4.101126443122849 -0.11734722369845971
# 1.507  -4.0961656398294615 -0.31190764606230637
# 1.508   -4.086264823325635 -0.48173720318205476
# 1.509   -4.070337511522053  -0.6741878783172209
#   ...                  ...                  ...
# 2.054  0.38498919604054066  -0.5745731069065435
# 2.055    0.504883881263544  -0.4233675581146268
# 2.056   0.5784118374331165 -0.23758678440554903
# 2.057   0.5570246522728519 -0.04844262464527726
# 2.058   0.4940670646158303  0.11397211572681637
# 2.059   0.3448439984361521  0.24491604602739897
#  2.06   0.1578207534883902  0.32884627622202395
# 2.064 -0.15520498856822934  -0.2809459869204509
# 2.065 -0.00999598084615696 -0.34848424325890415
# 2.066  0.17186680292971235  -0.3456339283624663
# 2.067   0.2775408414349479 -0.20692513454750205
# Length = 551 rows
#
# Clump 168
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.997 -4.8613270592631785 -1.5103568574654544
# 1.998  -4.818221920728828 -1.6994144682335215
# 1.999  -4.760338656654969 -1.8703559829866159
#   2.0  -4.657224491501712 -2.1400779204904956
# 2.001  -4.662755082727059  -2.250726852316906
# 2.002  -4.484791340194186 -2.6811148238528957
# 2.003  -4.214136901080542  -2.968337114189615
# 2.004  -4.244280680776118 -3.0561379878862094
# 2.005 -4.0037763762468535  -3.308480985754349
# 2.006 -3.8783246482605884 -3.4822002861901806
#   ...                 ...                 ...
# 2.067  5.3945949025637905  -2.499354809619401
# 2.068   5.456609752535377 -2.3549554591248567
# 2.069   5.527283359803523  -2.194338149084838
#  2.07   5.596373095356277   -1.90832227214098
# 2.071   5.606516154561751 -1.6638922685411732
# 2.072   5.718814978129182 -1.5522068087492884
# 2.074   5.777459791813951 -1.1810473130948087
# 2.075   5.776575522341541 -1.0564777704207822
# 2.076   5.755808602744725 -0.8933118129016107
# 2.078   5.680866351842847 -0.5613344523575736
#  2.08   6.164096552786187 -0.3485702739522504
# Length = 81 rows
#
# Clump 169
#  TIME         X                   Y
# ----- ------------------ -------------------
# 2.002  4.569359703872194  2.5695181528834614
# 2.004 4.3165678307002695  2.9620162789007107
# 2.006  4.079388561436094   3.327934715547731
# 2.007  3.958387491127639   3.486540392663865
# 2.008 3.8493399504446852  3.6132186299496625
# 2.009  3.735817218377951  3.7538554256544727
#  2.01 3.6079136115262926   3.893686607067654
# 2.011  3.478495831705014   4.030724893437954
# 2.012 3.3495697930993287   4.168190808268836
# 2.013 3.2221310944110364   4.265100328386237
#   ...                ...                 ...
# 2.107 0.6908703989940999  -4.008051900521886
# 2.108 0.8568263905565151  -3.982372751771177
# 2.109 1.0254435853327464  -3.934297891984373
#  2.11 1.1893272769110674 -3.8781365206791385
# 2.111 1.3638623490474293 -3.8495679967234566
# 2.112 1.5525226166223944 -3.8229464000870284
# 2.113 1.7141539205104215  -3.753994478279757
# 2.114 1.8929247263143438 -3.6821492103950555
# 2.115 2.0688984009707374 -3.5988318198850076
# 2.116  2.257342311638049 -3.4998057730484757
# 2.118 2.5639737748572906  -3.302759979519727
# Length = 101 rows
#
# Clump 173
#  TIME          X                    Y
# ----- -------------------- -------------------
# 2.056  -3.5324748053118737 -3.8311818712178676
# 2.058  -3.5558129943430505 -3.9826486764359816
# 2.059   -3.353452160095977  -4.167795431873364
# 2.061   -2.952013629995391  -4.449145015552902
# 2.062  -2.2297121350149816  -4.633503801309165
# 2.066   -1.941212559217993   -5.03036517656384
# 2.068  -1.6297444855439673    -5.1789738598494
# 2.069  -1.3949822531773926  -5.328066252867115
#  2.07  -1.1604233523176368  -5.393890566818588
# 2.071  -1.0095527468157477  -5.461298344126968
# 2.072  -0.7470632164602654  -5.506738938170838
# 2.073  -0.6441483812067462  -5.525394992156349
# 2.074   -0.374986703426172  -5.558850328108124
# 2.075  -0.3146174245124589  -5.579581164169921
# 2.076 -0.04655530429725741  -5.575224779336762
# 2.077   0.2163320515828278  -5.588759478971096
# 2.079   1.0356829695893472   -5.32816477446285
#  2.08    1.152976349955737 -5.3196623552951054
# 2.082   1.5470280268080967  -5.238528382224058
# 2.083   1.7602381846649007  -5.070058170991885
#
# Clump 178
#  TIME          X                  Y
# ----- ------------------- ------------------
# 2.065  -3.460066242769858  3.588216983018453
# 2.066 -3.6703401651961562 3.4312662870969675
# 2.068 -3.8630868871351827 3.7226576262191102
# 2.071  -4.203614931085933 3.3398450427021573
# 2.075  -4.628111348415662 2.6314512868548974
# 2.078  -4.945619649104405 1.8871953036765698
# 2.079  -4.896025333849505 2.1708392828918885
#  2.08  -4.966710351409256 2.0115143564940836
# 2.081  -5.040157878358225 1.8308546712858789
# 2.082  -5.137467909578162 1.5566932797491908
#
# Clump 183
#  TIME          X                   Y
# ----- ------------------- --------------------
# 2.073  -4.544468747748232   2.2328703908848833
# 2.077 -4.8323310632777865   1.3673322823416059
# 2.079 -4.9452718165852225    1.072820699885156
# 2.083 -5.2832510435406865    0.727342452525806
# 2.084  -5.343114114593343   0.5805285481815049
# 2.085  -5.364897214540281  0.43742526428011125
# 2.086  -5.395794472007629  0.23247764293189505
# 2.087  -5.430897259131315  0.05792432713060743
# 2.088  -5.443124681494261 -0.17838510095537835
# 2.089  -5.406950919277882 -0.43093263209764243
#   ...                 ...                  ...
# 2.101  -4.801173748561479   -2.730247427828332
# 2.102  -4.716156803172256  -2.8835817102937975
# 2.103  -4.581394954841698   -3.040860065650827
# 2.104  -4.540316332800128  -3.1958879271756264
# 2.105  -4.397653163237318  -3.3695224951614526
# 2.106  -4.321274327028398  -3.5162415983642106
# 2.107  -4.555305703976705  -3.6246915818423058
# 2.108 -4.2543264288810345  -3.7978965544135606
# 2.109    -4.4154710832023  -3.8583340023965844
# 2.113 -3.8863916397456366   -4.550486305464915
# 2.114 -3.7883868227722863   -4.610770472899668
# Length = 32 rows
#
# Clump 185
#  TIME         X                   Y
# ----- ------------------ --------------------
# 2.076  4.236717436616768   -3.058880166917353
# 2.077  4.350057172251447  -2.9269798059838106
# 2.078  4.450968380517648  -2.8347552310634443
#  2.08  4.625365162880941  -2.6082647428041668
# 2.084  4.893647252098183  -1.8592673889502067
# 2.086  4.984599491613679   -1.505767789417909
# 2.087  5.001351163153474  -1.3095007035086772
# 2.088 5.0058252306380036  -1.1401028478067774
# 2.089  5.034373949888263  -0.9752936499387043
# 2.092  5.189151977947276 -0.24414025431486622
# 2.095   5.12848471688159   0.2564098834616213
#   2.1  5.026554959320524    1.292115333368742
# 2.102  4.927428420345158   1.6308142633542544
#
# Clump 189
#  TIME          X                   Y
# ----- ------------------- -------------------
# 2.084 -3.2290178107355016   3.390736529338611
# 2.086  -3.468068114738204  3.2625405699354437
# 2.087  -3.646091391179924  3.6228308956320054
# 2.088 -3.7508139805609924   3.539597155761714
# 2.089 -3.8369751306515143   3.396179741141176
#  2.09  -3.994826435569829   3.350705419064983
# 2.091  -4.085348581773276  3.2043923236601146
# 2.092   -4.23904699278861  2.9550878577484236
# 2.093 -4.3405889709538075   2.935186977186246
# 2.094  -4.453421712787017   2.803909837767241
#   ...                 ...                 ...
# 2.116  -5.256483579596395 -1.4624142114602054
# 2.117  -5.222799486838963 -1.6606111955016656
# 2.118  -5.170323122200035 -1.8196499121178664
# 2.119  -5.080178066985927 -2.0067391265374126
#  2.12  -5.009353062109162 -2.1638368586522647
# 2.121  -4.966342048839656   -2.33061670133698
# 2.122  -4.879664788448074 -2.5117913077005527
# 2.123  -4.794180742071607 -2.6527536188838763
# 2.124  -4.700063828926718  -2.852193937618499
# 2.125 -4.6228272823354155 -3.0035121367007567
#  2.13  -4.059626497078349 -3.5342416003755903
# Length = 41 rows
#
# Clump 196
#  TIME         X                   Y
# ----- ------------------ --------------------
# 2.099  5.100392497402731  -0.2473864541640271
# 2.101  5.122708165677098 0.045699596461435225
# 2.103  5.083952462646105  0.45697952859071167
# 2.104  5.070718091697892    0.671429908346162
# 2.105  5.013905644962783   0.9360487708073645
# 2.106  4.940976899350818    1.207065655594778
# 2.107  4.928874060978913    1.294688920618218
# 2.108   4.86173199082011   1.5359891109678727
# 2.109  4.804049207580152   1.6780529343622743
#  2.11  4.754825260396236   1.9098161627158712
# 2.111  4.409429980653955   2.5708753299823393
# 2.112  4.582514207355532   2.3456057747152497
# 2.113  4.182178684228494   2.9357384793810146
# 2.114 4.0888348431333625   3.1080489104696296
# 2.115  3.889966092118263    3.249248620026108
# 2.116 3.8094036691317914    3.361632962670225
# 2.119  3.783749236162677    3.676091502012829
#
# Clump 201
#  TIME         X                   Y
# ----- ------------------ --------------------
# 2.111  4.077322224721297  -0.8493284271994955
# 2.113  4.153499741853794  -0.5738214227482034
# 2.114  4.189350432064189  -0.5482941516911283
# 2.115   4.18979240545144 -0.29717264759212186
# 2.116  4.250022137928861 -0.16797631896266285
# 2.118  4.215905149917702  0.19426970028468052
# 2.119 4.0982820481151245  0.48936969834110206
#  2.12  4.058631988394099   0.6624412886256522
# 2.122  3.976713170775158   0.9817823855794457
# 2.123 3.9308932059182533   1.1430925166085537
# 2.124  3.918131473632315   1.3133263534956696
# 2.125 3.8964772064001743   1.4624015291209809
# 2.126  3.858105817948264    1.601610432400605
#
# Clump 230
#  TIME          X                    Y
# ----- -------------------- -------------------
# 2.009   -0.469783100731937  -4.565917329214659
#  2.01  -0.2549897521465955  -4.584445606194372
# 2.011 -0.14575754802864996  -4.602539876955808
# 2.012 -0.03027585354061746  -4.624411073314096
# 2.013  0.18653875568605266   -4.63798889735769
# 2.014   0.4328922307502392  -4.652481062015957
# 2.015   0.5430940362060667 -4.6313028371491995
# 2.017   0.8924250515780167  -4.598984362291588
# 2.018    1.102854738445544  -4.557050755319615
# 2.019   1.2744349875667924  -4.508557870538257
#   ...                  ...                 ...
# 2.209    5.170606754784828  0.8494526250327419
#  2.21     5.33082672119335  0.6771745038415549
# 2.211    5.252124698825127  0.9015105645726785
# 2.212    5.222954737114992   1.115340855270026
# 2.213    5.147793624816111  1.3276188873802242
# 2.214    5.143733976415219  1.5117014923037424
# 2.215    5.100792960787299  1.6999740897129865
# 2.216    4.533647212919048  1.9104315031003485
# 2.217    4.435975389649594  2.0620791780281937
# 2.218   4.3355420221865435   2.202430515932952
# 2.219    4.758808233243302  2.5023591107099064
# Length = 210 rows
#
# Clump 231
#  TIME          X                   Y
# ----- ------------------- -------------------
# 2.125  -5.416304905193494  -3.083725676066807
# 2.126    -5.3620004367416 -3.2359729676738054
# 2.127   -5.27265696864536 -3.3927097036492393
# 2.128  -5.177023467511315 -3.5517532269434167
# 2.129  -5.072354796396627 -3.7223650538538577
#  2.13  -4.938233001423711 -3.9114233293075777
# 2.131   -4.78101284935285  -4.109628839779765
# 2.132  -4.646100289430338  -4.264584225079964
# 2.133   -4.51728737774172 -4.3971215095073894
# 2.134  -4.390515071215573   -4.51488554517823
#   ...                 ...                 ...
# 2.139 -3.6235630815390385  -5.190941288513221
#  2.14 -3.4070805364453527  -5.266560743004143
# 2.141 -3.2477028672762485  -5.370987713145796
# 2.142 -3.0946541485531704  -5.476426795418399
# 2.143  -2.896262535733372  -5.579143561766755
# 2.144  -2.775659556176704  -5.670295182418913
# 2.146 -2.2717868944120156  -5.777217488272065
# 2.148  -1.921556266892287  -5.915960759694339
# 2.149 -1.7959137201556685 -6.0365276916907415
#  2.15 -1.5933996671263673  -6.056306699166144
# 2.151 -1.4261584296403906 -6.1010225095304484
# Length = 24 rows
#
# Clump 232
#  TIME         X                  Y
# ----- ------------------ ------------------
# 2.135  4.418793030222042  2.572286504588725
# 2.136  4.373470287157977  2.814079769077154
# 2.137  4.181638080629159 2.9335581985700205
# 2.138 3.9472821837217857 3.1231398802313537
# 2.139  4.226254004768623 3.2617940812640978
#  2.14  4.216266826599591  3.299868250057769
# 2.141  3.871162544155724 3.5365855481267854
# 2.142  3.852870257186553  3.648096673053761
# 2.143  4.095558835567483 3.6299292617127246
# 2.144 3.5074792665323624  4.009773232315807
# 2.145 3.3094319670758403  4.119108598724703
# 2.146 3.2369624148625964  4.209138264394618
# 2.147 3.2130957999161156  4.365438935741961
# 2.148  3.021379765306744  4.416903716717182
# 2.149  2.715136547809106   4.54981183234645
#  2.15  2.628550616062373  4.640240069618492
# 2.151  2.403512101129179  4.737794511926193
# 2.152 2.2696428912452427  4.816738270385775
# 2.154 1.9073847373716786  5.016091359630349
# 2.155  1.619015645030319  5.006889977591009
# 2.158 1.1333171441632877  5.213867596743434
#
# Clump 233
#  TIME          X                   Y
# ----- ------------------- -------------------
# 2.145 -0.8975278440856208  -4.355647483599297
# 2.146 -0.7710726463080977  -4.378662194280502
# 2.147 -0.5417035752667201  -4.397620401324268
#  2.15 0.15804159226245695 -4.3058747028429245
# 2.151  0.3189587297064803  -4.299497075403003
# 2.152  0.5909227738304001 -4.2094961929361245
# 2.153  0.7542750680598383  -4.127326546101773
# 2.154  0.9393466263102573  -4.150677996988606
# 2.155  1.1789530200709297  -4.020376602802467
# 2.156  1.3253844954499892  -3.962043464664939
# 2.157  1.5045444799801908 -3.9233370512309684
# 2.158  1.6348324291869343  -3.865850764424684
# 2.159  1.8869526346559362  -3.672539349731013
#  2.16  1.7188465672934972  -4.013837468245787
# 2.161  1.8805344869033251 -3.9316467566602284
# 2.162  2.3222859203901463  -3.346802437282188
# 2.163   2.514430500595794 -3.2230151075940863
# 2.164   2.635293456319236 -3.1064893920781675
# 2.165   2.758114008004132 -3.0032528984963243
# 2.166   2.757924170554985 -3.3985904670645777
# 2.167  2.9610499849166265  -2.728143020074868
# 2.168   3.024293584884652 -3.1974370734591133
#
# Clump 263
#  TIME         X                   Y
# ----- ------------------ --------------------
# 2.172  3.556097296819722  -1.8441519541308473
# 2.173 3.5313024208780837   -1.633471820558432
# 2.174 3.7152611763998613  -1.4941809657529412
# 2.175  3.787515271139929  -1.2953535360019937
# 2.176 3.8377973585576686  -1.1174810487330649
# 2.177 3.8354345619982517   -0.894428734269536
# 2.178  3.876697856200044   -0.778271801283646
# 2.179  3.840729549348999  -0.5779839325381497
#  2.18 3.8492442612923456 -0.47084219291602186
# 2.181  3.874927424973019 -0.23261351035496014
# 2.182 3.9085342257783933 -0.48886541613609746
# 2.183  3.897145344566718   0.1980991352757466
# 2.186 3.8014023071317755   0.6997486677578091
# 2.187 3.5963385937687966   0.9165391445406736
# 2.188 3.5319367578431518   1.1109407903060107
# 2.189  3.463634370093789   1.2764266116239347
#  2.19 3.4427975084121254   1.4116990549953545
# 2.191 3.3216947310026246    1.584991398587518
# 2.192 3.2512158258783463   1.7333835365598493
#
# Clump 265
#  TIME         X                  Y
# ----- ------------------ ------------------
# 2.176 3.2693985880496967  4.085920483149977
# 2.179  3.018825770964586 4.4003501525796365
#  2.18 2.8101973000157754   4.46982469707404
# 2.181  2.610154869098445  4.546923731499616
# 2.184  2.114316526801631  4.828834649553444
# 2.186 1.8093007665984149  4.958675387815633
# 2.187  1.672571872967085  5.011814455232441
# 2.192 1.0539976110656988   5.47478792309958
# 2.193  1.303747757617127  5.536452264143905
# 2.194  1.106811548187288  5.555855918095028
#
# Clump 282
#  TIME           X                    Y
# ----- --------------------- -------------------
# 2.201   -3.1700143958002607  -3.264367770281058
# 2.202    -2.961194901692994 -3.4004197877972726
# 2.204    -2.683285210815464 -3.6369097426077626
# 2.205    -2.510185924061911 -3.7397678764545073
# 2.206   -2.3980519934544993 -3.7866484196533854
# 2.207   -2.2498137511624257  -3.839237132283751
# 2.208    -2.104081391934272  -3.904426476594432
# 2.209   -1.9377950310664107 -3.9736695373976336
#  2.21   -1.7999536046673859 -3.9987358512288607
# 2.213   -0.8379246379110921  -4.117881771795903
# 2.214   -0.6243327603051498  -4.146405821433702
# 2.219 -0.021321964212034673  -4.241964948685536
# Clump 313
#  TIME           X                    Y
# ----- --------------------- -------------------
#  2.13    1.1040182361063198    5.55585178674996
# 2.132    0.8223391507037409   5.575489489349597
# 2.133    0.4135154444701154  5.6475741941135436
# 2.134   0.25599367580513627   5.661623602741432
# 2.135  0.059714269600179205   5.659953613856117
# 2.136 -0.019256743767779323   5.710898246340408
# ...
# 3.805  3.526763005511525 -4.8941179367182475
# 3.806  3.825616800628313  -4.787119425723382
# 3.807 3.8950550529307937  -4.654764340622728
# 3.808 3.9699140215351663  -4.581159594201474
# 3.809  4.247502111852999  -4.387825291084791
#  3.81  4.347049407065786 -4.1251607248749576
# 3.811  4.522595828328967   -4.01717702825264
# 3.812  4.636351463704394 -3.7881256961975733
# 3.813   4.76981048173536  -3.640428844378466
# 3.814 4.9430399730729855 -3.4588345273083236
# 3.815 5.0819620504086975  -3.254859774812736
# 3.816  5.191799194210749 -3.0577700284646876
# 3.818  5.361525724960189 -2.7147196306726404
# 3.819  5.475092350725912  -2.483967635957618
# 3.822   5.73793539555077 -1.9181450360585781
#
# Clump 2118
#  TIME          X                   Y
# ----- ------------------- -------------------
# 3.809  -5.489164472327314 -2.5263654126349975
# 3.812  -5.266776404219228  -3.030981832289752
# 3.813  -5.159921433450448 -3.1977944125582853
# 3.816  -4.819179723147282  -3.628996240316057
# 3.819  -4.047736144436389  -4.170390133600582
#  3.82 -3.7102159813663667   -4.26382919823479
# 3.821  -3.696014349285926  -4.399817933578458
# 3.822   -3.46590716261296  -4.491339844215667
# 3.827 -2.5029351171554017  -4.848195871917749
# 3.828  -2.745604314321013  -5.160999635612164
# 3.829 -2.5873463112361637  -5.301822718986594
#
# Clump 2136
#  TIME         X                  Y
# ----- ------------------ ------------------
# 3.821  5.074562963840677 2.3170693322033062
# 3.822  5.012375332828386 2.4971458466899046
# 3.823  4.926653357028964 2.6430292022539605
# 3.824  4.792733249606978 2.7937328790783718
# 3.826  4.550418932252786 3.1658187672652454
# 3.827 4.4678054953042095  3.312500687596482
# 3.828 4.3246272064496765 3.5004913279802143
# 3.829  4.216013768396931  3.685574379340391
#  3.83 4.1088327309811294 3.8371800366352105
# 3.831  4.077170528251175  4.125491968375958
#
# Clump 2186
#  TIME           X                     Y
# ----- --------------------- ---------------------
# 3.172    -5.322107385978662     3.230241771242467
# 3.176    -5.825107060357735    2.5565669195848555
# 3.177    -5.933938164360071    2.3735024292332976
# 3.178    -6.017521021315711    2.1934646327289715
# 3.179    -6.113357840673292    1.9913323578743438
#  3.18    -6.191945362991361    1.8035294049550699
# 3.181    -6.273411534315973     1.614081154886375
# 3.182    -6.354391162626125    1.4092889202519387
# 3.183    -6.402179865996057    1.2283966195455207
# 3.184    -6.458208414087259    1.0256174273240435
#   ...                   ...                   ...
#  3.84   -0.4621724491246198   0.30438048405885565
# 3.841   -0.4809166219293094   0.08272940618187324
# 3.842   -0.2250834330571158  -0.26013485521634244
# 3.843   -0.0899275741069735  -0.33513232733418336
# 3.844    0.3152139686601611   -0.2434516655610671
# 3.845    0.4253851451400375 0.0019940794890065928
# 3.846   0.39079111846297915   0.11626505900327229
# 3.847    0.3115440303786507   0.25028608762758137
# 3.848   0.18147579153306498    0.3532035903109707
# 3.849 -0.008779786329680224   0.37843997172815175
#  3.85  -0.17409952837367018   0.25625850976930814
# Length = 676 rows
#
# Clump 2187
#  TIME         X                   Y
# ----- ------------------ -------------------
# 3.817  4.697000845717706 -4.5842388755618035
#  3.82  5.126818988888815 -4.1571971145251965
# 3.821  5.100403357074526 -3.7605917177047785
# 3.822  5.335448908993732 -3.8649961484847704
# 3.823  5.430189813991306  -3.704795453376756
# 3.824  5.600976635648632 -3.5040910472580107
# 3.828  6.001225310573049 -2.8452854216964796
# 3.829  6.131472919991055 -2.6520101335811384
#  3.83  6.241998206011087  -2.403450307537635
# 3.831  6.293134581150375  -2.178631339571156
#   ...                ...                 ...
# 3.854  6.309271614110359  2.8252541370026356
# 3.855  6.197638928224591   3.050368017252023
# 3.856  6.380215024684217  3.1675997093178716
# 3.857  6.135107485320972  3.4634315698224833
# 3.858  6.136295559302495   3.573946099874468
# 3.859  6.062774504007868  3.7849902988083652
#  3.86  5.965565538547066   3.930766346284308
# 3.861  5.861542593241524   4.092800049049171
# 3.862  5.724595990556643   4.233703653217641
# 3.863  5.610758465089353    4.38096495810962
# 3.865 5.3524695691932225   4.628773914287064
# Length = 41 rows
#
# Clump 2202
#  TIME         X                    Y
# ----- ------------------ ---------------------
# 3.848 1.3662522295462587    -4.097111371005127
# 3.851 1.8333143573570196    -3.896780992688858
# 3.854 2.4555128322566118    -3.589324142827122
# 3.855 2.5773998683885035    -4.070710277305812
# 3.856  2.770548080803529   -3.9453682430214196
# 3.861 3.1983888195777013    -3.256203637825195
# 3.863 3.8363195948394377    -3.084751509753677
# 3.864 3.8796810035128315    -2.957308954858898
# 3.866  4.223694997577995   -2.6379027618121933
# 3.869  4.386496504024212    -1.949972391156684
# 3.871  4.546442550216002   -1.5306720986130302
# 3.872  4.626898351427327   -1.3220483072415181
# 3.873   4.67372865927342   -1.1296478692981493
# 3.878  4.824282168385935 -0.024497320184940625
#
# Clump 2217
#  TIME          X                   Y
# ----- ------------------- -------------------
# 3.854 -4.3785097790577705  -5.469169072843525
# 3.856  -4.015182328786812  -5.621600757525633
# 3.858 -3.6722195223082466  -5.792047040468093
# 3.859  -3.412162622206927 -5.9149373376451555
#  3.86   -3.55525677242631  -5.931589085181678
# 3.861 -2.9256868583247466  -5.942245255699248
# 3.862 -2.7650750683132443  -6.107785550119488
# 3.863  -2.552074696772793  -6.128980440361784
# 3.864  -2.467655687119466 -6.2923066013043085
# 3.865 -2.2048240693601024  -6.281352166468471
# 3.866 -2.1717692236714092  -6.455097677056483
# 3.867  -2.233197198697403  -6.742494073159207
# 3.868 -2.0700215556098804   -6.79913069792013
# 3.869  -1.866199574012901  -6.863198399025407
#
# Clump 2229
#  TIME         X                   Y
# ----- ------------------ -------------------
# 3.857 3.4809786846705992  -4.686750361151908
# 3.858  3.626589037238495  -4.542475649988815
# 3.859 3.8123598874321414  -4.424828824374381
#  3.86    3.9449949832375  -4.298567181186258
# 3.862  4.335073725035174 -3.9304748786739068
# 3.863  4.465505025547558    -3.7600637740931
# 3.865   4.68667399901211  -3.381054055712784
# 3.866  4.805613146136819 -3.0823684418218806
# 3.867  4.967865880380404  -2.739912794662612
# 3.868   5.03438169797316 -2.6223322016136543
#
# Clump 2250
#  TIME          X                  Y
# ----- ------------------- ------------------
# 3.869 -2.9985966679444807 6.7568357075022805
# 3.871 -3.3290319445373546  6.679883676871849
# 3.872 -3.5604914678087187  6.603064587027247
# 3.873  -3.686953404558613  6.510734500383755
# 3.874 -3.9547731356449667  6.275808677396879
# 3.875  -4.065067211626856  6.198402269639195
# 3.876  -4.421892357201975  5.660715157589091
# 3.877  -4.757067438462221  5.440543852753808
# 3.878  -4.493181310338739  5.640322736569096
# 3.882 -4.9340512914128976  5.130118983420604
# 3.886  -5.488859731795908  4.641882547607016
# 3.887  -5.666779001731546  4.438333556405253
# 3.888  -5.736072879048957  4.311133039522358
# 3.889  -5.912913721389312  4.067566596772741
#  3.89  -6.014973908617926  3.922081318222432
# 3.891  -6.109934834376386  3.767263261959805
# 3.896  -6.356687324679286  3.420246777845355
# 3.899  -6.793311084680871 2.6270771136108877
#   3.9  -6.853352534763728 2.4661851860971535
#
# Clump 2302
#  TIME          X                  Y
# ----- ------------------- ------------------
#  3.89 -2.9827031376396973  5.880097985603951
# 3.892 -3.2945113417201335 5.7112389552320675
# 3.893  -3.506626255668204  5.599600580524158
# 3.896  -4.082978644127131  5.270968373914842
# 3.897  -4.221340499471931 5.1608040328915115
# 3.902  -5.065302090658028  4.217694432855575
# 3.903 -5.1807440433190814  4.136604060481386
# 3.904  -5.301412234835761  3.914439486992682
# 3.905   -5.36193554544671 3.8526005558778618
# 3.906  -5.651063712925865 3.4100490659855067
#
# Clump 2310
#  TIME         X                   Y
# ----- ------------------ -------------------
# 3.893  3.177775377392951  -6.145535309915722
# 3.897  4.078241481521798   -6.05119069023021
# 3.898 4.2390081498806715 -5.9520423718314275
# 3.899 4.3673658785436125  -5.796328782608891
#   3.9  4.484238846035138 -5.5426135680994335
# 3.902  4.834432969209755  -5.405737039856915
# 3.903  4.963710361472963  -5.683948194133725
# 3.904  5.122000434644921  -5.234622162023793
# 3.905  5.389263088810793  -5.039445327028348
# 3.906  5.510473204510843 -4.8715068731630184
# 3.907   5.61719497186163  -4.702668871396967
# 3.908  5.684953949080587 -4.5750950971941355
#  3.91  5.990625430390125  -4.150260043902049
# 3.911  6.008592803665327 -3.8427663077182053
# 3.912  6.192734240073418  -3.792079292521527
# 3.913  6.229701304959008 -3.5131254363311952
# 3.914  6.348362381251522 -3.3899351205108044
# 3.916  6.619471863688982  -3.015612880305184
# 3.917  6.819483344737843  -2.903413876944668
#  3.92  7.102411565227173 -2.4966749095112855
#
# Clump 2313
#  TIME          X                   Y
# ----- -------------------- ------------------
# 3.895   1.7850456765366451   4.80380712970375
# 3.896   1.6139207782337694  4.797898324607969
# 3.897   1.4597464421345079 4.9593667257144105
# 3.899   1.0924025392312808   4.97212576399672
# 3.903  0.45186585563106707  5.273176290859165
# 3.904  0.20883112197128184  5.308328899829439
# 3.906 -0.05015716210023516  5.563468710370639
# 3.907 -0.30385819180142354  5.531009027132416
# 3.908  -0.4759007291901041  5.667022651157732
# 3.909  -0.5627419940290183  5.717684668283784
#  3.91  -0.5778553062215533  5.788686640502791
# 3.911  -0.9104484774690957  5.733387939131936
# 3.913  -1.7430726312512517  5.375347972250338
# 3.914  -1.9860427363639823  5.341938277439222
# 3.915  -2.1514229854633324  5.240157174310759
#  3.92  -3.0612983993763874  4.866630210660943
# 3.922   -3.382624973840459  4.640813086394554
# 3.927    -4.20502738738337 3.6194234564899084
# 3.928  -4.3607555537615275 3.4594383269032933
# 3.929    -4.47058045442325 3.3163538395191345
#  3.93   -4.579022709030382  3.151227318476049
# 3.931   -4.726220850476031  2.979595914266917
#
# Clump 2470
#  TIME          X                  Y
# ----- ------------------- ------------------
# 3.927 -2.7609763947243033  5.465317355789026
# 3.932   -4.04379758254899  4.735021241326378
# 3.933 -4.2382790066458975   4.64531373490568
# 3.934  -4.337989830320308  4.486562383952297
# 3.936  -4.494324572845684   4.19346715710584
# 3.937  -4.917603553861779 3.7843047819636046
# 3.938  -5.023304143623083  3.707159574404402
# 3.939  -5.150439376027072 3.5825990853229768
#  3.94  -5.245269128648702 3.4044777043203935
# 3.941  -5.384118128971854  3.326583236697112
# 3.942   -5.51754371029646 3.1845300337861873
# 3.944  -5.720358045490744 2.5685959537743748
# 3.947 -6.4528968574043954 2.0782180624988227
# 3.948  -6.516310476250502 1.8969070643358823
#  3.95  -6.626444608084512 1.5270601247137539
#
# Clump 2471
#  TIME         X                    Y
# ----- ------------------ ---------------------
# 3.933 -5.884104870226773     2.209847038133104
# 3.936 -6.034105726761247    1.5645147127036412
# 3.937 -5.989987747116626    1.2697606274491835
#  3.94 -6.057527527730582    0.7753178598538665
# 3.941 -6.052274564557858    0.6120958430854323
# 3.942 -6.038102069464105   0.38296618929105386
# 3.943  -6.12859132089651   0.19650513728489946
# 3.944  -6.14981084286553 -0.042136743109780876
# 3.945 -6.148197472601788  -0.22014730839953997
# 3.946 -6.157044526946785   -0.4435291471276662
# 3.947  -6.16244635401942   -0.6610562966068518
# 3.948 -6.263838858776686   -0.9320538608746926
# 3.949 -5.939667608341692    -1.031906028819313
#  3.95 -5.957614010370997   -1.2993605571818758
#
# Clump 2489
#  TIME          X                   Y
# ----- -------------------- ------------------
#  3.95  -1.5950489727430062 -5.873958550558553
# 3.951   -1.407318601611269 -5.892865394221285
# 3.952  -1.6874506574842272 -6.265361043831737
# 3.953  -1.6015146673249259 -6.273358532634788
# 3.954  -1.3121918603021754 -6.245623216469639
# 3.955   -1.173241386037242 -6.274824921768263
# 3.956   -0.891595957370047 -6.306588807672981
# 3.957 -0.38151823469302043 -6.549292866996779
# 3.958  -0.2130125957945245 -6.542419822137453
# 3.959 -0.05837471063729991  -6.49367958697557
#  3.96  0.15213236648309966 -6.491655627933467
#
# Clump 2515
#  TIME         X                  Y
# ----- ------------------ ------------------
# 3.958  4.109052976590041  5.550568713954077
#  3.96  3.777582372670515  5.754784302605623
# 3.961 3.8711324599108465  5.362525553412062
# 3.962  3.613972525815883  5.557022795387098
# 3.966 2.8955640998127277  5.959711554951635
# 3.971 2.2406175517345712  6.338438545195699
# 3.972  1.592004710264574 6.2617229820368605
# 3.974 1.1918988115356588  6.317762619187896
# 3.975 1.5200504292157353  6.487246606391713
# 3.977 1.0542681225998682 6.5395057811250075
#
# Clump 2520
#  TIME         X                  Y
# ----- ------------------ ------------------
#  3.96  5.824143933461462 1.0286351358381474
# 3.962   6.07706652080499 0.9999874532700282
# 3.963  6.044807327549407 1.1792995465033165
# 3.964  6.114849502999674 1.3113628154662267
# 3.965  6.095963455428225 1.5809388847983494
# 3.966  5.869713080741796 1.8074519094220058
#  3.97 5.4904758673869924 2.4550538198664844
# 3.971 5.4358855400268205  2.853648908774024
# 3.972  5.463611293874663     3.135876652093
# 3.975  5.172673317873942  3.697578779116344
# 3.976  5.065100641356803   3.74413014182272
#
# Clump 2532
#  TIME          X                    Y
# ----- -------------------- -------------------
# 3.964  -0.2868270410719283  -6.763491929153748
# 3.965 -0.12713027264342378  -6.783526295466371
# 3.966  0.05922816424282127  -6.764366145337718
# 3.967  0.18577053233002783 -6.7857034470131845
# 3.968   0.4306948314408735  -6.740744202228695
# 3.969   0.6105681951220522  -6.703648156080218
#  3.97   0.7788994971069191  -6.686113412631031
# 3.971   0.9382384018629658  -6.700892103120006
# 3.972   1.1500996297909114  -6.614354436578462
# 3.973    1.287152316248624  -6.622639331079799
# 3.974   1.5210995409225283 -6.5628461369468365
# 3.976   1.9379307616964911 -6.3832127196871165
# 3.977    2.136707669621875  -6.324231262688021
# 3.978    2.235642009856648  -6.315939089245147
#  3.98    2.468586877713312  -5.924239600087333
# 3.981   2.5231954475833005  -5.846857879115951
# 3.983     2.92551577208001 -5.6457002173207815
# 3.988   3.9656382889704624  -5.346956863879669
# 3.991   4.2624538567880865  -5.218666008362514
# 3.993   4.3912050714363655  -5.528556472224745
# 3.994    4.609070986454431  -5.575908955058604
# Clump 2535
#  TIME          X                  Y
# ----- ------------------- -----------------
# 3.966  1.9645375622684815 5.569441750713324
# 3.967   1.781098069507119 5.664236520395938
# 3.968  1.5899705169514544 5.718588558992137
# 3.969  1.4500611829140484 5.809288856571032
#  3.97   1.221925596417494 5.817780690149471
# 3.971  1.0663730675903536 5.881302536362121
# 3.976  0.7127804571500673 6.067723809968898
# 3.978 0.38061272957003484 6.195827458014046
# 3.979  0.6970945010035908 6.509713737121913
#  3.98  0.4564790642915843 6.616203709260316
# 3.984 -0.2590844943818824 6.621040452284084
#
# Clump 2602
#  TIME          X                   Y
# ----- ------------------- --------------------
#  3.96 -1.8240149320978354    6.428872591162054
# 3.961  -2.014800558140368    6.385828977643746
# 3.962 -2.2195389640300083    6.330091155350752
# 3.963 -2.3875486521899916    6.268648022145794
# 3.964  -2.588711238827356    5.961546028189093
# 3.965  -2.776093267174489    5.823758788114545
# 3.966 -3.0988944960781573     5.50507719189761
# 3.967 -3.2527492776211915    5.404582177661709
# 3.968 -3.4209685871525353    5.374904682412222
# 3.969  -3.495791075993217    5.282245594785923
#   ...                 ...                  ...
# 3.989 -6.0175850393455415   1.5606970633623323
#  3.99  -6.059304441991872   1.2248358692459473
# 3.991  -6.094568579400364   0.9344966052472812
# 3.992 -6.0679932281867845   0.8953286374859422
# 3.993  -6.072828551988116   0.6046521981605447
# 3.994   -6.11380967355166  0.27906272818345346
# 3.995  -6.109711404506997   0.0180932015528336
# 3.996   -6.11328872221676  -0.2218646877457046
# 3.997 -6.1009586852816255 -0.40532141176057634
# 3.998  -6.085177235957981  -0.5548448224224743
# 3.999 -6.0822524665048014  -0.8544826024773656
# Length = 37 rows

# %%
plt.figure(figsize=(10,10))
snapshot = FitsRead(18)
colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(newClumps))]
for clump,c in zip(newClumps,colors):
    x = []
    y = []
    for index in clump[0]:
        ind = int(index)
        x.append(snapshot['X'][ind])
        y.append(snapshot['Y'][ind])
    plt.scatter(x,y,color=c)
im2, xedges, yedges  = np.histogram2d (-snapshot['Y'],snapshot['X'],(100,100),range=[[-7,7],[-7,7]])
extent2 = [yedges[0], yedges[-1], -xedges[-1], -xedges[0]]
plt.imshow(np.log(im2), cmap='Greys_r', extent=extent2)
# Out:
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in log

# %%
positions = (tbl['x_peak'], tbl['y_peak'])
apertures = phot.CircularAperture(positions, r=3)
norm = simple_norm(data, 'sqrt', percent=99.9)
plt.figure(figsize=(10,10))
plt.imshow(data, cmap='Greys_r', origin='lower', norm=norm)
apertures.plot(color='#0547f9', lw=1.5)
plt.xlim(0, data.shape[1]-1)
plt.ylim(0, data.shape[0]-1)
# Out:
# (0, 99)

# %%
# Read snapshot file
snapshot = FitsRead(16)
r = np.sqrt(snapshot['X']**2+snapshot['Y']**2)
theta = np.arctan2(snapshot['Y'],snapshot['X'])
vth = -snapshot['VX']*np.sin(theta)+snapshot['VY']*np.cos(theta)
snapshot.add_column(r,name='R')
snapshot.add_column(vth,name='VTH')

# Interpolate vDisk as a function of rho
bins = int(np.max(r)/2.5)
medians,binEdges,binNumber = stats.binned_statistic(r,vth,'median',bins)
edges = []
for i in range(0,len(binEdges)-1):
    edges.append((binEdges[i]+binEdges[i+1])/2)
w = np.isnan(medians)
medians[w] = 0
vDisk1 = UnivariateSpline(edges,medians,~w)

#Snapshot density plot
plt.figure(figsize=(10,10))
imS, xedgesS, yedgesS  = np.histogram2d (-snapshot['Y'],snapshot['X'],(100,100),range=[[-7,7],[-7,7]])
extentS = [yedgesS[0], yedgesS[-1], -xedgesS[-1], -xedgesS[0]]
plt.imshow(np.log(imS),extent=extentS)

#Clump 1 (2.77,3.5)
inclump1 = ((snapshot['X']-2.77)**2+(snapshot['Y']-3.5)**2<0.01)
clump1 = snapshot[inclump1]
#plt.figure(figsize=(10,10))
#imC1, xedgesC1, yedgesC1  = np.histogram2d (-clump1['Y'],clump1['X'],(100,100))
#extentC1 = [yedgesC1[0], yedgesC1[-1], -xedgesC1[-1], -xedgesC1[0]]
#plt.imshow(np.log(imC1),extent=extentC1)

#Clump 2 (0.9,4.23)
inclump2 = ((snapshot['X']-0.9)**2+(snapshot['Y']-4.23)**2<0.01)
clump2 = snapshot[inclump2]

#Clump 3 (-3.97,0.42)
inclump3 = ((snapshot['X']+3.97)**2+(snapshot['Y']-0.42)**2<0.01)
clump3 = snapshot[inclump3]

#Clump 4 (-2.96,4.3)
inclump4 = ((snapshot['X']+2.96)**2+(snapshot['Y']+4.3)**2<0.01)
clump4 = snapshot[inclump4]

#Plot vDisk and density plot
plt.figure(figsize=(10,10))
imVth, xedgesVth, yedgesVth  = np.histogram2d (-vth,r,(100,100),range=[[-400,50],[0,20]])
extentVth = [yedgesVth[0], yedgesVth[-1], -xedgesVth[-1], -xedgesVth[0]]
plt.imshow(np.log(imVth),extent=extentVth)
x = np.arange(0,20)
plt.plot(x,vDisk(x),color='r')
#plt.scatter(clump1['R'],clump1['VTH'])
plt.axes().set_aspect(20/450, 'datalim')

#Plot Vth vs r density plot for clumps
plt.figure(figsize=(10,10))
imV1, xedgesV1, yedgesV1  = np.histogram2d (-clump1['VTH'],clump1['R'],(100,20))
extentV1 = [yedgesV1[0], yedgesV1[-1], -xedgesV1[-1], -xedgesV1[0]]
plt.imshow(np.log(imV1),extent=extentV1)
imV2, xedgesV2, yedgesV2  = np.histogram2d (-clump2['VTH'],clump2['R'],(100,20))
extentV2 = [yedgesV2[0], yedgesV2[-1], -xedgesV2[-1], -xedgesV2[0]]
plt.imshow(np.log(imV2),extent=extentV2)
imV3, xedgesV3, yedgesV3  = np.histogram2d (-clump3['VTH'],clump3['R'],(100,20))
extentV3 = [yedgesV3[0], yedgesV3[-1], -xedgesV3[-1], -xedgesV3[0]]
plt.imshow(np.log(imV3),extent=extentV3)
imV4, xedgesV4, yedgesV4  = np.histogram2d (-clump4['VTH'],clump4['R'],(100,20))
extentV4 = [yedgesV4[0], yedgesV4[-1], -xedgesV4[-1], -xedgesV4[0]]
plt.imshow(np.log(imV4),extent=extentV4)
plt.plot(x,vDisk(x),color='r')
plt.xlim(3.5,5.5)
plt.axes().set_aspect(2/450, 'datalim')
# Out:
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: RuntimeWarning: divide by zero encountered in log
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:49: RuntimeWarning: divide by zero encountered in log
# C:\Users\betha\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: divide by zero encountered in log
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:62: RuntimeWarning: divide by zero encountered in log
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:65: RuntimeWarning: divide by zero encountered in log
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:68: RuntimeWarning: divide by zero encountered in log
