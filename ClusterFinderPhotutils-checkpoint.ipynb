# %%
import photutils as phot
from astropy.stats import sigma_clipped_stats
from astropy.table import Table
import numpy as np
import scipy.stats as stats
from scipy.interpolate import UnivariateSpline
import pylab as plt
from astropy.visualization import simple_norm
from astropy.io import fits

# %%
def FitsRead(time):
    # Read the fits file for that time and return table of stars
    if time < 10:
        time = '0{0}'.format(time)
    try:
        fileName = 'coords.starsandgas.chemrun733DiffFB10T1.0.00{0}0.fits'.format(time)
        read = Table.read(fileName,1)
        stars = (read['P']=='s')
        cat = read[stars]
    except:
        try:
            fileName = 'coords.chem733DiffFB10T1.0.00{0}0.fits'.format(time)
            cat = Table.read(fileName,1)
        except:
            raise ValueError('No file')
    return cat

# %%
def RotateBack(x,y,dtime,vcirc):
    # Rotate stars back in time
    lindist = vcirc*dtime #linear distance traveled in time interval
    rho = (x**2+y**2)**(1/2) #distance from z axis
    nrot = lindist/(2*np.pi*rho) #number of rotations
    nrotints = []
    for i in nrot:
        nrotints.append(int(i))
    nrotints = np.array(nrotints) #integer number of rotations
    rotangle = nrot-nrotints #partial rotation
    rotanglerad = 2*np.pi*rotangle #convert to radians
    xrot = x*np.cos(-rotanglerad)-y*np.sin(-rotanglerad) #x position at beginning of interval
    yrot = x*np.sin(-rotanglerad)+y*np.cos(-rotanglerad) #y position at beginning of interval
    return xrot,yrot

# %%
def make_unique(original_list):
    # Takes a list and returns it without duplicate entries
    unique_list = []
    [unique_list.append(obj) for obj in original_list if obj not in unique_list]
    return unique_list

# %%
def StarsInInterval(starlist,start,end):
    # Returns table of stars that formed within time interval
    tRange = (starlist['TFORM']>start,starlist['TFORM']<end)
    inRange = np.array(np.zeros(len(tRange[0])),dtype=bool) 
    for i in range(0,len(inRange)):
        if tRange[0][i] and tRange[1][i]:
            inRange[i] = True            #true for stars that formed in time interval
    newStars = starlist[inRange]
    return newStars

# %%
def FindPeaks(data,z):
    # Find peaks in 2D array of data
    statsdata = [] #only includes data points with density greater than 1 to calculate threshold
    for i in data:
        for j in i:
            if j>2:
                statsdata.append(j)
    mean, median, std = sigma_clipped_stats(statsdata, sigma=3.0)
    threshold = median + (z * std) #minimum density for a peak
    tbl = phot.find_peaks(data, threshold, box_size=11) #table of x index, y index, and density for peaks
    tbl['peak_value'].info.format = '%.8g'
    return tbl

# %%
def CombineClose(positions):
    # Combine multiple peaks in the same star cluster
    peaks = []
    closelist = []
    for i in range(0,len(positions[0])):
        jlist = [i] #a list containing that peak and other peaks near it
        for j in range(i+1,len(positions[0])):
            xi = positions[0][i]
            yi = positions[1][i]
            xj = positions[0][j]
            yj = positions[1][j]
            dist2 = (xi-xj)**2+(yi-yj)**2
            if dist2<0.1:
                jlist.append(j)
        closelist.append(jlist) #a list where each element is a list of nearby peaks
    for i in range(0,len(closelist)):
        if len(closelist[i])>1:
            for j in closelist[i]:
                if i==j:
                    continue
                closelist[j] = closelist[0]
    closelist = make_unique(closelist) #remove elements of closelist that contain the same peaks
    for i in closelist:
        sumx = 0
        sumy = 0
        for j in i:
            sumx = sumx+positions[0][j]
            sumy = sumy+positions[1][j]
        meanx = sumx/len(i) #mean x position of a close group of peaks
        meany = sumy/len(i) #mean y position of a close group of peaks
        peaks.append([meanx,meany])
    xcoords = []
    ycoords = []
    for peak in peaks:
        xcoords.append(peak[0])
        ycoords.append(peak[1])
    xcoords = np.array(xcoords) #array of peak x coordinates
    ycoords = np.array(ycoords) #array of peak y coordinates
    peaks1 = (xcoords,ycoords)
    return peaks1

# %%
def MeanPeaks(starlist,positions):
    # Make the x and y positions of the clumps equal to the mean x and y positions of the stars, rather than peak location
    x = []
    y = []
    for i in range(0,len(positions[0])):
        inclump = ((starlist['XROT']-positions[0][i])**2+(starlist['YROT']-positions[1][i])**2<0.09) #true for stars within
                                                                                                     #aperture
        clump = starlist[inclump] #only includes stars in clump
        x.append(np.mean(clump['XROT']))
        y.append(np.mean(clump['YROT']))
    x = np.array(x) #array of mean x coordinates of clump
    y = np.array(y) #array of mean y coordinates of clump
    meanPositions = (x,y)
    return x,y,meanPositions

# %%
def TrackClumps(oldClumps,xcoords,ycoords,stars):
    # Match clumps in current timestep to clumps in previous timesteps
    leftx = xcoords
    lefty = ycoords
    lefti = []
    clumps = oldClumps
    for i in range(0,len(leftx)):
        lefti.append(i)
    if len(clumps)>0:
        for skip in range(1,6): #run through the previous 5 timesteps
            clumpsrho = (leftx**2+lefty**2)**(1/2)
            clumpsvcirc = vDisk(clumpsrho)
            cxrot,cyrot = RotateBack(leftx,lefty,skip*dt,clumpsvcirc) #move clumps back in time
            xleft = []
            yleft = []
            ileft = []
            for i in range(0,len(cxrot)): #run through clumps in current timestep
                for clump in clumps: #run through clumps from previous timesteps
                    newest = clump[len(clump)-1] #[time,x,y] of the most recent location of the clump
                    if newest[0]==round(start-skip*dt,3): #only look at clumps that were found recently
                        xi = cxrot[i]
                        yi = cyrot[i]
                        xj = newest[1]
                        yj = newest[2]
                        if (xi-xj)**2+(yi-yj)**2<0.36 and clumpsrho[i]>0.3:
                            inclump = ((stars['XROT']-leftx[i])**2+(stars['YROT']-lefty[i])**2<0.09)
                            clumpStars = stars[inclump] #only includes stars in clump
                            clump.append([start,xcoords[lefti[i]],ycoords[lefti[i]]])
                            clump[0] = clump[0]+list(clumpStars['INDEX'])
                            clump[0] = make_unique(clump[0])
                            break
                    if clump==clumps[len(clumps)-1]: #make a list of clumps that do not match clumps seen earlier
                        xleft.append(leftx[i])
                        yleft.append(lefty[i])
                        ileft.append(lefti[i])
            leftx = np.array(xleft)
            lefty = np.array(yleft)
            lefti = ileft
    for i in range(0,len(lefti)): #add clumps that don't match older ones to the end of the list
        if leftx[i]**2+lefty[i]**2>0.09:
            inclump = ((stars['XROT']-leftx[i])**2+(stars['YROT']-lefty[i])**2<0.09)
            clumpStars = stars[inclump] #only includes stars in clump        
            clumps.append([list(clumpStars['INDEX']),[start,xcoords[lefti[i]],ycoords[lefti[i]]]])
    return clumps

# %%
# Read txyz file
txyz = Table.read('txyzform.fits',1)
index = np.linspace(0,len(txyz)-1,len(txyz))
txyz.add_column(Table.Column(index),name='INDEX')
rho = np.sqrt(txyz['XFORM']**2+txyz['YFORM']**2)
txyz.add_column(rho,name='RHO')
start = 1.5
dt = 0.001
clumps = []
oldClumps = []

for refTime in range(15,41):
    print('refTime = {}'.format(refTime))
    # Read snapshot file
    snapshot = FitsRead(refTime)
    r = np.sqrt(snapshot['X']**2+snapshot['Y']**2)
    theta = np.arctan2(snapshot['Y'],snapshot['X'])
    vth = -snapshot['VX']*np.sin(theta)+snapshot['VY']*np.cos(theta)
    snapshot.add_column(r,name='R')
    snapshot.add_column(vth,name='VTH')

    # Interpolate vDisk as a function of rho
    bins = int(np.max(r)/2.5)
    medians,binEdges,binNumber = stats.binned_statistic(r,vth,'median',bins)
    edges = []
    for i in range(0,len(binEdges)-1):
        edges.append((binEdges[i]+binEdges[i+1])/2)
    w = np.isnan(medians)
    medians[w] = 0
    vDisk = UnivariateSpline(edges,medians,~w)

    while round(start*10)==refTime and start<4:
        #Find stars that formed in time interval
        end = start+5*dt
        newStars = StarsInInterval(txyz,start,end)
        outOfCenter = (newStars['RHO'] > 0.15)
        newStars = newStars[outOfCenter]

        # Move stars back in time to beginning of interval
        vcirc = vDisk(newStars['RHO'])
        dtime = newStars['TFORM']-start
        xrot,yrot = RotateBack(newStars['XFORM'],newStars['YFORM'],dtime,vcirc)
        newStars.add_column(xrot,name='XROT')
        newStars.add_column(yrot,name='YROT')
        im, xedges, yedges  = np.histogram2d (-yrot,xrot,(50,50))
        dx = xedges[1]-xedges[0]
        dy = yedges[1]-yedges[0]
        extent = [yedges[0], yedges[-1], -xedges[-1], -xedges[0]]

        # Find peaks in density
        tbl = FindPeaks(im,2)
        
        if len(tbl)>0:
            # Combine clumps in the same place
            peakPositions = (yedges[tbl['x_peak']]+dy/2, -xedges[tbl['y_peak']]-dx/2)
            peaks = CombineClose(peakPositions)

            # Make clump positions the mean x and y of stars in the clump
            xcoords,ycoords,positions = MeanPeaks(newStars,peaks)
            xcoords,ycoords,positions = MeanPeaks(newStars,positions)

            # Track clumps through time
            clumps = TrackClumps(clumps,xcoords,ycoords,newStars)

            # Plot density plots with clumps
            #apertures = phot.CircularAperture(peaks, r=0.3)
            #norm = simple_norm(im, 'sqrt', percent=99.9)
            #plt.figure(figsize=(10,10))
            #plt.imshow(im, cmap='Greys_r', norm=norm, extent=extent)
            #apertures.plot(color='#0547f9', lw=1.5)
            #plt.title("{0} million years".format(int(start*1000)))

        start = round(start+dt,3)
    newClumps = []
    for clump in clumps:
        if clump[len(clump)-1][0] > start-5*dt:
            newClumps.append(clump)
        elif len(clump) > 10:
            oldClumps.append(clump)
    clumps = newClumps
lastClumps = []
for clump in clumps:
    if len(clump) > 10 or clump[len(clump)-1][0] > start-5*dt:
        lastClumps.append(clump)
clumps = oldClumps+lastClumps
for id in range(0,len(clumps)):
    clumps[id] = [id+1]+clumps[id]
print('{0} clumps total'.format(len(clumps)))
# Out:
# refTime = 15
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 16
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 17
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 18
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 19
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 20
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 21
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 22
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 23
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 24
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 25
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 26
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 27
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 28
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 29
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 30
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 31
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 32
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 33
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 34
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 35
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 36
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 37
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 38
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 39
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# refTime = 40
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# 157 clumps total

# %%
#Plot locations of clumps through time
plt.figure(figsize=(10,10))
for clump in clumps:
    x = []
    y = []
    for j in range(2,len(clump)):
        x.append(clump[j][1])
        y.append(clump[j][2])
    plt.plot(x,y)
    #plt.scatter(x,y)
plt.imshow(im, cmap='Greys_r', extent=extent)

# %%
tList = []
xList = []
yList = []
idList1 = []
iList = []
idList2 = []
for clump in clumps:
    for j in range(2,len(clump)):
        txy = clump[j]
        tList.append(txy[0])
        xList.append(txy[1])
        yList.append(txy[2])
        idList1.append(clump[0])
    for star in clump[1]:
        iList.append(star)
        idList2.append(clump[0])

hdu1 = fits.PrimaryHDU()
        
idcol1 = fits.Column(name="CLUMPID", format='J', array=idList1)
tcol = fits.Column(name="TIME", format='E', array=tList)
xcol = fits.Column(name="X", format='E', array=xList)
ycol = fits.Column(name="Y", format='E', array=yList)
hdu2 = fits.BinTableHDU.from_columns([idcol1,tcol,xcol,ycol])

idcol2 = fits.Column(name="CLUMPID", format='J', array=idList2)
icol = fits.Column(name="INDEX", format='J', array=iList)
hdu3 = fits.BinTableHDU.from_columns([idcol2,icol])

hdul = fits.HDUList([hdu1,hdu2,hdu3])
hdul.writeto('clumps3.fits')

# %%
fits.info('clumps3.fits')
# Out:
# Filename: clumps3.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1                1 BinTableHDU     16   9634R x 4C   [J, E, E, E]
#   2                1 BinTableHDU     12   211980R x 2C   [J, J]

# %%
# Print x and y locations of clumps
for clump in clumps:
    t = Table(names=('TIME','X','Y'))
    for j in range(2,len(clump)):
        t.add_row((clump[j][0],clump[j][1],clump[j][2]))
    print('Clump {0}'.format(clump[0]))
    print(t)
    print()
# Out:
# Clump 1
#  TIME         X                   Y
# ----- ------------------ --------------------
# 1.501 4.9298466790194135  -1.1358579951831498
# 1.502  4.967175427693803  -0.9955645273305751
# 1.503  5.008058916235222  -0.8319258828035548
# 1.504  5.065326418939714  -0.6253991358926788
# 1.505  5.085521050710526  -0.4822491981909103
# 1.506  5.119938328077973   -0.284296355017236
# 1.507  5.119130081378302 -0.08901483863670047
# 1.508 5.1304960859057465  0.03185083853936157
# 1.509  5.111693552782669  0.23385805234343254
#  1.51  5.128218786223135   0.4461177564003237
# 1.511  5.076710065437352   0.6043788317867486
# 1.512  5.054673202948981    0.778045517088088
# 1.513   5.04732137807825    1.096656306022077
#
# Clump 2
#  TIME          X                  Y
# ----- ------------------- ------------------
# 1.533   3.100175366610033  4.047349276927785
# 1.535  3.0404105669150967   4.18645755270569
# 1.536  2.9322221119491796  4.186015319901743
# 1.537  2.7873961023149523  4.349401760704733
# 1.538  2.6469034179100275  4.395869067514388
# 1.539  2.3796386761287738  4.579089651066311
#  1.54   2.200235686184661  4.682512132216723
# 1.541  2.0560996627806336  4.745716368604701
# 1.542  1.8619847852753653  4.798379829481932
# 1.543  1.7140406248358353 4.8512180147559585
# 1.544  1.5258936032497525  4.912892503234043
# 1.545   1.307963127020282  4.963757338966273
# 1.546  1.1499431307248513  4.996487421519417
# 1.547  0.9940854790748209  5.045686093767172
# 1.548   0.825701152101406  5.057608815606432
# 1.549   0.634715671762289  5.073456773859897
#  1.55 0.41316410636109735  5.043960711461036
#
# Clump 3
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.558 -1.0302885267092488    4.82445138809039
# 1.562 -1.6473260092202051   4.592968006770958
# 1.563  -1.790547333188338   4.530126618895834
# 1.564  -1.948161699388174   4.453598684384835
# 1.565 -2.0972491945554657   4.387290249240145
# 1.566 -2.2894274309358735   4.239193806451243
# 1.567  -2.575084255823686   4.109456322621719
# 1.568  -2.731350283862302  3.9701010014128713
# 1.569 -2.8479638252876978  3.8569229459633196
#  1.57  -2.997675815813459  3.7858741984588122
#   ...                 ...                 ...
# 1.605 -4.0976050546462295  -2.055724057359432
# 1.607 -3.9175719237622024 -2.3801469684964234
# 1.609  -3.692685336864213  -2.695115079214532
#  1.61  -3.583106500216246   -2.83011601812221
# 1.611 -3.4592009178113945  -2.976568268992093
# 1.612 -3.3400483574177673 -3.1366005625084528
# 1.616  -2.764160823775754 -3.6091095050942057
# 1.621 -1.9873773264754926 -4.0823111346022944
# 1.622 -1.8120454422131678   -4.15381432668345
# 1.624  -1.487973197391287  -4.267707972432228
# 1.625 -1.3311558749503887 -4.3177707622563615
# Length = 51 rows
#
# Clump 4
#  TIME          X                   Y
# ----- ------------------- -------------------
#   1.5 -3.8325034663434114  -2.261198737982124
# 1.501 -3.7509953976553603 -2.4010690202439644
# 1.502  -3.650569834405383    -2.5587114923308
# 1.503 -3.5537974509073256  -2.694399455833148
# 1.504  -3.446904134226015  -2.852370447381483
# 1.505 -3.3193389556188384  -3.014067639225646
# 1.506 -3.2065872172304988 -3.1378315319457593
# 1.507  -3.059509881600355 -3.2844293341655995
# 1.508  -2.929381173624958  -3.411993605361357
# 1.509  -2.788791952623082   -3.53706381330977
#   ...                 ...                 ...
# 1.699   4.486171924235998 -2.4532763656871475
#   1.7   4.557159202406238 -2.2980351987399135
# 1.701  4.6212980197108084 -2.1227278718967417
# 1.702   4.675734054155474 -1.9337522863319425
# 1.703  4.7220453075868685 -1.7752945395055444
# 1.704   4.753213406163777 -1.5932125065987788
# 1.705   4.790936978284019  -1.426190314232467
# 1.706   4.800886476361919 -1.2366356886756367
# 1.707   4.807597469172848 -1.0404582144155008
# 1.708   4.817907533668325 -0.8706579065274884
# 1.709   4.802887012188741 -0.6809810400944524
# Length = 210 rows
#
# Clump 5
#  TIME           X                   Y
# ----- --------------------- ------------------
# 1.501   -3.1865265961226794  3.991874438161208
# 1.502   -3.2816341166611043  3.907128928064019
# 1.503   -3.3656199767443673  3.816433279524675
# 1.505    -3.661384367527262 3.5501008192663317
# 1.506    -3.839302289200162 3.3097706289347535
# 1.508    -4.007870601908226 3.2277624740714086
#  1.51    -4.281170576991656 2.6903657070560243
# 1.511    -4.421089972491373  2.648450162465299
# 1.512    -4.423034533255651  2.430430293648621
# 1.513    -4.454408886882582  2.278246633147843
#   ...                   ...                ...
# 1.645    1.0342520050222703  4.769736216667573
# 1.646    0.8796347545636166  4.792920069111033
# 1.647    0.6808069231967252  4.787071450687719
# 1.648    0.5116451560904055  4.795312868570067
# 1.649    0.3219307798531561  4.783096868975544
#  1.65   0.13339332754770955  4.763333738690679
# 1.651 -0.015411402717552994  4.755554499417134
# 1.652   -0.2155086676559109   4.72206795777379
# 1.653   -0.3742032054368808 4.6841150127214215
# 1.655   -0.7561890017062765  4.560170348765465
# 1.658   -1.2497298789049347  4.378872677750994
# Length = 134 rows
#
# Clump 6
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.597  -2.076529956679426 -3.3232696499221075
#   1.6 -1.6146084844544828 -3.5206232568325113
# 1.602 -1.2227272315076303 -3.6091523738601468
# 1.606 -0.5012280051855801 -3.7089329772332302
# 1.607 -0.2991121734074544 -3.7089681241726375
# 1.608 -0.1272737285532703  -3.697907092518358
# 1.609 0.06457178215415664  -3.676173447238759
#  1.61  0.2315604044917059 -3.6612687921539595
# 1.611  0.4141620093275597  -3.622030088554954
# 1.612  0.6052026418497511 -3.5637023161838117
#   ...                 ...                 ...
# 1.637  3.1712800943558426 0.06018328157771867
# 1.638  3.1519036061767816 0.24943355558775138
# 1.639  3.1220001830215143  0.4648290326010829
#  1.64   3.076680911218286  0.6804131191537165
# 1.641   3.033798731192343  0.8656948736388627
# 1.642   2.973528275594116  1.0403197905424955
# 1.643  2.9091216550469783   1.206297353795117
# 1.644    2.80735991839912  1.3989117830274433
# 1.645   2.699573026601643  1.5811248536912383
# 1.646   2.597827193878652  1.7311844043161313
# 1.649   2.219381184908442  2.2395559480622658
# Length = 45 rows
#
# Clump 7
#  TIME           X                    Y
# ----- --------------------- -------------------
# 1.603   -3.5242345681456317  3.1526262159019756
# 1.604    -3.608938790672149  3.0354314075528417
# 1.605    -3.672970517853376   2.928035811372423
# 1.606   -3.7815716223084306  2.7835485144246213
# 1.607    -3.876758290140233   2.614143493843359
# 1.608   -3.9227658665596263   2.509502568250769
# 1.609    -4.043421647454864   2.334713889960004
# 1.612    -4.235158694508604  1.8010216824943994
# 1.613    -4.279921955657762   1.593862418494359
# 1.614    -4.318295187846028  1.4167083138073553
#   ...                   ...                 ...
# 1.628    -4.090087897572006 -1.1035805027325467
#  1.63    -3.775632900746568 -1.5359422383722958
# 1.633   -3.5059974025422522  -1.947992508226348
# 1.636    -3.043402323810747 -2.3070826797323223
# 1.637   -2.9514576642151673   -2.43986663024392
# 1.639   -2.5852903619666034  -2.690343895144321
#  1.64    -2.526890754441928 -2.7712395528683516
# 1.641    -2.544927008475962 -2.9149482476641624
# 1.643    -2.036070423712014 -3.1233358546259553
# 1.648   -1.0132539361250357  -3.463801506407228
# 1.652 -0.061757780465606635  -3.511113465707022
# Length = 30 rows
#
# Clump 8
#  TIME          X                   Y
# ----- -------------------- ------------------
#   1.5   0.7346485741825289  5.065454748615629
# 1.501   0.5344673051292643  5.113510340042393
# 1.502  0.33114571517947233  5.155902000216862
# 1.503  0.17196719456636228  5.168066851387158
# 1.504 -0.02070929113635366  5.180397609861836
# 1.505  -0.2260562248234079  5.184210866079932
# 1.506 -0.39906192125660306  5.178697559850703
# 1.507   -0.594826918839607  5.175237146634788
# 1.508  -0.7470482111709722  5.145310500350899
# 1.509  -0.9578853813016895  5.110379979391937
#   ...                  ...                ...
# 1.765  -0.5607424469531664  2.186111830998307
# 1.766  -0.7174855100773982  2.126899655058537
# 1.767  -0.8940174402633759  2.048043496371099
# 1.768  -1.0488104483018814 1.9672847925114243
# 1.769  -1.2207645271708358 1.8594800441060741
#  1.77  -1.3821002449069781  1.724524284278062
# 1.771  -1.5147998741944078  1.601608222783473
# 1.772  -1.6441214449400794 1.4625363641115499
# 1.773  -1.7517944228440459 1.3272887158043751
# 1.774  -1.8660274890886699 1.1802457865385052
# 1.775  -1.9876995220919238 1.0115792933970738
# Length = 271 rows
# Clump 9
#  TIME          X                   Y
# ----- ------------------- -------------------
#   1.5  0.9775767588303711  -4.358749781344653
# 1.502  1.3513969557375862  -4.247646827587965
# 1.503   1.512114173661068 -4.2008547781999255
# 1.505    1.85903283909932  -4.110499631060274
# 1.506  1.9785605452059727  -4.046092560295122
# 1.507  2.1248591146700377 -3.9459071265142747
# 1.508   2.278271912410976 -3.8474460682869887
# 1.509  2.4391042641600884 -3.7330883813185327
#  1.51  2.5532465963849504 -3.6277091593935893
# 1.511   2.673165794324059 -3.5380577262433577
#   ...                 ...                 ...
# 1.781 -2.6898438952498376  -2.644794991381595
# 1.782 -2.5620892606290715 -2.7523630716031464
# 1.783  -2.432077282778504 -2.8528263876265036
# 1.784 -2.2673818140441053 -2.9679767519140436
# 1.785  -2.121305276460982  -3.059676550470539
# 1.786 -1.9882778279786504  -3.132388208239254
# 1.787 -1.8352956132322977  -3.202562324887184
# 1.788 -1.6774718460249696 -3.2743784405241882
# 1.789 -1.5066218245232466  -3.296827867164497
#  1.79 -1.3482195098755552 -3.3345726018329462
# 1.791 -1.1924648476475608 -3.3773369626573495
# Length = 283 rows
#
# Clump 10
#  TIME          X                    Y
# ----- -------------------- -------------------
# 1.734   1.0736494224754485 -3.8212395932712613
# 1.735   1.2281505131123056  -3.748482023216024
# 1.736   1.4005847465513417 -3.6805225040193257
# 1.737   1.5700494738615105 -3.5796828212483653
# 1.738   1.6984743767783557  -3.495704180325009
# 1.739     1.81070156654766  -3.343689052906289
#  1.74   1.9457750230433253 -3.2217897387189742
# 1.741    2.073174537078715  -3.111179668688227
# 1.742    2.199111871432492  -2.971293789856834
# 1.743    2.350624319040768  -2.868726196644383
#   ...                  ...                 ...
# 1.801  -1.9612305891108575  -0.700032546796605
# 1.802  -1.9146646376086869 -0.8574910149058028
# 1.803  -1.8490877024158743 -0.9995443426515326
# 1.804  -1.7795173372650597 -1.1817650967911826
# 1.806  -1.4409276922537775 -1.4394477890845596
# 1.808   -1.180449191966039 -1.6639279781308474
# 1.809  -1.0126984534481276 -1.7829204740048048
#  1.81  -0.8509419584459044 -1.9012952293565364
# 1.811  -0.6637936372201866 -2.0084875983279913
# 1.812 -0.49523511673890275 -2.0621870134693223
# 1.813 -0.33022991074973074   -2.10153513015077
# Length = 72 rows
#
# Clump 11
#  TIME         X                   Y
# ----- ------------------ --------------------
# 1.742 4.8748904327704246  -1.5654801542047503
# 1.743  4.911470269177017  -1.4495134077370024
# 1.744  4.928041111298644  -1.1956314789713265
# 1.746   4.99443382978433  -0.8558125465893128
# 1.747  5.001327320384462  -0.5865734585434565
# 1.748  5.030807991667112  -0.4567979505486873
# 1.749 5.0632224870922355   -0.236918562168891
#  1.75  5.060510053986763 -0.09394609392609204
# 1.751  5.025650773486438  0.11212370945219717
# 1.752  4.999259465692086   0.3139889446415091
# 1.753  5.025199040688356  0.41458990013943475
# 1.754  5.368207708296708   0.1939686470013367
#
# Clump 12
#  TIME          X                    Y
# ----- -------------------- --------------------
# 1.751   0.0938896431439296  -0.2973143956900858
# 1.755  0.08518267863430444  -0.3066969858228389
# 1.756  0.06513892504694634 -0.29618060850122857
# 1.757  0.09099812802181198  -0.2990287392849653
# 1.758   0.1789153560917808  -0.2823311835818496
# 1.759  0.11345242576692488 -0.32130643063335634
#  1.76  0.19621156563137282 -0.31335116093156967
# 1.761   0.2766423655545354  -0.2657902055594481
# 1.762  0.30982410934431864 -0.25071672604655004
# 1.763  0.26200981654402666 -0.28333305104061485
#   ...                  ...                  ...
# 1.811  -0.0935316925578302   0.5418165773652255
# 1.812 -0.05477140183706165   0.5448895443939311
# 1.813 -0.10905191375495384   0.5418708630092894
# 1.814 -0.15275967615611788   0.5176009552951328
# 1.815  -0.2802023428723092   0.4790135008743736
# 1.816  -0.2653726863116567   0.4708845019012644
# 1.817 -0.15495278546824942  0.49404326667374726
# 1.818  -0.3117598579263725  0.44371442719513715
# 1.819 -0.28008020911664816    0.445109479708293
#  1.82  -0.3373062752516968   0.4140972607730406
# 1.821 -0.34331270435415123  0.39975734901542626
# Length = 68 rows
#
# Clump 13
#  TIME          X                   Y
# ----- ------------------- --------------------
# 1.802  -4.747972076474699    1.109178568978649
# 1.803  -4.782551585050492   0.9553251822598241
# 1.804  -4.805130034903682   0.7498755735606129
# 1.805  -4.807406922554005   0.5635794443186932
# 1.806  -4.806739791724179   0.4208687184168411
# 1.807  -4.793818826048957  0.16638647665386266
# 1.808  -4.785082253363004 -0.03318246957657608
# 1.809  -4.761222749001356 -0.22994433857823668
#  1.81  -4.486122207063074  -0.6087992914669491
# 1.811  -4.685343309127143  -0.6179034194732559
#   ...                 ...                  ...
# 1.827 -3.1973593822818254  -3.1847694825318693
# 1.828  -3.068282392764331  -3.3000621999022797
# 1.829  -2.918513825550963  -3.3938854179478626
#  1.83 -2.7960522337225577   -3.495996827126228
# 1.831  -2.581011714360623   -3.567256912740608
# 1.832 -2.3820424331807275   -3.627944202767013
# 1.833 -2.2062901557300765  -3.6820973324504167
# 1.835 -1.8524229407718136  -3.7724434204979578
# 1.836 -1.6497762922429606   -3.840221818946287
# 1.837   -1.49285928596052  -3.9021819886561087
# 1.838 -1.3468589527411001   -3.923506740827244
# Length = 36 rows
#
# Clump 14
#  TIME           X                    Y
# ----- --------------------- --------------------
# 1.821    1.0204126147417032  -0.9298992041114198
# 1.822    0.9132074939783535  -0.7926337963643046
# 1.823    1.0482559750012297  -0.6799347132999843
# 1.824    0.6775635088358611   -0.512178288034991
# 1.825    0.6859532094261452 -0.38314294193353304
# 1.826    0.6031162238639358 -0.22868994035447437
# 1.827    0.5839545683342623 -0.03993466360913122
# 1.828    0.5444683536724644  0.10322881383863151
# 1.829    0.3834454909423221   0.3108100520570195
#  1.83   0.22840649575442723  0.43752560921560874
# 1.831 -0.061934353140945204   0.5401859270333399
#
# Clump 15
#  TIME          X                  Y
# ----- ------------------- ------------------
#   1.5   4.414957421606191 1.1648456561965348
# 1.501   4.374215076687531 1.2718574924863737
# 1.503   4.244359917697849   1.56154260889724
# 1.504   4.106714144833319 1.7987376151691905
# 1.505  3.9764879830620457 1.9804428969928736
# 1.506  3.8960399900536364  2.189963362937421
# 1.507  3.8227219023300827  2.379615469382603
# 1.508  3.7676059711484213   2.51982925311566
# 1.509  3.6791144504655606  2.674367528165531
#  1.51   3.552183506006801  2.834153267843754
#   ...                 ...                ...
# 1.859 -2.1931738712149325 3.0189108759362897
#  1.86  -2.322413156720869  2.909738861095939
# 1.861  -2.442969165232571 2.7703770142036794
# 1.862  -2.571186114783352 2.6194377117085716
# 1.863 -2.6878169974204704  2.479411909967023
# 1.864 -2.7913515430652094 2.3178060180197066
# 1.865  -2.887701188888468  2.174248673261559
# 1.866 -2.9874381807507175 1.9742966868147704
# 1.867 -3.0596067517510295 1.7981236421539912
# 1.868  -3.124755026241027 1.6405136025967504
# 1.869 -3.1832535911731417  1.447592708161199
# Length = 369 rows
#
# Clump 16
#  TIME          X                    Y
# ----- -------------------- --------------------
# 1.832  -1.0577923309673345   0.5625157236810046
# 1.833  -1.1496901027496975   0.4139362829667325
# 1.834  -1.4608036448992294   0.1006702285222897
# 1.835  -1.4333646455744444 -0.02851672415260819
# 1.836  -1.5574407934041608  -0.3369478905230047
# 1.837    -1.57224054757691  -0.5745989953272596
# 1.838  -1.5316086081197027  -0.7549371841660575
# 1.839  -1.4949398404335013  -0.9936475455886457
#  1.84  -1.4158151567366262   -1.167245797870914
# 1.841  -1.3180482978192023  -1.3780485521456287
# 1.842  -1.1922826152474053  -1.5365588028012551
# 1.843     -1.0583860405788  -1.6433117604210805
# 1.844  -0.9032805184468828  -1.7449696009843354
# 1.845   -0.751889385996097  -1.8121323904751419
# 1.846   -0.581005239761238  -1.8566199341706633
# 1.847  -0.4075223616104945   -1.857022243540739
# 1.848  -0.2477047109238758  -1.8566745019472053
# 1.849 -0.08293547455408042    -1.80170669337986
#  1.85  0.07169294649118738  -1.7436957523072087
# 1.851  0.22739826902923774  -1.6763737704951185
# 1.852     0.35396922465243    -1.54093471101742
# 1.853  0.48483928413141336   -1.456016442820688
#
# Clump 17
#  TIME          X                    Y
# ----- -------------------- --------------------
# 1.842 -0.49479744513359186 -0.10312523248265702
# 1.843  -0.4676671178318341 -0.21354232002690016
# 1.844  -0.4918873148873839  -0.2020181697581147
# 1.845  -0.5105812371552112  -0.1932983712928596
# 1.846  -0.5294782156216886 -0.21070688168927207
# 1.847  -0.5131498944309726 -0.30398060507185604
# 1.848 -0.49602690042252734 -0.31124506421456594
#  1.85 -0.45312161774000675  -0.3564562462631592
# 1.854 -0.42952065186445304 -0.41432271196232845
# 1.855 -0.36924245891877616 -0.47999377696515594
# 1.856  -0.4220423684080677  -0.4935529247965647
# 1.857 -0.36175529763836434  -0.5549792881056903
# 1.858 -0.27808637179227685  -0.5944711760816817
# 1.859  -0.2559374602533663  -0.6190161807269406
#  1.86 -0.24531560044074519  -0.5864564899251874
# 1.861  -0.2105038389370855   -0.602945279540742
#
# Clump 18
#  TIME         X                   Y
# ----- ------------------ -------------------
# 1.858 1.0886944513841266   -4.78876892921347
# 1.859 1.2775796827259995  -4.757989884221898
# 1.863  2.065410964966524  -4.388393688856485
# 1.865 2.3694112579474282   -4.23905406682762
# 1.866 2.5181911251756066  -4.150714920332929
# 1.867  2.666098702650478  -4.142521945063004
# 1.868  2.838636733019959   -3.90246247612518
# 1.869 3.0122185807150075 -3.7838454546766225
#  1.87 3.1588398318762123 -3.6450849848995563
# 1.871  3.308373873429114  -3.557734504791702
#   ...                ...                 ...
# 1.903  4.074894622101299   2.304249051535565
# 1.904 3.9943879831006797   2.502636442603449
# 1.905  3.898181360169994  2.6545073786047717
# 1.906   3.80430765109882   2.788278401867605
# 1.908 3.5869651897214005  3.0809554141474917
# 1.909  3.440859680906824  3.2607829475467747
# 1.911 3.1859171436937412   3.545007168921067
# 1.913 2.8491861974165884   3.782907312400664
# 1.914 2.7512394482678486  3.8919439779794853
# 1.915  2.633951587112444  4.0158311698206814
# 1.919  2.138587854227465   4.407895871556905
# Length = 52 rows
#
# Clump 19
#  TIME          X                     Y
# ----- -------------------- ---------------------
# 1.862  -0.4178197069508981 -0.035340666920012705
# 1.863  -0.8649314732771145  -0.44608335607870353
# 1.864  -0.8148162184237197   -0.6415337261209572
# 1.865  -0.7320173919238099   -0.8071195785660573
# 1.866  -0.6134068639609267   -0.9957525385493358
# 1.867  -0.4319438679417908    -1.167397856372973
# 1.868  -0.2439856114624552   -1.2376111258032823
# 1.869 0.004455682832246588   -1.2578522022704297
#  1.87  0.21806651238295938   -1.2153569968993096
# 1.871  0.39296163366547415   -1.1367708130861394
# 1.872   0.5573421335942274   -1.0004122758559648
# 1.873    0.675927943687584    -0.843198151197004
# 1.874   0.7441719881551223   -0.6167127510595423
# 1.875   0.7472090831236801   -0.3820098136395873
#
# Clump 20
#  TIME           X                    Y
# ----- --------------------- --------------------
# 1.876   0.13429086091325668  -0.5498469134194246
# 1.877  0.002750183278510737  -0.4596199835428697
# 1.878     0.137191603490652 -0.45996782942328773
# 1.879   -0.2188713900155429 -0.30431054372346805
#  1.88  -0.13990529606419044  -0.4104045419037273
# 1.881    0.1626761791201193  -0.5035670580008741
# 1.882   0.29583310761236586  -0.4937222842831168
# 1.883   0.03631428596411389  -0.3353615467236984
# 1.884 -0.007589148268388902  -0.3071866659336989
# 1.885   0.03509703928856182 -0.30818000777647486
#
# Clump 21
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.885  -3.094529445480089  4.6584483368505545
# 1.886  -3.191911010085009   4.563707445618089
# 1.889  -3.836381003165337  4.2410589044384155
#  1.89  -3.987839129966863  4.1223390342390624
# 1.891  -4.097902513394915   4.029157175435634
# 1.892  -4.265717316060811   3.912322247215094
# 1.893 -4.3851729242356585    3.79899642894865
# 1.894   -4.53075816261914  3.6526709040654595
# 1.895  -4.713746220392998   3.496951212569867
# 1.896  -4.817830072038072   3.371603249008494
#   ...                 ...                 ...
# 1.924 -5.8255122410393865 -0.9881933910566251
# 1.925 -5.7570866562075755   -1.16186056759333
# 1.926  -5.704251246429217 -1.3182122242911352
# 1.927  -5.635041483176964  -1.492444640681991
# 1.928   -5.58709239893616 -1.6422879869978904
# 1.929  -5.516218786516418 -1.8030805038071915
#  1.93  -5.417656045088312 -1.9593176446857465
# 1.931  -5.338230935063639   -2.09532299298893
# 1.935  -4.830804079113562  -2.689120764761702
# 1.937  -4.605013753117447 -2.9813002701376603
#  1.94  -4.225925931036308 -3.3581211949078393
# Length = 48 rows
#
# Clump 22
#  TIME          X                    Y
# ----- -------------------- -------------------
# 1.892  -1.8248583797830735 -1.1616307824336987
# 1.893  -1.7308434024916297 -1.2510371445816741
# 1.894  -1.6224015517769235  -1.300316367123575
# 1.895  -1.5055738765706888 -1.3548030151598085
# 1.896  -1.3914185353269812  -1.437828697344781
# 1.898  -1.1089258411724512 -1.5082902987580908
# 1.899  -0.9429841888219153   -1.50232709396172
#   1.9  -0.7816226349718967 -1.5023121950711276
# 1.901  -0.6348457442945609 -1.5379755138049849
# 1.902  -0.4504576324053977 -1.4916019794829731
#   ...                  ...                 ...
# 1.933  -1.4000961012339013  -0.810164236470775
# 1.934   -1.246410737274287 -0.9834646463193232
# 1.935  -1.0909301432371723 -1.1135598665137865
# 1.936   -0.918803129181898 -1.2128774578652977
# 1.937  -0.6934627606079454 -1.2618719327361165
# 1.938  -0.5243014831575618 -1.3041272884254895
# 1.939  -0.2875371880889757 -1.2476315201626669
#  1.94 -0.11732637170615787 -1.2181950780687887
# 1.941 0.056747604976192995  -1.155766217688874
# 1.942  0.21403827743120316 -0.9827707628436007
# 1.943   0.3519150830809019 -0.9065655412937423
# Length = 49 rows
#
# Clump 23
#  TIME         X                  Y
# ----- ------------------ ------------------
#  1.91 0.2983048220349933 -5.451594276405527
# 1.911 0.4873147985896915 -5.444190727562364
# 1.912 0.6531994746073367 -5.408850258705981
# 1.913 0.8021196430275257 -5.388742533007594
# 1.918  1.513923342684863 -5.636441292574286
#  1.92 1.9373354893012529 -5.472739754499803
# 1.922 2.3372012997231737 -5.336707153543769
# 1.923  2.530386506208777 -5.236284565432326
# 1.925  2.810421449641033 -5.053905009765638
# 1.926  3.004676399211499 -4.912183704916467
# 1.927 3.1389510423959894 -4.817028514353868
# 1.929 3.4698638273909688 -4.565875425940414
# 1.931  3.801297570020493 -4.271971474294309
# 1.934  4.241643818035179 -3.830203665241742
#
# Clump 24
#  TIME          X                   Y
# ----- ------------------- --------------------
# 1.942  -5.112005442182376    1.114800478589704
# 1.947 -5.2827111297781375  0.07209222621011546
# 1.948  -5.283131982210959 -0.16576817872613034
# 1.949  -5.287230811763457 -0.37973735703736083
# 1.951  -5.263351685287466  -0.8877323933471518
# 1.952  -5.237202132950718  -1.0521217334471105
# 1.953  -5.217762625098698   -1.237611377373908
# 1.954  -5.179612876063748  -1.4126070348973638
# 1.955   -5.14150411119666  -1.5774276063087427
# 1.958  -4.858830618045742  -2.4142983303117025
#   ...                 ...                  ...
# 1.993  0.5520106128239763   -6.217311029329541
# 1.994  0.7293460790367019   -6.227134189404805
# 1.995   0.935876919937201    -6.19523005449633
# 1.996  1.1151830613354399   -6.172584076967085
# 1.997   1.342017490237254  -6.1375428931000044
# 1.998    1.47960952082793  -6.1058377404806405
# 1.999   1.709133655124417   -6.072688162039298
#   2.0  1.8996800134987235   -6.038520285789703
# 2.001  2.0482448387262866   -5.987143557459672
# 2.002   2.245888663285743   -5.924718377696124
# 2.003    2.38370582494978  -5.8613631465571725
# Length = 55 rows
#
# Clump 25
#  TIME           X                     Y
# ----- ---------------------- --------------------
# 1.958   -0.10867777925372382 -0.49640833994509764
# 1.959     0.2176736393850597 -0.49851585423532463
#  1.96 -0.0023803407437585737  -0.5315812971801167
# 1.961   0.044630933095667104  -0.5733073205771596
# 1.962    0.08964970455284191  -0.5732763395007675
# 1.963     0.1811188317204974  -0.5533772675852486
# 1.964    0.14590665690054785   -0.530015804941503
# 1.965    0.20476215725863736  -0.5169489890910084
# 1.966    0.08339285270408983  -0.5250161365348489
# 1.967    0.21406122883826498  -0.5160241982312624
#   ...                    ...                  ...
# 1.975     0.3980527279943033 -0.24226616344433177
# 1.976    0.34976402141800644 -0.27680381165566253
# 1.977    0.33046762803886653  -0.2749784862319049
# 1.978    0.36251450133830443 -0.21650710165054626
# 1.979     0.3535652029807752 -0.20892426494936212
#  1.98     0.3718431191124791 -0.15271541428067947
# 1.981      0.284623930628266 -0.23375542818143066
# 1.982     0.3252061070362207  -0.1589070341780711
# 1.983      0.338936744142505 -0.09380614406410458
# 1.984     0.3284994149403457 -0.06548110801233721
# 1.985     0.3158991909133748 -0.02007711804271657
# Length = 28 rows
#
# Clump 26
#  TIME          X                   Y
# ----- ------------------- --------------------
# 1.969 -1.8533373583874664   3.9835074037054308
#  1.97 -1.9449484678892341   3.8594220537641277
# 1.971  -2.211535759934921    3.825621173890613
# 1.972 -2.4003350689906675    3.739841762599276
# 1.973 -2.5605606134343497   3.6399712147327565
# 1.974 -2.7735969594527567   3.5295747119528045
# 1.975   -2.90231144292547    3.427841731505293
# 1.977  -3.382788781994477   3.1391731840251627
# 1.978  -3.542326051424062   2.9834359351893354
# 1.979 -3.7357736693982155    2.902030796775374
#   ...                 ...                  ...
# 1.985  -4.567808988591214   2.0406591700233316
# 1.987     -4.805621302156    1.643253330942228
# 1.988  -4.911028571888948   1.4462504698067427
# 1.989 -5.0556898309783795   1.2714947751302859
#  1.99  -5.120500558052214   1.0795929030044868
# 1.991  -5.212837818773289   0.8863403523544352
# 1.992  -5.272367231410973   0.6922433917853797
# 1.993  -5.326155328700924   0.5303987358911615
# 1.994  -5.407536613138227  0.31275785437259934
# 1.995  -5.439909756750616  0.13687000044941544
# 1.996  -5.491950927421362 -0.08245005162720608
# Length = 26 rows
#
# Clump 27
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.982 -4.1455922777219545   0.951747939107545
# 1.983  -4.186743543753067  0.7788520176155236
# 1.984  -4.249953736658192  0.5866964687501044
# 1.985   -4.28695882371286  0.3968655233623692
# 1.986  -4.366226513588775  0.2591589176401679
# 1.987  -4.395285433133231 0.02025789314789136
# 1.991  -4.514590543666773 -0.8182763044034992
# 1.992  -4.481087368199272 -0.9963030022368005
# 1.993  -4.442822530906762 -1.1634886954079346
# 1.994 -4.4215523486533455  -1.368013254049924
# 1.996  -4.354838564516649 -1.8212117666291063
# Clump 28
#  TIME           X                    Y
# ----- --------------------- --------------------
#   1.5      -3.9095114316768   1.0366654327688711
# 1.501   -3.9705120947028703   0.8424085155262071
# 1.502    -4.019697360925169   0.6492957549545502
# 1.503    -4.050740589570385   0.4842600541038774
# 1.504    -4.081956527477604   0.2739437242036737
# 1.505     -4.09748754002424  0.06113842505851281
# 1.506    -4.101126443122849 -0.11734722369845971
# 1.507   -4.0961656398294615 -0.31190764606230637
# 1.508    -4.086264823325635 -0.48173720318205476
# 1.509    -4.070337511522053  -0.6741878783172209
#   ...                   ...                  ...
# 2.054   0.38498919604054066  -0.5745731069065435
# 2.055     0.504883881263544  -0.4233675581146268
# 2.056    0.5784118374331165 -0.23758678440554903
# 2.058    0.4940670646158303  0.11397211572681637
# 2.059    0.3451979549203158  0.24594744335156882
#  2.06    0.1578207534883902  0.32884627622202395
# 2.064 -0.059393166641833514 -0.30040789897167686
# 2.065 -0.013939579694756546 -0.35564652112666456
# 2.066    0.1718622291381535 -0.34352666288798583
# 2.067   0.27612254271283004 -0.20672436460108196
# 2.068   0.31137961366853034 -0.04677479266826453
# Length = 558 rows
#
# Clump 29
#  TIME          X                   Y
# ----- ------------------- -------------------
# 1.997  -4.852729455037781 -1.5129810516435258
# 1.998  -4.815704717435898   -1.67943739154225
# 1.999  -4.760153609091454 -1.8772103497862846
#   2.0  -4.706894802913841 -2.0452921349580957
# 2.001  -4.660290130219245 -2.2878562001870737
# 2.003  -4.299799739047634  -2.905093431218562
# 2.004  -4.138414353563048 -3.1283052392792117
# 2.005 -3.9532942763556607  -3.347984825892614
# 2.006 -3.8980953614258342  -3.452489422194372
# 2.007 -3.7741223056124196  -3.619832819092603
#   ...                 ...                 ...
# 2.067   5.390970209388502  -2.510910086623975
# 2.068    5.45314861830162  -2.367155906366056
# 2.069   5.527283359803523  -2.194338149084838
#  2.07    5.57938988977403 -1.9971134549844651
# 2.072   5.701285585129963 -1.5464119607372917
# 2.073  5.7619974120317075 -1.4031733559909503
# 2.074   5.777459791813951 -1.1810473130948087
# 2.075   5.776575522341541 -1.0564777704207822
# 2.077   5.665091225831545 -0.7257536008443148
# 2.078   5.680866351842847 -0.5613344523575736
# 2.079   5.740529563792238 -0.4521322121932988
# Length = 80 rows
#
# Clump 30
#  TIME          X                  Y
# ----- ------------------- ------------------
# 1.999   4.754693044398938  2.047647018878817
#   2.0   4.694937843349231 2.1955167798664217
# 2.001   4.553297791460835  2.450276499543913
# 2.002   4.481573776353638 2.6450830514649497
# 2.003     4.4052634207734  2.800122492797329
# 2.004  4.2821276015437615 2.9838040790578892
# 2.005   4.186531086205825 3.1742895895140464
# 2.006   4.075743940458142  3.329767507479145
# 2.007  3.9639354563544953  3.482556046177272
# 2.008  3.8493399504446852 3.6132186299496625
#   ...                 ...                ...
# 2.048 -2.5804263939118304  4.227476829252934
# 2.049  -2.732937025514723  4.132498553323133
#  2.05  -2.884623033249101  4.014644423222369
# 2.051   -3.02340356725553 3.8911143599505227
# 2.052  -3.159250455687408  3.737258449260797
# 2.053  -3.262103669100265 3.5860157132130217
# 2.054 -3.4312660381436517 3.4148955565700136
# 2.055 -3.4813921550095417 3.2597026504642166
# 2.056  -3.561445226728204 3.0957121924736497
# 2.057 -3.7741577238358177 2.9414603606557996
# 2.058 -3.8074245617950617   2.71823790594438
# Length = 60 rows
#
# Clump 31
#  TIME          X                   Y
# ----- ------------------- --------------------
# 2.076  -4.806298194789476   1.4530119317646817
# 2.077   -4.86195294156176   1.3090209278704446
#  2.08  -4.990850265808771   0.8813929845564888
# 2.083  -5.300730821587532   0.7409412037661594
# 2.084 -5.3444085703828765   0.5319580082274056
# 2.085  -5.371097003205695  0.38493732962557237
# 2.086  -5.403227974951014  0.23654328493329513
# 2.087  -5.427814697085243  0.05192176912586234
# 2.088  -5.436698683533218 -0.15585529440070944
# 2.089  -5.431198326002906  -0.3952297357735372
#   ...                 ...                  ...
# 2.098 -5.1130499232298225  -2.1061670227934357
# 2.099  -5.050409151950917  -2.3208321869537474
#   2.1  -4.903761446883427  -2.5578296875139763
# 2.101  -4.794755421760849   -2.734789141122992
# 2.102  -4.708203912631162   -2.883847316002938
# 2.103  -4.606157906344821  -3.0290642224491977
# 2.104  -4.498742081260432  -3.2077387158373725
# 2.105  -4.806482850915846  -3.2500482215064377
# 2.106 -4.7138206363989825  -3.4193078711759455
# 2.107  -4.530934170146168  -3.6523356219788554
# 2.108   -4.50334152060327   -3.739045977518942
# Length = 29 rows
#
# Clump 32
#  TIME          X                   Y
# ----- ------------------- -------------------
# 2.084 -3.2290178107355016   3.390736529338611
# 2.085  -3.223629985319228  3.7123689615700344
# 2.086  -3.420702360256075   3.349597158870242
# 2.087  -3.608388315208421  3.5996112617846525
# 2.088 -3.7298745042103523   3.535885755211984
# 2.089 -3.8651205674004507   3.410522210484814
#  2.09   -3.99605799010329  3.3384022840929815
# 2.091  -4.089177427762211  3.2554995106845634
# 2.092  -4.279249353813489   2.886168425003994
# 2.093 -4.3415490252304885   2.841636223621551
#   ...                 ...                 ...
# 2.114  -5.331989647999618  -1.111223813106547
# 2.115 -5.2842672929144054 -1.2993208474798137
# 2.116  -5.256483579596395 -1.4624142114602054
# 2.117  -5.222799486838963 -1.6606111955016656
# 2.118  -5.170323122200035 -1.8196499121178664
# 2.119  -5.080178066985927 -2.0067391265374126
#  2.12  -5.009353062109162 -2.1638368586522647
# 2.121  -4.966342048839656   -2.33061670133698
# 2.122  -4.879664788448074 -2.5117913077005527
# 2.123  -4.785462406083175  -2.650432781335261
# 2.124  -4.738680195435532 -2.8788574922672656
# Length = 41 rows
#
# Clump 33
#  TIME          X                   Y
# ----- ------------------- -------------------
# 2.085 -3.3527034602243666  -2.271246682590917
# 2.086   -3.28538564572283 -2.3401581551494477
# 2.087  -2.924789956645459  -2.636985393141767
# 2.088  -2.935645639614742 -2.7334735015457685
# 2.089 -2.5259990049121552  -2.956927595953407
#  2.09 -2.4075323949408425 -3.0806526589526104
# 2.091  -2.308393339226043 -3.2110063277205687
# 2.092 -2.1035294117663454   -3.30705050083646
# 2.093  -1.922010535080347 -3.4005251173457864
# 2.094 -1.8678869867806394  -3.559764819433751
#   ...                 ...                 ...
# 2.114  1.8929247263143438 -3.6821492103950555
# 2.115   2.057605763511071 -3.6017529418945853
# 2.116   2.257342311638049 -3.4998057730484757
# 2.117  2.4150928503419533 -3.4062041506086027
# 2.118  2.5639737748572906  -3.302759979519727
# 2.119  2.7570095653266224 -3.2107217471520673
# 2.121  3.0119358777885363 -2.9550303676350036
# 2.122   3.147162457556644 -2.8191438028743203
# 2.123  3.2496356396999904  -2.701761777257843
# 2.124  3.3617043075016224 -2.5593661163860046
# 2.125   3.493405135812263 -2.4073366642069907
# Length = 40 rows
#
# Clump 34
#  TIME         X                   Y
# ----- ------------------ -------------------
# 2.017 0.9100766662275193  -4.613908315362905
# 2.019 1.2673086158548548  -4.512771038221586
#  2.02 1.4072064062970397  -4.469661621541066
# 2.021  1.578142697009316  -4.429386461356429
# 2.022 1.7282916378579352  -4.350986819066156
# 2.023 1.8837673711047285  -4.290341278217918
# 2.024 2.0653450574754793  -4.232677732683393
# 2.025 2.2287445855008112  -4.152549491769054
# 2.026  2.388713042303296  -4.043400140968619
# 2.027  2.527667440725599 -3.9566970781779385
#   ...                ...                 ...
# 2.209   5.35201335044419  0.4511396870024909
#  2.21 5.3270728653855945  0.6891718463926442
# 2.211  5.276261587196294   0.892372483093719
# 2.212  5.246331714675661  1.1114436925669668
# 2.213  5.198264504208675  1.3030040139694126
# 2.214   4.70772961810516  1.6047371642434167
# 2.215  5.100792960787299  1.6999740897129865
# 2.216  4.538845017952477  1.9226958519351645
# 2.217  4.430449146357318   2.062007233342335
# 2.218  4.332778678056948   2.205291180254448
# 2.219  4.758808233243302  2.5023591107099064
# Length = 202 rows
#
# Clump 35
#  TIME          X                   Y
# ----- ------------------- -------------------
# 2.124  -5.489130684898819 -2.9054014706415656
# 2.125  -5.416304905193494  -3.083725676066807
# 2.126    -5.3620004367416 -3.2359729676738054
# 2.127   -5.27265696864536 -3.3927097036492393
# 2.128  -5.163871510794597 -3.5755187601413807
# 2.129  -5.063797074969198 -3.7306172895538587
#  2.13  -4.929491907227679 -3.9385442497248913
# 2.131   -4.78101284935285  -4.109628839779765
# 2.132  -4.646100289430338  -4.264584225079964
# 2.133  -4.525791833437557  -4.388667665502411
#   ...                 ...                 ...
# 2.143  -2.896262535733372  -5.579143561766755
# 2.144   -2.75913691647995  -5.679426405715694
# 2.145 -2.5360142686445895  -5.755237912282457
# 2.146  -2.285466143021317  -5.787672704234189
# 2.147 -2.0849053896683287  -5.865844686553791
# 2.148  -1.921556266892287  -5.915960759694339
# 2.149 -1.7630049059284927  -6.006053212648829
#  2.15 -1.5933996671263673  -6.056306699166144
# 2.151 -1.4261584296403906 -6.1010225095304484
# 2.154 -0.8082130207054928  -6.224262952068314
# 2.156 -0.3795644655807735   -6.28544063046126
# Length = 28 rows
# Clump 36
#  TIME          X                    Y
# ----- -------------------- --------------------
#  2.13   1.1276733858438939    5.482945336363711
# 2.133   0.6966018023179391    5.625843477479278
# 2.134  0.24213902294917908    5.663171607655541
# 2.135  0.09360342453274492    5.667122781833486
# 2.136 -0.03819056799377192     5.66937919363729
# 2.137  -0.2240075881742216    5.651401907502567
# 2.138    -0.37527269565654     5.62019878511612
#  2.14  -0.6657778203990737    5.676772562175546
# 2.141   -0.866561686634495    5.438281761209755
# 2.146  -1.8722858215697151    5.422857836235984
#   ...                  ...                  ...
# 2.183    -5.89360880228244   0.9951526634461603
# 2.184   -5.905367554248609   0.7858257662245656
# 2.186   -5.954318150123383   0.5219529259093728
# 2.187   -5.971443357115671   0.3341667726985367
# 2.188   -6.007612562759199  0.11742755309542076
# 2.189  -5.9813714712498305 -0.14702559507513843
#  2.19   -6.043855619280208 -0.25508648896131025
# 2.191   -6.048934329053009 -0.41694467883494185
# 2.192  -6.0539126772051075  -0.6223204912269513
# 2.193   -6.044776946111375  -0.7924068715500131
# 2.194  -6.0397884839061735  -0.9662870883568851
# Length = 42 rows
#
# Clump 37
#  TIME          X                  Y
# ----- ------------------- ------------------
# 2.144  3.4198348008338595  3.982288677759768
# 2.145  3.3690470616973704  4.107239591716654
# 2.146  3.2670530661843253  4.223559919491128
# 2.147   3.186329102587278  4.323105208936225
# 2.149   2.715136547809106   4.54981183234645
#  2.15  2.5722253059350755  4.643817232912843
# 2.151  2.4168761735491144  4.744540754611638
# 2.152  2.2696428912452427  4.816738270385775
# 2.153   2.103522234022258  4.878162648296568
# 2.154   1.841284268057505  5.007480470926339
#   ...                 ...                ...
# 2.173 -1.8631676409589137  4.956673998912122
# 2.174 -2.0483166056910926  4.852908612611304
# 2.175  -2.221914431491737   4.77099135706284
# 2.176  -2.369259158506555  4.628981426722515
# 2.177 -2.5379021311462346  4.523141883793559
# 2.178 -2.6741284647008188  4.443253916124437
# 2.179 -2.8315345841956137  4.324640325107314
#  2.18 -2.9955674277126376  4.217233573886002
# 2.181 -3.1464567907716847 4.1157982705317515
# 2.182  -3.298696565812812 3.9927559744693006
# 2.184 -3.6183664125915818 3.7566909227124836
# Length = 39 rows
#
# Clump 38
#  TIME           X                    Y
# ----- --------------------- -------------------
# 2.145    -0.917979533529381  -4.370944392581085
# 2.146   -0.7433672449754511  -4.358555637422095
# 2.149   -0.2737826048023611  -4.411858950990323
#  2.15 -0.017481594533522746  -4.390088446227903
# 2.151   0.40522264854414336  -4.251404126263204
# 2.152    0.5751585092754106  -4.198308700387578
# 2.153    0.7432668169242109  -4.123003707789622
# 2.154    1.0082226538332781  -4.134011812677503
# 2.155    1.1855077391006625   -4.03460114058527
# 2.156    1.3253844954499892  -3.962043464664939
# 2.158     1.693834597139189  -3.808436825339848
# 2.159    1.5356090538748648  -4.090075734005814
#  2.16    1.7056089645232217  -4.027078016127497
# 2.161    1.8805344869033251 -3.9316467566602284
# 2.162      2.02981882645483  -3.859418934168753
#
# Clump 39
#  TIME         X                   Y
# ----- ------------------ --------------------
# 2.163  2.514430500595794  -3.2230151075940863
# 2.164  2.635293456319236  -3.1064893920781675
# 2.165  2.758114008004132  -3.0032528984963243
# 2.166  2.860749884679969   -2.889401796924541
# 2.167 2.9610499849166265   -2.728143020074868
# 2.168 3.0543129361455446   -2.578555177918415
# 2.169 3.3594533731775464  -2.2901007796656403
# 2.171 3.4049639299905397   -2.028052369333602
# 2.172  3.556097296819722  -1.8441519541308473
# 2.173 3.5278710555330086   -1.698511542085019
#   ...                ...                  ...
# 2.182  3.893637018804936 -0.33890460005746964
# 2.185 3.6897403019429005   0.5953295688020168
# 2.186  3.731465583765178   0.7311567791390977
# 2.187 3.5963385937687966   0.9165391445406736
# 2.188 3.5319367578431518   1.1109407903060107
# 2.189   3.44415671911714   1.2889263553514354
#  2.19  3.454275039605125   1.3986574017784286
# 2.191 3.3368095922670085   1.5774876803263103
# 2.192  3.299272732182323   1.6991753410598154
# 2.193 3.2085618334004034   1.8570086422095642
# 2.194 3.0911179346640854   2.0048212214453005
# Length = 29 rows
#
# Clump 40
#  TIME          X                  Y
# ----- ------------------- ------------------
# 2.193   4.352602295598875 1.9275722242659563
# 2.194   4.226286771024622 2.1681693206074946
# 2.195  4.0462325352639334  2.392461288199327
# 2.196  4.0840195737898135 2.4242559781821735
# 2.197   3.968526135467285  2.632685035546913
#   2.2  3.4603292259159804  3.132390308517951
# 2.201   3.844591664685999  3.139089305001607
# 2.202  3.6595056953960676 3.3523363017371066
# 2.203   3.629951195707133   3.43514487866177
# 2.204  3.4411247772240343 3.6130803021847044
#   ...                 ...                ...
# 2.217  1.2320068529482542  5.025496996935961
# 2.218   1.042146986249298  5.099305369573876
# 2.219  0.8618391773306933  5.181653490004331
#  2.22  0.6599709731140065 5.1938103003481375
# 2.221  0.4746442074955216 5.2258621791266835
# 2.222 0.27622588461335784   5.24929938032569
# 2.223 0.07424682836929095  5.299625646552404
# 2.228   -1.09235639447262  5.252864448996187
#  2.23 -1.5048474444851359   5.12621674514905
# 2.231 -1.6732118836834533  5.088238627056038
# 2.233  -2.062998286047676   4.92214070128434
# Length = 31 rows
#
# Clump 41
#  TIME          X                   Y
# ----- ------------------- -------------------
# 2.195  -4.976511137484739  -2.019364682761373
# 2.196  -4.688822897962993  -2.530255549294692
# 2.197  -4.756839669639723  -2.463697313766573
# 2.198 -5.1167770606797305 -2.2436121691709605
# 2.199  -4.678505789422006  -2.716902394151587
#   2.2  -4.940742855161331  -2.593729981027344
# 2.201 -4.8787124539159095  -2.795886045442633
# 2.202  -4.777350135871883  -2.985521868683847
# 2.203  -4.701060366449562 -3.1073876753657688
# 2.204  -4.585081233814427  -3.274601926150682
#   ...                 ...                 ...
#  2.22 -2.8656743975224703  -5.363262400617296
# 2.221  -2.640364386685842  -5.392074200244613
# 2.222 -2.4904262255799057  -5.542247401445172
# 2.223  -2.276990154535069  -5.548983744587678
# 2.224 -2.1131201348105466  -5.681064040091481
# 2.225  -1.899769141594329  -5.703567784321044
# 2.226  -1.769115157842222  -5.799509565340557
# 2.227 -1.6051398932159564  -5.927929406939928
# 2.228 -1.4232060203009396  -5.947533220527941
#  2.23 -1.0507767393680205   -6.16216918301263
# 2.231 -0.7543096190692136  -5.897386947793468
# Length = 33 rows
#
# Clump 42
#  TIME          X                  Y
# ----- ------------------- ------------------
# 2.208 -2.5149247290705574  4.023902137941958
# 2.209  -2.645052699639453 3.9166642462335854
#  2.21 -2.7844309326438994  3.823187821299496
# 2.211  -2.888312700839396  3.686192732985165
# 2.214 -3.3348104147250823 3.2922059926315566
# 2.215 -3.4197735304231958  3.211211550117361
# 2.216 -3.5805397371553513 3.0119199331809408
# 2.217  -3.578900694691222 3.3691451803536276
# 2.218 -3.6517712763369867  3.353477449586552
# 2.219  -3.775562548577721 3.1616815687896613
#  2.22 -3.8843360564233658  3.027725500171293
#
# Clump 43
#  TIME          X                    Y
# ----- -------------------- -------------------
# 2.221   -4.128799473217474   2.209724671815163
# 2.222   -4.180629664178799   2.003481922539622
# 2.223   -4.250342947979256  1.8376397971053835
# 2.224  -4.3217041789359545  1.6166101140586988
# 2.225   -4.362802005808798  1.4331918257624565
# 2.226   -4.403229091846087   1.270770173748265
# 2.227  -4.4151134578455595   1.096372439366766
# 2.228   -4.443598264534481  0.9633859853335014
# 2.229    -4.43067517396858  0.7890826244358219
#  2.23   -4.465406230785431  0.6292590733406151
#   ...                  ...                 ...
# 2.266 -0.23962159844880163   -3.66062118493914
# 2.267 -0.04161454516940953 -3.6591981580772193
# 2.268  0.11911343391380877  -3.657493092566696
# 2.269    0.329202884906865  -3.652170035799034
#  2.27   0.5287859797011978 -3.6495711517689475
# 2.271   0.6979267293119278 -3.6122811628200293
# 2.272   0.9068359690475124  -3.552055936825607
# 2.273   1.0291195745169788  -3.486729247621789
# 2.277   1.6510477892630573  -3.148771539647856
# 2.278   1.8918345085042827 -3.0361711604963775
# 2.282   2.5222063851955823 -2.5263707147698167
# Length = 48 rows
#
# Clump 44
#  TIME          X                   Y
# ----- -------------------- ------------------
# 2.259   0.7797804684353594  5.730034177074585
# 2.261  0.41277714464475695  5.747139629808187
# 2.264   0.2696209622173281   5.66397205407568
# 2.265 0.036567740742740315  5.730537732329774
# 2.266 -0.09437345846411715  5.697417181432357
# 2.267 -0.37742129271238717  5.754160988126428
# 2.269  -0.7095992720169267 5.8544502956301985
#  2.27  -0.8979988279713179 5.8505657132543005
# 2.271  -1.1344318395116515  5.750550808006123
# 2.273  -1.5087603470402269  5.682272288978927
#
# Clump 45
#  TIME         X                  Y
# ----- ------------------ ------------------
# 2.091  5.140026471855621 1.7924150172444024
# 2.094 4.7481314886121355  2.240164294840586
# 2.095  4.765178158973556  2.448600488464036
# 2.097 4.5245168360611405  2.817579561303885
# 2.099  4.359359070792978 3.1388392034563815
# 2.101 4.1196028698838365  3.375050951888083
# 2.104 3.5694158993115885  3.710168156080135
# 2.105 3.3973168909238494  3.814761287277959
# 2.106 3.2778674164790944 3.9242103493259664
# 2.107    3.0685176402309  3.996320033826986
#   ...                ...                ...
# 2.406 2.8507865107927763   4.15818283035923
# 2.407 2.6961073538215388  4.247335784317262
# 2.408  2.530377020957814  4.340216439082942
# 2.409  2.343550399036019  4.418125855673935
#  2.41  2.157347524353096  4.488609649593587
# 2.411 1.9703042994327755  4.548615027974511
# 2.412 1.7817091169405657  4.604259282065649
# 2.413 1.5995525864416424  4.651782869041745
# 2.414 1.4214087652660088  4.692923619816315
# 2.415 1.2377721347051145  4.726440778027703
# 2.418 0.6145513018975303  4.733601397125006
# Length = 315 rows
# Clump 46
#  TIME          X                   Y
# ----- ------------------- --------------------
# 2.185  -2.637261019428134    4.916398895929301
# 2.186 -2.8689432665570225   4.8550256492229655
# 2.187 -3.0760777951615648    4.788630377418459
# 2.188 -3.2255820374327584   4.7017952015780455
# 2.189 -3.4284793465794055    4.596649804329681
#  2.19 -3.6013993973652894    4.483610519228339
# 2.191 -3.7924155132709103   4.3721961433278045
# 2.192   -4.00646270119636    4.262059632331649
# 2.193  -4.140134184791902    4.149019613610568
# 2.194  -4.299255324409928    4.032112409391991
#   ...                 ...                  ...
# 2.376  -3.723667710467294  -0.1623222370608863
# 2.377  -3.684081195383718 -0.34459457325213766
# 2.378 -3.6437444001586643  -0.5180701853896506
# 2.379  -3.581643048413843  -0.7104283274269978
#  2.38  -3.524135981051095  -0.8845942843179908
# 2.381  -3.441330137594144  -1.0621129143246375
# 2.382 -3.3496795286785788  -1.2366683170546755
# 2.383 -3.2773484236148405  -1.3909753613220102
# 2.384  -3.161317916715527  -1.5563322020907904
# 2.385  -3.053183182272959  -1.7065582097259777
# 2.387 -2.7956178163792664  -1.9858004971985261
# Length = 201 rows
#
# Clump 47
#  TIME          X                   Y
# ----- ------------------- --------------------
# 2.385  -5.947459116946141  0.23053631940393005
# 2.388  -5.897184270581443 -0.44285764898748653
# 2.389  -5.848638491554762   -0.694013034407334
#  2.39  -5.805949761719052  -0.7869715643722521
# 2.391  -5.797325261857357  -0.9844282141086533
# 2.392   -5.73782276116243  -1.0917585832317631
# 2.393  -5.686670621623005  -1.2531887046165644
# 2.396  -5.436238055069121  -1.8144955341982263
# 2.401  -4.998138785696051  -2.8649409847503704
# 2.402 -4.8134307037953565  -3.0164453031060665
# 2.404  -4.622973626842747  -3.3153063849698063
# 2.406  -4.402681784148192  -3.6690503047325294
# 2.411   -3.46760473580917   -4.221972623231219
# ...
# ----- ------------------- ------------------
# 3.757 -3.4473107644069008   5.55752586675026
# 3.758 -3.6226923465142318   5.46888026913086
# 3.759 -3.8514678082903577  5.307847078903151
#  3.76  -4.064981844808238  5.192307031378575
# 3.761  -4.237361409084015   5.08284484880504
# 3.763  -4.501523004780058  4.812301482764641
# 3.765  -4.852970311313533 4.4690942493349555
# 3.767  -5.215311500068088  4.140863776009061
# 3.768 -5.3306163427400435 3.9972772264097522
#  3.77  -5.588842913286086  3.653287444036022
# 3.772  -5.892015492507475 3.3590918046220435
# 3.774  -6.188544163603889  2.893914767559672
# 3.775  -6.362534161478078  2.677283476755675
# 3.777  -6.477154347414205 2.3339446972645743
# 3.778 -6.5250703676188975 2.1551678878650082
#
# Clump 127
#  TIME         X                   Y
# ----- ------------------ -------------------
# 3.806 3.7251899136778195  -4.757340774171772
# 3.808  4.111961915568081 -4.5608480195905345
# 3.809  4.223832859518229  -4.373915638767964
# 3.811  4.498054313412544  -3.972419834075417
# 3.812  4.636351463704394 -3.7881256961975733
# 3.813   4.76981048173536  -3.640428844378466
# 3.814 4.9430399730729855 -3.4588345273083236
# 3.815 5.0819620504086975  -3.254859774812736
# 3.816  5.191799194210749 -3.0577700284646876
# 3.817  5.281324264133933 -2.9020646416341855
# 3.818  5.361525724960189 -2.7147196306726404
# 3.819  5.475092350725912  -2.483967635957618
# 3.821  5.648198650189929 -2.0962704606521085
# 3.823  5.808813284889983 -1.7303313877809126
#
# Clump 128
#  TIME           X                    Y
# ----- --------------------- --------------------
# 3.167    -4.552599163432727    3.990127214641351
# 3.169   -4.8833221915742895    3.692187452435603
#  3.17    -5.024208336075013   3.5452271091668437
# 3.171    -5.172231573425937   3.3931142799959932
# 3.172    -5.315237270446314    3.231173192650897
# 3.173    -5.434167613513118    3.072832739545616
# 3.174    -5.574726567795034    2.913724260561325
# 3.175    -5.708925802001598    2.738901258208141
# 3.176    -5.825107060357735   2.5565669195848555
# 3.177    -5.933938164360071   2.3735024292332976
#   ...                   ...                  ...
#  3.84  -0.46155126371578115   0.3078279620007276
# 3.841   -0.4922370410838342  0.10390664448648106
# 3.842    -0.390880505103691  -0.1515703139970493
# 3.843  -0.04620410663847738 -0.34580224121341896
# 3.844   0.06077001028156499 -0.35232848791434745
# 3.845      0.36348724574048 -0.14364713602205512
# 3.846   0.39260723876400183  0.12958580544225032
# 3.847    0.3122996936033537  0.24777341043277895
# 3.848   0.18118676364455066   0.3513208421514997
# 3.849 -0.008779786329680224  0.37843997172815175
#  3.85   -0.1755464123121846  0.25397126606066667
# Length = 683 rows
# Clump 129
#  TIME         X                   Y
# ----- ------------------ -------------------
# 3.821 5.1666135082577425  -3.914484152826455
# 3.822  5.349364362000338  -3.825507306077478
# 3.823  5.434441491572505 -3.7312230806184132
# 3.826  5.812592096600756 -3.1903851114310373
# 3.827  5.902520815597168 -3.0022118547992847
#  3.83  6.272042644263893  -2.420593629255988
# 3.831 6.3716549792926065 -2.3157408439746674
# 3.832  6.410640943470481  -1.956417484593426
# 3.833  6.490715502647482 -1.7614658029698647
# 3.834  6.537602163149912  -1.557396621506178
#   ...                ...                 ...
# 3.854  6.269256432080328  2.8579341788072306
# 3.855   6.21428734091255  3.0333507365071277
# 3.857  6.135107485320972  3.4634315698224833
# 3.858   6.16499029262908  3.5480400887097874
# 3.859  6.062774504007868  3.7849902988083652
#  3.86  5.965565538547066   3.930766346284308
# 3.861  5.861542593241524   4.092800049049171
# 3.862  5.724595990556643   4.233703653217641
# 3.863  5.610758465089353    4.38096495810962
# 3.864   5.47149694963501   4.495280164369202
# 3.865 5.3524695691932225   4.628773914287064
# Length = 35 rows
#
# Clump 130
#  TIME          X                   Y
# ----- ------------------- -------------------
# 3.832  -1.467445000217298  -5.335057837623049
# 3.833 -1.2677103346316876 -5.3690597934087965
# 3.834  -1.105787870722526 -5.3741429524008355
# 3.836 -0.6448255427277666  -5.445279286466559
# 3.837 -0.4723655970760112  -5.456932832939701
# 3.839 -0.1609523909712972  -5.488454688929365
# 3.843  0.3024391002852645  -6.020227129639974
# 3.844  0.5272370787130536  -6.006707053079801
# 3.845  0.7096917168824605  -6.015469987991513
# 3.846  0.9277110735967521  -5.992908664635753
# 3.847   1.097342139262067  -5.963854494248623
#
# Clump 131
#  TIME         X                   Y
# ----- ------------------ -------------------
# 3.852  2.503603732862159  -5.268784151822852
# 3.857  3.493234970299239  -4.658966961713783
# 3.858 3.6538630215766115  -4.555617486473426
# 3.859 3.8123598874321414  -4.424828824374381
#  3.86    3.9449949832375  -4.298567181186258
# 3.862  4.335073725035174 -3.9304748786739068
# 3.863  4.466821035365627 -3.7316852872900657
# 3.866  4.786142334253343 -3.1405327557384193
# 3.867  4.967865880380404  -2.739912794662612
# 3.868   5.03438169797316 -2.6223322016136543
#
# Clump 132
#  TIME          X                   Y
# ----- ------------------- -------------------
# 3.858  -3.529720588027129  -5.739079449839077
# 3.859  -3.412162622206927 -5.9149373376451555
# 3.861 -2.9041508957904227  -5.997606563153186
# 3.862  -2.733058927940907   -5.91493623894501
# 3.863  -2.552074696772793  -6.128980440361784
# 3.864  -2.392367143015261 -6.2256671301417885
# 3.865 -2.2048240693601024  -6.281352166468471
# 3.866  -2.044568378997115    -6.3281159037164
# 3.867 -1.8076624317830214    -6.4271339794056
# 3.868 -2.0700215556098804   -6.79913069792013
# 3.869  -1.866199574012901  -6.863198399025407
#
# Clump 133
#  TIME         X                   Y
# ----- ------------------ -------------------
# 3.885 1.6501457376479174  -7.096680001211491
# 3.886 1.8315967420731314  -7.080368243313267
# 3.887 1.9871661647095051  -7.030701749583591
# 3.892   2.99186552791129  -6.171641035670033
# 3.897  4.078241481521798   -6.05119069023021
# 3.898 4.2390081498806715 -5.9520423718314275
# 3.899 4.3673658785436125  -5.796328782608891
#   3.9  4.479634796394917  -5.743468445654106
# 3.901  4.641953433582516  -5.583468521715482
# 3.904 5.3071837412154625  -5.199002279511977
# 3.905  5.389263088810793  -5.039445327028348
# 3.906  5.510473204510843 -4.8715068731630184
# 3.908  5.684953949080587 -4.5750950971941355
# 3.912  6.192734240073418  -3.792079292521527
# 3.913  6.255742932462044 -3.5914685303424405
# 3.917  6.819483344737843  -2.903413876944668
# 3.918 6.9562743695556195  -2.813754947124552
# 3.921  7.132219881366185  -2.350611746383951
#
# Clump 134
#  TIME          X                   Y
# ----- -------------------- ------------------
# 3.895   1.7850456765366451   4.80380712970375
# 3.896   1.6139207782337694  4.797898324607969
# 3.901   0.8532972168612806  5.192403869972977
# 3.903  0.48445117024556655   5.30664044484221
# 3.906 -0.07847210765423496  5.571728272959302
# 3.907 -0.30385819180142354  5.531009027132416
# 3.908  -0.4759007291901041  5.667022651157732
# 3.909  -0.5627419940290183  5.717684668283784
#  3.91  -0.7437604964600045  5.713589450385028
# 3.912  -1.0840098643169627  5.795976426869943
# 3.913  -1.6877073443101431   5.40448787817713
# 3.914   -1.464154853823563  5.110329656782107
# 3.915  -1.6782389010454442  5.089209741356523
# 3.917  -2.5276210343420447  5.134851149303036
#  3.92   -3.022153295653353  4.947284770500008
# 3.921   -3.212327473707975  4.768228839904297
# 3.922   -3.382624973840459  4.640813086394554
# 3.927    -4.20502738738337 3.6194234564899084
# 3.928  -4.3607555537615275 3.4594383269032933
# 3.929    -4.47058045442325 3.3163538395191345
#  3.93   -4.579022709030382  3.151227318476049
#
# Clump 135
#  TIME          X                   Y
# ----- ------------------- -------------------
#  3.91  -7.388236270910397  0.0839676164434003
# 3.912   -7.39595963045323 -0.2582833557742766
# 3.913  -7.388049901020164  -0.428638439516694
# 3.918  -7.212256329487274 -1.5292555611059602
# 3.919  -7.110364187399952 -1.7147225539228832
#  3.92  -7.211375238780615 -1.7935759102867255
# 3.921  -6.958075730179003 -2.0225580572014676
# 3.922  -6.969636359797693 -2.1476194226371446
# 3.923 -6.8177776447587375 -2.3511494343765404
# 3.928  -6.361185415658994 -2.9144859980893196
# 3.929  -6.348214305642532  -3.062556919148304
# 3.933  -6.205372596150671  -3.448561156185611
# 3.935  -5.763806552954795  -4.068133084725757
# 3.936  -5.719912806550767  -4.227138689165568
# 3.939  -5.549137790364769  -4.674312042043635
#
# Clump 136
#  TIME          X                   Y
# ----- ------------------- -------------------
# 3.935  -4.853532601025007  -4.088792828720512
# 3.936  -4.778763899707796  -4.263349753563058
# 3.937  -4.997873540067403  -4.699456746202367
# 3.939  -4.734168269135542  -5.197867631305859
#  3.94  -4.775721253618236 -4.9594010741217245
# 3.941  -4.556925594897878  -5.159832996110198
# 3.942  -4.333927619314424  -5.369682984166222
# 3.943  -4.319262373745128  -5.303130335856884
# 3.944 -3.9891603076427966  -5.466677587970991
# 3.945 -3.9443379615672076  -5.588019149287362
# 3.946  -3.486084981102993  -5.788221597743539
# 3.947 -3.6827108071155483  -5.756081121378947
# 3.948 -3.4762760544592957  -5.860969559171245
#  3.95 -2.7175566546430905 -6.1236218449382065
#
# Clump 137
#  TIME          X                   Y
# ----- ------------------- --------------------
# 3.936  -6.016186285954887   1.5271710716528288
# 3.937  -5.989987747116626   1.2697606274491835
# 3.938  -6.015353193927897   1.0834297487641456
# 3.939  -6.059507819141307   0.9844158378317851
#  3.94  -6.057527527730582   0.7753178598538665
# 3.941  -6.052274564557858   0.6120958430854323
# 3.942  -6.034709163087855  0.42328607621260467
# 3.943   -6.12859132089651  0.19650513728489946
# 3.944  -6.141887592338371 -0.01607354670129391
# 3.945  -6.148197472601788 -0.22014730839953997
# 3.946  -6.157044526946785  -0.4435291471276662
# 3.951 -5.8760448235790665  -1.5039926502537198
#
# Clump 138
#  TIME          X                  Y
# ----- ------------------- -----------------
# 3.951    5.41739301810088 4.448969999874061
# 3.954   4.991705907685597  4.77696280464512
# 3.955   4.986224798878284 4.715107865852572
# 3.958  4.9439295580247515 5.159012095723821
# 3.963   4.019772649421247 5.837549259023836
# 3.964  3.4147050908361636 5.774613552785496
# 3.965  3.7355577683234467 6.021302874425001
# 3.968  3.2241175523142274 6.318792577787697
# 3.971   3.275018061406873   6.6578264722895
# 3.973     2.9011386962114 6.836794265228639
# 3.975   2.488497684206182  6.98695217044391
# 3.976  2.1533724654738133 7.013890109269626
# 3.977  1.9396930073863776 7.042299180621819
# 3.982  0.9116244202054086 7.373969356905568
# 3.985 0.49974657898066593 7.477638100691014
# 3.986  0.3224499176235686 7.476635913877497
#  3.99 -0.8422253989706928  7.33528444408881
#
# Clump 139
#  TIME           X                    Y
# ----- --------------------- -------------------
# 3.963   0.08626818448186743   -6.46950343701059
# 3.965 0.0066889510974424485   -6.82270460989549
# 3.966   0.05922816424282127  -6.764366145337718
# 3.967   0.18577053233002783 -6.7857034470131845
# 3.968    0.4306948314408735  -6.740744202228695
# 3.969    0.6105681951220522  -6.703648156080218
#  3.97    0.7788994971069191  -6.686113412631031
# 3.971    0.9505607701136475  -6.676453594325426
# 3.972    1.1500996297909114  -6.614354436578462
# 3.973    1.3250931288211611  -6.561967009875525
# 3.974    1.5210995409225283 -6.5628461369468365
# 3.976    1.9379307616964911 -6.3832127196871165
# 3.978    2.3183424691581798 -6.2467505757279485
# 3.979    2.2863318572383253  -6.048755395824961
# 3.981    2.4940197266672723  -5.818027101617759
# 3.982     2.695470764386327  -5.719067873977845
# 3.983      2.92551577208001 -5.6457002173207815
#
# Clump 140
#  TIME          X                   Y
# ----- ------------------- --------------------
#  3.96 -1.8240149320978354    6.428872591162054
# 3.962 -2.2195389640300083    6.330091155350752
# 3.963 -2.4132650007107666    6.247158901862046
# 3.965  -2.776093267174489    5.823758788114545
# 3.966 -3.0988944960781573     5.50507719189761
# 3.967  -3.352466760633404    5.399153887133165
# 3.968  -3.401407071423065   5.3949472116271044
# 3.969 -3.4587139502902664    5.387652450279851
#  3.97 -3.7154683658905916   5.2135579881124965
# 3.971 -3.8782981846066997    5.146320796525657
#   ...                 ...                  ...
# 3.989  -6.022823115628855    1.541564213194053
#  3.99  -6.074314677862415   1.5080609760847414
# 3.991  -6.094568579400364   0.9344966052472812
# 3.992   -5.93872846426185   1.0403544945327206
# 3.993   -5.98218155268146   0.6966730511286795
# 3.994   -6.11380967355166  0.27906272818345346
# 3.995  -6.109711404506997   0.0180932015528336
# 3.996   -6.11328872221676  -0.2218646877457046
# 3.997 -6.1009586852816255 -0.40532141176057634
# 3.998  -6.090874258312315  -0.6161110294940599
# 3.999  -6.100006671994545  -0.8106055170219624
# Length = 35 rows
#
# Clump 141
#  TIME         X                  Y
# ----- ----------------- -------------------
# 3.991 6.566981095114634 -0.3852201541407742
# 3.996 6.786657095107218  0.6620273896201565
# 3.997 6.778119763654226  0.8486977399021858
# 3.998 6.749699680694898   1.002509037621226
# 3.999 6.712176257306047  1.1631141247725794
#
# Clump 142
#  TIME          X                  Y
# ----- ------------------- -----------------
# 3.993  -2.473759472755201 6.559087696251436
# 3.994  -2.630840512079783 6.482688380827959
# 3.995  -2.835244087503049  6.38446615704948
# 3.997 -3.3432197820439136 6.207126575052716
# 3.998 -3.5506432157101124 6.102267106065551
#
# Clump 143
#  TIME         X                  Y
# ----- ------------------ ------------------
# 3.994 1.7874861226008802 -4.500736579791338
# 3.997  2.177776064866597 -4.380271304692602
#
# Clump 144
#  TIME         X                  Y
# ----- ------------------ ------------------
# 3.995  3.507930309258338  5.559303671840763
# 3.997  3.152436793792515 5.6680117697544805
# 3.998 2.9675902146100035  5.798464580248977
# 3.999 2.7760515006891353  5.910467081264675
#
# Clump 145
#  TIME          X                  Y
# ----- ------------------- ------------------
# 3.995 0.12893920080821494 -4.144872890334982
# 3.997  0.4979723148289129 -4.106145404307278
#
# Clump 146
#  TIME         X                  Y
# ----- ----------------- -------------------
# 3.995 4.720863027962248  -5.464862211181851
# 3.996 4.882581901074555 -5.3510059271484565
#
# Clump 147
#  TIME         X                  Y
# ----- ------------------ ------------------
# 3.996 5.7597195726029256 3.8019590777139043
# 3.997  5.643899889923993 3.9523302538837353
# 3.998  5.534238866090376  4.112662272268189
# 3.999  5.422543999322611  4.262237148067512
#
# Clump 148
#  TIME          X                   Y
# ----- -------------------- -----------------
# 3.996 -0.05916624221509091 2.604612018099876
#
# Clump 149
#  TIME          X                   Y
# ----- ------------------- -------------------
# 3.996  0.6240055674070029 0.27638475790164246
# 3.999 -0.3005777781166956 0.14382562631779303
#
# Clump 150
#  TIME         X                 Y
# ----- ----------------- -----------------
# 3.997 5.665094899356783 2.677891524882123
#
# Clump 151
#  TIME         X                  Y
# ----- ------------------ ------------------
# 3.997 -2.949320386100482 -1.972064492258259
#
# Clump 152
#  TIME         X                   Y
# ----- ------------------ -------------------
# 3.997 3.4364829066866744  -2.568718218992743
# 3.999  3.640526828304546 -2.2620855027719835
#
# Clump 153
#  TIME         X                 Y
# ----- ----------------- ------------------
# 3.997 5.569324772809261 -4.612884516642022
# 3.999 5.790478317488451 -4.347442157986785
#
# Clump 154
#  TIME          X                   Y
# ----- ------------------- -------------------
# 3.998 0.06794848966221996 -0.6717767674071525
#
# Clump 155
#  TIME         X                   Y
# ----- ------------------ -------------------
# 3.998 1.7330281669948635 -3.5454314661273023
#
# Clump 156
#  TIME          X                  Y
# ----- ------------------- -----------------
# 3.999 -4.5421312450901015 2.798999246008884
#
# Clump 157
#  TIME          X                  Y
# ----- ------------------- ------------------
# 3.999 -3.6463021757127465 -5.227602610223454

# %%
plt.figure(figsize=(10,10))
snapshot = FitsRead(18)
colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(newClumps))]
for clump,c in zip(newClumps,colors):
    x = []
    y = []
    for index in clump[0]:
        ind = int(index)
        x.append(snapshot['X'][ind])
        y.append(snapshot['Y'][ind])
    plt.scatter(x,y,color=c)
im2, xedges, yedges  = np.histogram2d (-snapshot['Y'],snapshot['X'],(100,100),range=[[-7,7],[-7,7]])
extent2 = [yedges[0], yedges[-1], -xedges[-1], -xedges[0]]
plt.imshow(np.log(im2), cmap='Greys_r', extent=extent2)
# Out:
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in log

# %%
positions = (tbl['x_peak'], tbl['y_peak'])
apertures = phot.CircularAperture(positions, r=3)
norm = simple_norm(data, 'sqrt', percent=99.9)
plt.figure(figsize=(10,10))
plt.imshow(data, cmap='Greys_r', origin='lower', norm=norm)
apertures.plot(color='#0547f9', lw=1.5)
plt.xlim(0, data.shape[1]-1)
plt.ylim(0, data.shape[0]-1)
# Out:
# (0, 99)

# %%
# Read snapshot file
snapshot = FitsRead(16)
r = np.sqrt(snapshot['X']**2+snapshot['Y']**2)
theta = np.arctan2(snapshot['Y'],snapshot['X'])
vth = -snapshot['VX']*np.sin(theta)+snapshot['VY']*np.cos(theta)
snapshot.add_column(r,name='R')
snapshot.add_column(vth,name='VTH')

# Interpolate vDisk as a function of rho
bins = int(np.max(r)/2.5)
medians,binEdges,binNumber = stats.binned_statistic(r,vth,'median',bins)
edges = []
for i in range(0,len(binEdges)-1):
    edges.append((binEdges[i]+binEdges[i+1])/2)
w = np.isnan(medians)
medians[w] = 0
vDisk1 = UnivariateSpline(edges,medians,~w)

#Snapshot density plot
plt.figure(figsize=(10,10))
imS, xedgesS, yedgesS  = np.histogram2d (-snapshot['Y'],snapshot['X'],(100,100),range=[[-7,7],[-7,7]])
extentS = [yedgesS[0], yedgesS[-1], -xedgesS[-1], -xedgesS[0]]
plt.imshow(np.log(imS),extent=extentS)

#Clump 1 (2.77,3.5)
inclump1 = ((snapshot['X']-2.77)**2+(snapshot['Y']-3.5)**2<0.01)
clump1 = snapshot[inclump1]
#plt.figure(figsize=(10,10))
#imC1, xedgesC1, yedgesC1  = np.histogram2d (-clump1['Y'],clump1['X'],(100,100))
#extentC1 = [yedgesC1[0], yedgesC1[-1], -xedgesC1[-1], -xedgesC1[0]]
#plt.imshow(np.log(imC1),extent=extentC1)

#Clump 2 (0.9,4.23)
inclump2 = ((snapshot['X']-0.9)**2+(snapshot['Y']-4.23)**2<0.01)
clump2 = snapshot[inclump2]

#Clump 3 (-3.97,0.42)
inclump3 = ((snapshot['X']+3.97)**2+(snapshot['Y']-0.42)**2<0.01)
clump3 = snapshot[inclump3]

#Clump 4 (-2.96,4.3)
inclump4 = ((snapshot['X']+2.96)**2+(snapshot['Y']+4.3)**2<0.01)
clump4 = snapshot[inclump4]

#Plot vDisk and density plot
plt.figure(figsize=(10,10))
imVth, xedgesVth, yedgesVth  = np.histogram2d (-vth,r,(100,100),range=[[-400,50],[0,20]])
extentVth = [yedgesVth[0], yedgesVth[-1], -xedgesVth[-1], -xedgesVth[0]]
plt.imshow(np.log(imVth),extent=extentVth)
x = np.arange(0,20)
plt.plot(x,vDisk(x),color='r')
#plt.scatter(clump1['R'],clump1['VTH'])
plt.axes().set_aspect(20/450, 'datalim')

#Plot Vth vs r density plot for clumps
plt.figure(figsize=(10,10))
imV1, xedgesV1, yedgesV1  = np.histogram2d (-clump1['VTH'],clump1['R'],(100,20))
extentV1 = [yedgesV1[0], yedgesV1[-1], -xedgesV1[-1], -xedgesV1[0]]
plt.imshow(np.log(imV1),extent=extentV1)
imV2, xedgesV2, yedgesV2  = np.histogram2d (-clump2['VTH'],clump2['R'],(100,20))
extentV2 = [yedgesV2[0], yedgesV2[-1], -xedgesV2[-1], -xedgesV2[0]]
plt.imshow(np.log(imV2),extent=extentV2)
imV3, xedgesV3, yedgesV3  = np.histogram2d (-clump3['VTH'],clump3['R'],(100,20))
extentV3 = [yedgesV3[0], yedgesV3[-1], -xedgesV3[-1], -xedgesV3[0]]
plt.imshow(np.log(imV3),extent=extentV3)
imV4, xedgesV4, yedgesV4  = np.histogram2d (-clump4['VTH'],clump4['R'],(100,20))
extentV4 = [yedgesV4[0], yedgesV4[-1], -xedgesV4[-1], -xedgesV4[0]]
plt.imshow(np.log(imV4),extent=extentV4)
plt.plot(x,vDisk(x),color='r')
plt.xlim(3.5,5.5)
plt.axes().set_aspect(2/450, 'datalim')
# Out:
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: RuntimeWarning: divide by zero encountered in log
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:49: RuntimeWarning: divide by zero encountered in log
# C:\Users\betha\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: divide by zero encountered in log
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:62: RuntimeWarning: divide by zero encountered in log
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:65: RuntimeWarning: divide by zero encountered in log
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:68: RuntimeWarning: divide by zero encountered in log

# %%
clumps[28][1]
# Out:
# [735375.0,
#  735464.0,
#  735465.0,
#  735769.0,
#  735931.0,
#  736028.0,
#  736029.0,
#  736147.0,
#  736454.0,
#  736649.0,
#  736650.0]
