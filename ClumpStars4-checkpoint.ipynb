# %%
from astropy.table import Table
import numpy as np
import pylab as plt
import photutils as phot

# %%
def FitsRead(time):
    # Read the fits file for that time and return table of stars
    if time < 10:
        time = '0{0}'.format(time)
    try:
        fileName = 'coords.starsandgas.chemrun733DiffFB10T1.0.00{0}0.fits'.format(time)
        read = Table.read(fileName,1)
        stars = (read['P']=='s')
        cat = read[stars]
    except:
        try:
            fileName = 'coords.chem733DiffFB10T1.0.00{0}0.fits'.format(time)
            cat = Table.read(fileName,1)
        except:
            raise ValueError('No file')
    return cat

# %%
txyn = Table.read('clumps7.fits',1)
stars = Table.read('clumps7.fits',2)
merges = Table.read('clumps7.fits',3)
txyz = Table.read('txyzform.fits',1)

# %%
print(merges)
# Out:
#  TIME  N  CLUMP1 CLUMP2 CLUMP3 CLUMP4 CLUMP5 CLUMP6
# ----- --- ------ ------ ------ ------ ------ ------
# 0.735   2      9     12      0      0      0      0
# 0.735   2      3      4      0      0      0      0
# 0.735   2      6     18      0      0      0      0
# 0.736   2      6     12      0      0      0      0
# 0.737   2     16     36      0      0      0      0
#  0.74   2     19     20      0      0      0      0
#  0.74   2      2      3      0      0      0      0
# 0.741   2      9     16      0      0      0      0
# 0.741   2     18     19      0      0      0      0
# 0.741   2     12     19      0      0      0      0
#   ... ...    ...    ...    ...    ...    ...    ...
# 2.663   2    923   1117      0      0      0      0
# 2.663   2   1117   1142      0      0      0      0
# 2.667   3    923   1117   1142      0      0      0
# 3.237   2   1403   1478      0      0      0      0
# 3.324   2    923   1494      0      0      0      0
# 3.397   2    923   1632      0      0      0      0
# 3.417   2    923   1403      0      0      0      0
# 3.424   2   1403   1632      0      0      0      0
# 3.425   3    923   1403   1632      0      0      0
# 3.822   2    923   1439      0      0      0      0
# 3.831   2    923   1745      0      0      0      0
# Length = 300 rows

# %%
inCenter = (txyn['X']**2+txyn['Y']**2<0.09)
center = txyn[inCenter]

centerclumpslist = np.unique(center['CLUMPID'])
print(centerclumpslist)
print()

centerclumpslist2 = []
for i in centerclumpslist:
    inclumpi = (center['CLUMPID']==i)
    clumpi = center[inclumpi]
    if len(clumpi)>40:
        centerclumpslist2.append(i)
print(centerclumpslist2)
# Out:
# CLUMPID
# -------
#       1
#       6
#     105
#     171
#     183
#     185
#     202
#     204
#     237
#     526
#     ...
#     965
#    1010
#    1040
#    1086
#    1117
#    1142
#    1322
#    1335
#    1403
#    1632
#    1745
# Length = 28 rows
#
# [1, 6, 923, 965]

# %%
plt.figure(1,figsize=(10,10))
plt.figure(2,figsize=(10,10))
for i in centerclumpslist2:
    c1 = txyn[(txyn['CLUMPID']==i)]
    plt.figure(1)
    plt.plot(c1['TIME'],(c1['X']**2+c1['Y']**2)**(1/2),label='Clump {}'.format(i))
    plt.legend()
    plt.figure(2)
    plt.plot(c1['X'],c1['Y'],label='Clump {}'.format(i))
    plt.legend()
