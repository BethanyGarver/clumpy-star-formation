# %%
import pynbody as pb
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm as LN

# %%
starlog=pb.tipsy.StarLog('/media/bgarver/Backup Plus/Simulations/run739MCLF.starlog')

# %%
starlog.keys()
# Out:
# ['pos',
#  'x',
#  'y',
#  'z',
#  'vel',
#  'vx',
#  'vy',
#  'vz',
#  'iord',
#  'iorderGas',
#  'massform',
#  'rhoform',
#  'tempform',
#  'metals',
#  'tform']

# %%
plt.hist2d(starlog['x'],starlog['y'],bins=[100,100],norm=LN())
plt.show()
