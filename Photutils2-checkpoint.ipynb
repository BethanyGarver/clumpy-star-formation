# %%
import photutils as phot
from astropy.stats import sigma_clipped_stats
from astropy.table import Table
import numpy as np
import scipy.stats as stats
from scipy.interpolate import UnivariateSpline
import pylab as plt
from astropy.visualization import simple_norm

# %%
def FitsRead(time):
    if time < 10:
        time = '0{0}'.format(time)
    try:
        fileName = 'coords.starsandgas.chemrun733DiffFB10T1.0.00{0}0.fits'.format(time)
        read = Table.read(fileName,1)
        stars = (read['P']=='s')
        cat = read[stars]
    except:
        try:
            fileName = 'coords.chem733DiffFB10T1.0.00{0}0.fits'.format(time)
            cat = Table.read(fileName,1)
        except:
            raise ValueError('No file')
    return cat

# %%
def RotateBack(x,y,dtime,vcirc):
    lindist = vcirc*dtime
    rho = (x**2+y**2)**(1/2)
    nrot = lindist/(2*np.pi*rho)
    nrotints = []
    for i in nrot:
        nrotints.append(int(i))
    nrotints = np.array(nrotints)
    rotangle = nrot-nrotints
    rotanglerad = 2*np.pi*rotangle
    xrot = x*np.cos(-rotanglerad)-y*np.sin(-rotanglerad)
    yrot = x*np.sin(-rotanglerad)+y*np.cos(-rotanglerad)
    return xrot,yrot

# %%
def make_unique(original_list):
    unique_list = []
    [unique_list.append(obj) for obj in original_list if obj not in unique_list]
    return unique_list

# %%
# Read txyz file
txyz = Table.read('txyzform.fits',1)
rho = np.sqrt(txyz['XFORM']**2+txyz['YFORM']**2)
txyz.add_column(rho,name='RHO')
start = 1.55
dt = 0.001
clumps = []

# Read snapshot file
snapshot = FitsRead(16)
r = np.sqrt(snapshot['X']**2+snapshot['Y']**2)
theta = np.arctan2(snapshot['Y'],snapshot['X'])
vth = -snapshot['VX']*np.sin(theta)+snapshot['VY']*np.cos(theta)
snapshot.add_column(r,name='R')
snapshot.add_column(vth,name='VTH')

# Interpolate vDisk as a function of rho
bins = int(np.max(r)/2.5)
medians,binEdges,binNumber = stats.binned_statistic(r,vth,'median',bins)
edges = []
for i in range(0,len(binEdges)-1):
    edges.append((binEdges[i]+binEdges[i+1])/2)
w = np.isnan(medians)
medians[w] = 0
vDisk = UnivariateSpline(edges,medians,~w)

while start<1.65:
    #Find stars that formed in time interval
    end = start+5*dt
    tRange = (txyz['TFORM']>start,txyz['TFORM']<end)
    inRange = np.array(np.zeros(len(tRange[0])),dtype=bool)
    for i in range(0,len(inRange)):
        if tRange[0][i] and tRange[1][i]:
            inRange[i] = True
    newStars = txyz[inRange]

    # Move stars back in time to beginning of interval
    vcirc = vDisk(newStars['RHO'])
    dtime = newStars['TFORM']-start
    xrot,yrot = RotateBack(newStars['XFORM'],newStars['YFORM'],dtime,vcirc)
    im, xedges, yedges  = np.histogram2d (-yrot,xrot,(100,100))
    dx = xedges[1]-xedges[0]
    dy = yedges[1]-yedges[0]
    extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]
    
    # Find peaks in density
    data = im
    statsdata = []
    for i in data:
        for j in i:
            if j>1:
                statsdata.append(j)
    mean, median, std = sigma_clipped_stats(statsdata, sigma=3.0)
    threshold = median + (3 * std)
    tbl = phot.find_peaks(data, threshold, box_size=11)
    tbl['peak_value'].info.format = '%.8g'
    
    # Combine clumps that are in the same place
    positions = (xedges[tbl['x_peak']]+dx/2, yedges[tbl['y_peak']]+dy/2)
    peaks = []
    closelist = []
    # Find which clumps are too close to each other
    for i in range(0,len(positions[0])):
        jlist = [i]
        for j in range(i+1,len(positions[0])):
            xi = positions[0][i]
            yi = positions[1][i]
            xj = positions[0][j]
            yj = positions[1][j]
            dist2 = (xi-xj)**2+(yi-yj)**2
            if dist2<0.04:
                jlist.append(j)
        closelist.append(jlist)
    # Make a list where clumps close to each other are combined
    for i in range(0,len(closelist)):
        if len(closelist[i])>1:
            for j in closelist[i]:
                if i==j:
                    continue
                closelist[j] = closelist[0]
    closelist = make_unique(closelist)
    # Combine clumps
    for i in closelist:
        sumx = 0
        sumy = 0
        for j in i:
            sumx = sumx+positions[0][j]
            sumy = sumy+positions[1][j]
        meanx = sumx/len(i)
        meany = sumy/len(i)
        peaks.append([meanx,meany])
    xcoords = []
    ycoords = []
    # Make updated list of peaks
    for i in peaks:
        xcoords.append(i[0])
        ycoords.append(i[1])
    xcoords = np.array(xcoords)
    ycoords = np.array(ycoords)
    peaks1 = (xcoords,ycoords)
    
    # Track clumps through time
    leftx = xcoords
    lefty = ycoords
    lefti = []
    for i in range(0,len(leftx)):
        lefti.append(i)
    # Match clumps in current timestep to clumps in previous timesteps
    if len(clumps)>0:
        # Check most recent steps
        for skip in range(1,6):
            clumpsrho = (leftx**2+lefty**2)**(1/2)
            clumpsvcirc = vDisk(clumpsrho)
            cxrot,cyrot = RotateBack(leftx,lefty,dt,clumpsvcirc)
            xleft = []
            yleft = []
            ileft = []
            for i in range(0,len(cxrot)):
                for clump in clumps:
                    newest = clump[len(clump)-1]
                    if newest[0]==round(start-skip*dt,3):
                        xi = cxrot[i]
                        yi = cyrot[i]
                        xj = newest[1]
                        yj = newest[2]
                        if (xi-xj)**2+(yi-yj)**2<0.5:
                            clump.append([start,xcoords[lefti[i]],ycoords[lefti[i]]])
                            break
                    if clump==clumps[len(clumps)-1]:
                        xleft.append(xi)
                        yleft.append(yi)
                        ileft.append(lefti[i])
            leftx = np.array(xleft)
            lefty = np.array(yleft)
            lefti = ileft
    # Add leftover clumps to end
    for i in range(0,len(lefti)):
        clumps.append([[start,xcoords[lefti[i]],ycoords[lefti[i]]]])
    
    # Plot clumps
    apertures = phot.CircularAperture(peaks1, r=0.3)
    norm = simple_norm(data, 'sqrt', percent=99.9)
    #plt.figure(figsize=(10,10))
    #plt.imshow(data, cmap='Greys_r', origin='lower', norm=norm, extent=extent)
    #apertures.plot(color='#0547f9', lw=1.5)
    #plt.title("{0} million years, {1} clusters".format(int(start*1000),len(tbl)))
    start = round(start+dt,3)
# Out:
# C:\Users\betha\Anaconda3\lib\site-packages\scipy\stats\_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]

# %%
plt.figure(figsize=(10,10))
for i in clumps:
    x = []
    y = []
    for j in i:
        x.append(j[1])
        y.append(j[2])
    plt.plot(x,y)
plt.imshow(data, cmap='Greys_r', origin='lower', norm=norm, extent=extent)

plt.figure(figsize=(10,10))
for i in clumps:
    x = []
    y = []
    t = []
    for j in i:
        x.append(j[1])
        y.append(j[2])
        t.append(j[0])
    plt.plot(x,y)
    plt.scatter(x,y,c=t)

# %%
for i in clumps:
    t = Table(names=('TIME','X','Y'))
    for j in i:
        t.add_row((j[0],j[1],j[2]))
    print(t)
# Out:
#  TIME          X                   Y
# ----- ------------------- -------------------
#  1.55  -3.127627489784956  -3.972160601988665
# 1.551  -3.290408251911697 -3.8647043670638754
# 1.552  -3.252724054114213   -3.86228713795428
# 1.553  -3.483772577345204  -3.746849975908406
# 1.554  -3.818781292185997 -3.5243700131113838
# 1.555  -4.158775987869634 -3.2286384449993486
# 1.556  -4.267934363524284 -3.1173518587088305
# 1.557 -4.3736325506097735  -2.983791791742761
# 1.558  -4.475702348484562  -2.848922033407181
# 1.559  -4.604102581477354 -2.7617379911542845
#  1.56  -4.730835284649734   -2.65664723517931
# 1.561  -4.684543669507418 -2.5164800264448695
# 1.562 -4.7539813030395575  -2.441533916982329
# 1.563  -4.520078253228331 -2.4921129460533837
# 1.564   -4.57373751917219 -2.2953235841736204
# 1.565  -4.520481981348359  -2.223264464719883
#  TIME         X                   Y
# ----- ------------------ -------------------
#  1.55 3.6707831591804663  -2.898563411616132
# 1.551 3.3903637663701316  -2.896459807837805
# 1.552 3.2088515339082786 -3.1080331289788896
# 1.553 3.0213830433253435  -3.242686076725993
# 1.554 2.8374425461951804 -3.2002250802661645
# 1.555 2.5770603052895256  -3.335958588799401
# 1.556 2.4397351305523056 -3.4361123818705783
# 1.557 2.3024240393709285  -3.408326361090825
# 1.558  2.054627077296455  -3.484612078864622
# 1.559 2.1209972726178217 -3.5913906285811374
#  1.56 1.9053830257375344 -3.6806135178255426
# 1.561 1.7742412066554665  -3.881607610164624
# 1.562 1.5538145663493497  -4.016683363985949
# 1.563  1.523970694891298  -4.281313369807648
# 1.564 1.2679274630879513  -4.321422585204186
# 1.565  1.165420874849349  -4.367607059251645
#  TIME          X                   Y
# ----- ------------------- --------------------
#  1.55  0.3291914842652588  -0.3219301547220548
# 1.551 0.21982789328722951 -0.20689158776538674
# 1.552  0.3122831668637138  -0.3065182384988696
# 1.553 0.30780384155991447  -0.2897260958004324
# 1.554  0.2426434227584502  -0.1748723737107838
# 1.555 0.10725366446450035 -0.11635427479782834
# 1.556 0.09205080762549933 -0.14225364253251627
# 1.557 0.07707184271069467 -0.11818344864333197
# 1.558 0.06232318468529696 -0.09426516975826837
# 1.559 0.21555231395752195  -0.2727800788737249
#   ...                 ...                  ...
# 1.639 -0.3709465634293534  0.48166794055189666
#  1.64 -0.7289821506583438    0.619959657389022
# 1.641 -0.5138919900192356   0.6022322149332218
# 1.642 -0.6699740476097333    0.520644769919683
# 1.643 -0.5923256080272457   0.7166037971946029
# 1.644 -0.9594375567076403   0.9149693277250668
# 1.645 -0.9984857393696083   0.8725381022814678
