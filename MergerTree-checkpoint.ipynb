# %%
from astropy.table import Table
import numpy as np
import pylab as plt

# %%
def FitsRead(time):
    # Read the fits file for that time and return table of stars
    if time < 10:
        time = '0{0}'.format(time)
    try:
        fileName = 'coords.starsandgas.chemrun733DiffFB10T1.0.00{0}0.fits'.format(time)
        read = Table.read(fileName,1)
        stars = (read['P']=='s')
        cat = read[stars]
    except:
        try:
            fileName = 'coords.chem733DiffFB10T1.0.00{0}0.fits'.format(time)
            cat = Table.read(fileName,1)
        except:
            raise ValueError('No file')
    return cat

# %%
txy = Table.read('clumps5.fits',1)
txy.add_column(Table.Column(np.zeros(len(txy))+2),name='ID')
for i in range(0,len(txy)):
    if txy['CLUMPID'][i]==1:
        txy['ID'][i] = 1
stars = Table.read('clumps5.fits',2)
merges = Table.read('clumps5.fits',3)
merges.reverse()
txyz = Table.read('txyzform.fits',1)
for merge in merges:
    for i in txy:
        if i['CLUMPID']==merge['CLUMP1']:
            id1 = i['ID']
            break
    for i in range(0,len(txy)):
        if txy['CLUMPID'][i]==merge['CLUMP2']:
            txy['ID'][i] = id1+1
        elif txy['ID'][i]>id1:
            txy['ID'][i] = txy['ID'][i]+1
idmax = np.max(txy['ID'])
for i in range(0,len(txy)):
    if txy['ID'][i]==idmax:
        txy['ID'][i] = txy['ID'][i]+txy['CLUMPID'][i]
idlist = np.unique(np.array(txy['ID']))
for i in range(0,len(idlist)):
    for j in range(0,len(txy)):
        if txy['ID'][j]==idlist[i]:
            txy['ID'][j] = i+1
idlist = np.unique(np.array(txy['ID']))
for i in range(0,len(merges)):
    for j in range(2,len(merges[i])):
        if merges[i][j]!=0:
            inclump = txy[(txy['CLUMPID']==merges[i][j])]
            merges[i][j] = inclump['ID'][0]

masses = []
feh = []
ofe = []
for clumpid in np.unique(np.array(txy['CLUMPID'])):
    txyclump = txy[(txy['CLUMPID']==clumpid)]
    starsclump = stars[(stars['CLUMPID']==clumpid)]
    starttime = int(txyclump['TIME'][0]*10)+1
    endtime = int(txyclump['TIME'][-1]*10)+2
    for time in range(starttime,endtime):
        snapshot = FitsRead(time)
        cutstars = starsclump[(starsclump['INDEX']<len(snapshot))]
        clumpstars = snapshot[cutstars['INDEX']]
        meanfeh = np.mean(clumpstars['FEH'])
        meanofe = np.mean(clumpstars['OFE'])
        x = clumpstars['X']
        y = clumpstars['Y']
        tform = txyz['TFORM'][cutstars['INDEX']]
        try:
            current = txyclump[(txyclump['TIME'] == time/10)]
            clumpx = current['X']
            clumpy = current['Y']
            radius = 3*np.sqrt((sum((x-clumpx)**2)+sum((y-clumpy)**2))/len(x))
        except:
            clumpx = np.mean(x)
            clumpy = np.mean(y)
            radius = 3*np.sqrt((sum((x-clumpx)**2)+sum((y-clumpy)**2))/len(x))
        bound = clumpstars[((clumpstars['X']-clumpx)**2+(clumpstars['Y']-clumpy)**2<radius**2)]
        mass = sum(bound['MS'])*2.33*10**5
        for i in range(0,len(txyclump)):
            if int(txyclump['TIME'][i]*10)+1==time:
                masses.append(mass)
                feh.append(meanfeh)
                ofe.append(meanofe)
txy.add_column(Table.Column(masses),name='MASS')
txy.add_column(Table.Column(feh),name='FEH')
txy.add_column(Table.Column(ofe),name='OFE')

# %%
plt.figure(figsize=(20,20))
for i in idlist:
    clump = txy[(txy['ID']==i)]
    plt.text(clump['TIME'][0]-0.08,clump['ID'][0]-0.2,str(clump['CLUMPID'][0]))
plt.scatter(txy['TIME'],txy['ID'],c=np.log(txy['NSTARS']/5),s=8)
plt.colorbar()
for merge in merges:
    merge = list(merge)
    ids = merge[2:2+merge[1]]
    t = [merge[0]]*merge[1]
    plt.plot(t,ids,c='k')
    plt.title('Merger tree (color is log(sfr))')

# %%
plt.figure(figsize=(20,20))
for i in idlist:
    clump = txy[(txy['ID']==i)]
    plt.text(clump['TIME'][0]-0.08,clump['ID'][0]-0.2,str(clump['CLUMPID'][0]))
plt.scatter(txy['TIME'],txy['ID'],c=np.log(txy['MASS']),s=8)
plt.colorbar()
for merge in merges:
    merge = list(merge)
    ids = merge[2:2+merge[1]]
    t = [merge[0]]*merge[1]
    plt.plot(t,ids,c='k')
    plt.title('Merger tree (color is log(mass))')

# %%
plt.figure(figsize=(20,20))
for i in idlist:
    clump = txy[(txy['ID']==i)]
    plt.text(clump['TIME'][0]-0.08,clump['ID'][0]-0.2,str(clump['CLUMPID'][0]))
plt.scatter(txy['TIME'],txy['ID'],c=txy['FEH'],s=8)
plt.colorbar()
for merge in merges:
    merge = list(merge)
    ids = merge[2:2+merge[1]]
    t = [merge[0]]*merge[1]
    plt.plot(t,ids,c='k')
    plt.title('Merger tree (color is mean [Fe/H])')

# %%
plt.figure(figsize=(20,20))
for i in idlist:
    clump = txy[(txy['ID']==i)]
    plt.text(clump['TIME'][0]-0.08,clump['ID'][0]-0.2,str(clump['CLUMPID'][0]))
plt.scatter(txy['TIME'],txy['ID'],c=txy['OFE'],s=8)
plt.colorbar()
for merge in merges:
    merge = list(merge)
    ids = merge[2:2+merge[1]]
    t = [merge[0]]*merge[1]
    plt.plot(t,ids,c='k')
    plt.title('Merger tree (color is mean [O/Fe])')
