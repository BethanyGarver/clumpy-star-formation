# %%
from astropy.table import Table
import numpy as np
import pylab as plt
import photutils as phot

# %%
def FitsRead(time):
    # Read the fits file for that time and return table of stars
    if time < 10:
        time = '0{0}'.format(time)
    try:
        fileName = 'coords.starsandgas.chemrun733DiffFB10T1.0.00{0}0.fits'.format(time)
        read = Table.read(fileName,1)
        stars = (read['P']=='s')
        cat = read[stars]
    except:
        try:
            fileName = 'coords.chem733DiffFB10T1.0.00{0}0.fits'.format(time)
            cat = Table.read(fileName,1)
        except:
            raise ValueError('No file')
    return cat

# %%
txy = Table.read('clumps3.fits',1)
stars = Table.read('clumps3.fits',2)
txyz = Table.read('txyzform.fits',1)

# %%
txyin63 = (txy['CLUMPID']==63)
txy63 = txy[txyin63]
print(txy63)
# Out:
# CLUMPID  TIME      X           Y
# ------- ----- ----------- -----------
#      63  1.93  -4.1725526  -0.8820582
#      63 1.931  -4.0885167  -1.0724915
#      63 1.932   -3.991415  -1.2601566
#      63 1.933  -3.8975046   -1.438829
#      63 1.934  -3.7753441  -1.6204238
#      63 1.935   -3.661603  -1.7887685
#      63 1.936  -3.5209465  -1.9580102
#      63 1.937  -3.3714552  -2.1349692
#      63 1.938  -3.2325113  -2.2908213
#      63 1.939  -3.0383172  -2.4488688
#     ...   ...         ...         ...
#      63 2.661  0.28140095  0.53654295
#      63 2.662 0.027685408   0.5585411
#      63 2.663 -0.18961138  0.49130303
#      63 2.664 -0.41989538  0.27970162
#      63 2.665 -0.50868714   0.0614549
#      63 2.666 -0.47620332 -0.21385184
#      63 2.667 -0.32656813 -0.41505206
#      63 2.668 -0.17262192 -0.49661028
#      63 2.669 0.042323865  -0.4977459
#      63  2.67   0.1945689  -0.4242155
#      63 2.671   0.3216302 -0.28484547
# Length = 741 rows

# %%
x = txy63['X']
y = txy63['Y']
plt.figure(figsize=(10,10))
plt.plot(x,y)

# %%
starsin63 = (stars['CLUMPID']==63)
stars63 = stars[starsin63]
print(stars63)
# Out:
# CLUMPID  INDEX
# ------- -------
#      63  831131
#      63  831132
#      63  831133
#      63  831134
#      63  831534
#      63  831535
#      63  831536
#      63  831690
#      63  831691
#      63  831692
#     ...     ...
#      63 1025690
#      63 1025697
#      63 1025698
#      63 1025699
#      63 1025700
#      63 1025701
#      63 1025704
#      63 1025717
#      63 1025718
#      63 1025761
#      63 1025773
# Length = 28955 rows

# %%
for time in range(20,28):
    plt.figure(figsize=(10,10))
    snapshot = FitsRead(time)
    cut = (stars63['INDEX']<len(snapshot))
    cutstars = stars63[cut]
    clumpstars = snapshot[cutstars['INDEX']]
    x = clumpstars['X']
    y = clumpstars['Y']
    age = time/10-txyz['TFORM'][cutstars['INDEX']]
    plt.scatter(x,y,c=age,s=1)
    plt.colorbar()
    current = (txy63['TIME'] == time/10)
    location = txy63[current]
    if len(location) == 0:
        clumpx = 0
        clumpy = 0
    else:
        clumpx = location['X']
        clumpy = location['Y']
    aperture = phot.CircularAperture((clumpx,clumpy), r=0.5)
    aperture.plot(color='r', lw=1.5)
    im, xedges, yedges  = np.histogram2d (-snapshot['Y'],snapshot['X'],(100,100),range=[[-7,7],[-7,7]])
    extent = [yedges[0], yedges[-1], -xedges[-1], -xedges[0]]
    plt.imshow(np.log(im),cmap='Greys_r',extent=extent)
    plt.xlabel('x')
    plt.ylabel('y')
    nearby = ((x-clumpx)**2+(y-clumpy)**2<0.25)
    stillthere = clumpstars[nearby]
    mass = sum(stillthere['MS'])
    plt.title('Clump 63 stars at {0} billion years (color is age). Mass = {1}'.format(time/10,mass))
# Out:
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: RuntimeWarning: divide by zero encountered in log

# %%
for time in range(20,28):
    plt.figure(figsize=(20,10))
    snapshot = FitsRead(time)
    cut = (stars63['INDEX']<len(snapshot))
    cutstars = stars63[cut]
    clumpstars = snapshot[cutstars['INDEX']]
    x = clumpstars['X']
    z = clumpstars['Z']
    age = time/10-txyz['TFORM'][cutstars['INDEX']]
    plt.scatter(x,z,c=age,s=1)
    plt.colorbar()
    plt.xlabel('x')
    plt.ylabel('z')
    plt.title('Clump 63 stars at {0} billion years (color is age)'.format(time/10))
    im, xedges, yedges  = np.histogram2d (-snapshot['Z'],snapshot['X'],(100,100),range=[[-2,2],[-7,7]])
    extent = [yedges[0], yedges[-1], -xedges[-1], -xedges[0]]
    plt.imshow(np.log(im),cmap='Greys_r',extent=extent)
# Out:
# C:\Users\betha\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: RuntimeWarning: divide by zero encountered in log

# %%
for time in range(20,28):
    plt.figure(figsize=(10,10))
    snapshot = FitsRead(time)
    cut = (stars63['INDEX']<len(snapshot))
    cutstars = stars63[cut]
    clumpstars = snapshot[cutstars['INDEX']]
    feh = clumpstars['FEH']
    ofe = clumpstars['OFE']
    age = time/10-txyz['TFORM'][cutstars['INDEX']]
    plt.scatter(feh,ofe,c=age,s=1)
    plt.colorbar()
    plt.xlabel('[Fe/H]')
    plt.ylabel('[O/Fe]')
    plt.xlim((-0.8,0.6))
    plt.ylim((-0.6,0.2))
    plt.title('[O/Fe] vs [Fe/H] for Clump 63 stars at {0} billion years (color is age)'.format(time/10))

# %%
time = txyz['TFORM'][stars63['INDEX']]
plt.hist(time, bins=250)
# Out:
# (array([ 17.,  25.,  28.,  23.,  18.,  31.,  24.,  32.,  22.,  36.,  29.,
#          32.,  27.,  42.,  36.,  35.,  65.,  76.,  95.,  85.,  59.,  73.,
#          78.,  61.,  83.,  57.,  59.,  62.,  61.,  63.,  46.,  49.,  46.,
#          38.,  25.,  27.,  33.,  26.,  17.,  23.,  38.,  19.,  25.,  21.,
#          31.,  45.,  45.,  46.,  54.,  48.,  51.,  50.,  56.,  37.,  42.,
#          51.,  47.,  34.,  39.,  44.,  28.,  41.,  38.,  37.,  46.,  46.,
#          43.,  49.,  46.,  51.,  53.,  32.,  34.,  44.,  44.,  42.,  44.,
#          40.,  44.,  35.,  40.,  25.,  51.,  54.,  43.,  49.,  35.,  41.,
#          50.,  33.,  41.,  48.,  59.,  50.,  46.,  91., 103., 118., 119.,
#         2.33292503, 2.33590503, 2.33888503, 2.34186503, 2.34484503,
#         2.34782503, 2.35080503, 2.35378503, 2.35676503, 2.35974503,
#         2.36272504, 2.36570504, 2.36868504, 2.37166504, 2.37464504,
#         2.37762504, 2.38060504, 2.38358504, 2.38656504, 2.38954504,
#         2.39252504, 2.39550504, 2.39848504, 2.40146504, 2.40444504,
#         2.40742504, 2.41040504, 2.41338504, 2.41636504, 2.41934505,
#         2.42232505, 2.42530505, 2.42828505, 2.43126505, 2.43424505,
#         2.43722505, 2.44020505, 2.44318505, 2.44616505, 2.44914505,
#         2.45212505, 2.45510505, 2.45808505, 2.46106505, 2.46404505,
#         2.46702505, 2.47000505, 2.47298505, 2.47596506, 2.47894506,
#         2.48192506, 2.48490506, 2.48788506, 2.49086506, 2.49384506,
#         2.49682506, 2.49980506, 2.50278506, 2.50576506, 2.50874506,
#         2.51172506, 2.51470506, 2.51768506, 2.52066506, 2.52364506,
#         2.52662506, 2.52960506, 2.53258507, 2.53556507, 2.53854507,
#         2.54152507, 2.54450507, 2.54748507, 2.55046507, 2.55344507,
#         2.55642507, 2.55940507, 2.56238507, 2.56536507, 2.56834507,
#         2.57132507, 2.57430507, 2.57728507, 2.58026507, 2.58324507,
#         2.58622507, 2.58920507, 2.59218508, 2.59516508, 2.59814508,
#         2.60112508, 2.60410508, 2.60708508, 2.61006508, 2.61304508,
#         2.61602508, 2.61900508, 2.62198508, 2.62496508, 2.62794508,
#         2.63092508, 2.63390508, 2.63688508, 2.63986508, 2.64284508,
#         2.64582508, 2.64880509, 2.65178509, 2.65476509, 2.65774509,
#         2.66072509, 2.66370509, 2.66668509, 2.66966509, 2.67264509,
#         2.67562509]),
#  <a list of 250 Patch objects>)

# %%
for time in range(16,41):
    snapshot = FitsRead(time)
    cut = (stars['INDEX']<len(snapshot))
    cutstars = stars[cut]
    clumpstars = snapshot[cutstars['INDEX']]
    plt.figure(figsize=(20,5))
    im, xedges, yedges  = np.histogram2d (-clumpstars['OFE'],clumpstars['FEH'],(100,100),range=[[-0.6,0.8],[-1.5,0.6]])
    extent = [yedges[0], yedges[-1], -xedges[-1], -xedges[0]]
    plt.subplot(1,2,1)
    plt.gca().set_title('[O/Fe] vs [Fe/H] for clump stars at {0} billion years'.format(time/10))
    plt.imshow(im,extent=extent)
    plt.xlabel('[Fe/H]')
    plt.ylabel('[O/Fe]')
    plt.subplot(1,2,2)
    im, xedges, yedges  = np.histogram2d (-snapshot['OFE'],snapshot['FEH'],(100,100),range=[[-0.6,0.8],[-1.5,0.6]])
    extent = [yedges[0], yedges[-1], -xedges[-1], -xedges[0]]
    plt.gca().set_title('[O/Fe] vs [Fe/H] for all stars at {0} billion years'.format(time/10))
    plt.imshow(im,extent=extent)
    plt.xlabel('[Fe/H]')
    plt.ylabel('[O/Fe]')
# Out:
# C:\Users\betha\Anaconda3\lib\site-packages\matplotlib\pyplot.py:522: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
snapshot.colnames
# Out:
# ['P', 'X', 'Y', 'Z', 'VX', 'VY', 'VZ', 'MS', 'TEMP', 'FEH', 'OFE']
